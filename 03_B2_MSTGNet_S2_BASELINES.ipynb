# %%
from pathlib import Path
from datetime import datetime
import gc
import shutil
import warnings
import inspect

import numpy as np
import pandas as pd
import torch

import model_base as mb

warnings.simplefilter("default")


# ============================================================
# Run switches
# ============================================================
# Final default below is prepared for running S1 now.
# If you want only dry-run again, set RUN_S0_DRYRUN=True and RUN_S1_MAIN_CV=False.

RUN_S0_DRYRUN = False

# Keep this False so S1 is controlled explicitly.
AUTO_RUN_S1_AFTER_S0_PASS = False

RUN_S1_MAIN_CV = False
RUN_S2_BASELINES = True
RUN_S3_ARCH_ABLATION = False
RUN_S3B_TEMPORAL_SENSITIVITY = False
RUN_S4_MODAL_ABLATION = False
RUN_S5_LANDMARK_QUALITY = False
RUN_S6_CROSS_DATASET = False
RUN_S7_MULTI_SEED = False
RUN_S8_COMPUTE_COST = False
RUN_S9_CALIBRATION_EXPORT = False
RUN_S10_INTERPRETABILITY = False
RUN_S11_EXPORT_PAPER_TABLES = False

CONFIRM_LONG_RUNS = True
RUN_S1_PREFLIGHT_CHECK = False
RUN_PRE_EXPERIMENT_CAPACITY_CHECK = False



# ============================================================
# Global setup
# ============================================================

SEED = 42
mb.set_all_seeds(SEED)

DEVICE = mb.get_device()

RUN_DATE_OVERRIDE = "20260501"

if RUN_DATE_OVERRIDE is None:
    RUN_DATE = datetime.now().strftime("%Y%m%d")
else:
    RUN_DATE = str(RUN_DATE_OVERRIDE)

OUTPUT_ROOT = Path(f"outputs/revision_final_{RUN_DATE}")
PROCESSED_DIR = Path("data/processed")

CONFIG = {
    "sequence_length": 50,
    "stride": 25,
    "hidden_features": 128,
    "num_heads": 4,
    "dropout_i3d": 0.4,
    "dropout_rlt": 0.3,
    "batch_size": 16,
    "epochs": 100,
    "patience": 15,
    "lr": 1e-4,
    "weight_decay": 1e-2,
    "validation_split": 0.28,
    "threshold_strategy": "validation_youden",
    "early_stopping_metric": "validation_auc",
    "main_seed": 42,
    "multiseeds": [42, 123, 2024, 2025, 3407],
    "fallback_multiseeds": [42, 123, 2024],
    "i3d_cv": {"n_splits": 5, "n_repeats": 1},
    "rlt_cv": {"n_splits": 5, "n_repeats": 3},
    "rlt_ablation_cv": {"n_splits": 5, "n_repeats": 1},
    "full_model_use_cross_modal": False,
    "transformer_num_layers": 4,
    "s7_multiseed_split_protocol": (
        "All seeds share identical video-level splits generated with seed=42 "
        "to isolate random initialization/training stochasticity from data partition variance."
    ),
    "s6_cross_dataset_protocol": (
        "MSTGNet source-only is trained on source train and thresholded on source validation; "
        "traditional temporal-stat source-only and diagonal CORAL are run separately. "
        "Target test is never used for training, scaling, thresholding, or adaptation."
    ),
    "notes": {
        "canonical_split_files": (
            "Use *_splits_main_seed42.json or *_splits_CANONICAL_main_seed42.json "
            "as canonical split definitions. Files named *_splits_seed*.json may be "
            "created internally by run_cv_experiment and can contain only remaining splits."
        ),
        "s6_mstgnet_source_only": (
            "S6 MSTGNet source-only is trained specifically on the source dataset for transfer. "
            "It does not reuse S1 best checkpoints."
        ),
        "manuscript_consistency": (
            "Manuscript must say sigmoid binary logit, not softmax; traditional ML uses "
            "temporal-stat 13,527-D descriptors, not mean-only 1,503-D; mixed precision "
            "should not be claimed unless AMP is added; dropout is dataset-specific "
            "I3D=0.4 and RLT=0.3."
        ),
    },
}

DATASETS = ["I3D", "RLT"]

for subdir in [
    "config",
    "config/splits",
    "tables",
    "predictions",
    "fold_results",
    "stats",
    "checkpoints",
    "interpretability",
    "cross_dataset",
    "landmark_quality",
    "compute_cost",
    "figures_data",
    "logs",
    "manuscript_exports",
]:
    mb.ensure_dir(OUTPUT_ROOT / subdir)

print("OUTPUT_ROOT:", OUTPUT_ROOT)
print("DEVICE:", DEVICE)

manifest = mb.create_experiment_manifest(
    output_dir=OUTPUT_ROOT,
    config=CONFIG,
    run_name="revision_final_v5",
)
mb.save_experiment_manifest(manifest, OUTPUT_ROOT)


# ============================================================
# model_base API validation
# ============================================================

required_mb_functions = [
    "dry_run_one_fold",
    "run_cv_experiment",
    "run_deep_learning_baselines",
    "run_traditional_ml_baseline",
    "run_cross_dataset_methods",
    "run_cross_dataset_mstgnet_source_only",
    "compute_landmark_quality_table",
    "compute_landmark_quality_prediction_correlation",
    "compute_gradient_importance_from_checkpoint",
    "save_gradient_importance",
    "select_checkpoint_validation_only",
    "compare_models_statistically",
    "compute_repeat_level_ci",
    "save_repeat_level_ci_table",
    "audit_video_split_overlap",
    "get_video_labels_from_data",
    "filter_completed_splits",
    "summarize_cv_results",
    "default_traditional_ml_models",
    "make_video_level_splits",
    "save_splits",
    "load_splits",
    "prepare_sequences",
    "compute_model_capacity_table",
    "wilcoxon_signed_rank_test",
    "paired_ttest",
    "safe_json_dump",
    "standardize_model_names_for_paper",
    "build_mstgnet_factory",
    "build_transformer_factory",
    "build_lstm_factory",
    "build_bilstm_factory",
    "build_gru_factory",
    "build_cnn_lstm_factory",
]

for name in required_mb_functions:
    assert hasattr(mb, name), f"model_base missing: {name}"

print("PASS: model_base API compatible with notebook")


# ============================================================
# Helper functions
# ============================================================

def transformer_model_name() -> str:
    return f"Transformer_L{int(CONFIG['transformer_num_layers'])}"


def dataset_dropout(dataset_name: str) -> float:
    name = str(dataset_name).upper()
    if name == "I3D":
        return float(CONFIG["dropout_i3d"])
    if name == "RLT":
        return float(CONFIG["dropout_rlt"])
    return 0.3


def dataset_cv_params(dataset_name: str) -> dict:
    name = str(dataset_name).upper()
    if name == "I3D":
        return CONFIG["i3d_cv"]
    if name == "RLT":
        return CONFIG["rlt_cv"]
    raise ValueError(f"Unknown dataset: {dataset_name}")


def active_feature_dim(dataset_name: str) -> int:
    if "data_dict" in globals() and dataset_name in data_dict:
        return int(len(data_dict[dataset_name]["coord_cols_active"]))
    return 1503


def build_mstgnet_for_dataset(
    dataset_name: str,
    data: dict,
    *,
    use_graph: bool = True,
    use_temporal: bool = True,
    use_pooling: bool = True,
    use_cross_modal: bool = False,
    enabled_modalities=("face", "eyes", "body"),
    hidden_dim: int = None,
    dropout: float = None,
):
    if hidden_dim is None:
        hidden_dim = int(CONFIG["hidden_features"])
    if dropout is None:
        dropout = dataset_dropout(dataset_name)

    return mb.build_mstgnet_factory(
        input_dim=int(len(data["coord_cols_active"])),
        modality_slices=data["active_modality_slices"],
        hidden_dim=int(hidden_dim),
        num_heads=int(CONFIG["num_heads"]),
        dropout=float(dropout),
        enabled_modalities=tuple(enabled_modalities),
        use_graph=bool(use_graph),
        use_temporal=bool(use_temporal),
        use_pooling=bool(use_pooling),
        use_cross_modal=bool(use_cross_modal),
    )


def build_transformer_for_dataset(
    dataset_name: str,
    *,
    input_dim: int = None,
    hidden_dim: int = None,
    num_layers: int = None,
    dropout: float = None,
):
    if input_dim is None:
        input_dim = active_feature_dim(dataset_name)
    if hidden_dim is None:
        hidden_dim = int(CONFIG["hidden_features"])
    if dropout is None:
        dropout = dataset_dropout(dataset_name)
    if num_layers is None:
        num_layers = int(CONFIG["transformer_num_layers"])

    return mb.build_transformer_factory(
        input_dim=int(input_dim),
        hidden_dim=int(hidden_dim),
        num_heads=int(CONFIG["num_heads"]),
        num_layers=int(num_layers),
        dropout=float(dropout),
    )


def require_long_run(section_name: str):
    if not CONFIRM_LONG_RUNS:
        raise RuntimeError(
            f"{section_name} is a long run. Set CONFIRM_LONG_RUNS=True before running."
        )


def read_csv_if_exists(path):
    path = Path(path)
    if path.exists():
        return pd.read_csv(path)
    return pd.DataFrame()


def copy_if_exists(src, dst):
    src = Path(src)
    dst = Path(dst)
    if src.exists():
        mb.ensure_dir(dst.parent)
        shutil.copy(src, dst)
        print(f"Copied: {src} -> {dst}")
    else:
        print(f"Skip copy, not found: {src}")


def save_table(df: pd.DataFrame, name: str) -> Path:
    path = OUTPUT_ROOT / "tables" / name
    mb.ensure_dir(path.parent)
    df.to_csv(path, index=False)
    print(f"Saved table: {path} shape={df.shape}")
    return path


def fold_results_file(model_name: str, dataset_name: str) -> Path:
    return OUTPUT_ROOT / "fold_results" / f"{model_name}_{dataset_name}.csv"


def combine_fold_results(files_or_patterns) -> pd.DataFrame:
    rows = []

    for item in files_or_patterns:
        item_path = Path(item)
        item_str = str(item_path)

        if "*" in item_str or "?" in item_str:
            parent = item_path.parent
            pattern = item_path.name
            matched = sorted(parent.glob(pattern))
        else:
            matched = [item_path]

        for p in matched:
            if p.exists():
                try:
                    rows.append(pd.read_csv(p))
                except Exception as e:
                    warnings.warn(f"Could not read {p}: {e}", RuntimeWarning)

    if rows:
        return pd.concat(rows, ignore_index=True)

    return pd.DataFrame()


def drop_duplicate_fold_rows(df: pd.DataFrame) -> pd.DataFrame:
    if df is None or len(df) == 0:
        return pd.DataFrame()

    key_cols = [
        "dataset",
        "source_dataset",
        "target_dataset",
        "model",
        "seed",
        "repeat",
        "fold",
    ]
    existing = [c for c in key_cols if c in df.columns]

    required_base = {"dataset", "model", "seed", "repeat", "fold"}
    if required_base.issubset(set(existing)):
        return df.drop_duplicates(subset=existing, keep="last").reset_index(drop=True)

    return df.drop_duplicates().reset_index(drop=True)


def drop_duplicate_prediction_rows(df: pd.DataFrame) -> pd.DataFrame:
    if df is None or len(df) == 0:
        return pd.DataFrame()

    candidate_keys = [
        "dataset",
        "source_dataset",
        "target_dataset",
        "model",
        "seed",
        "repeat",
        "fold",
        "split",
        "video_id",
    ]
    existing = [c for c in candidate_keys if c in df.columns]

    required_base = {"dataset", "model", "seed", "repeat", "fold", "split", "video_id"}
    if required_base.issubset(set(existing)):
        return df.drop_duplicates(subset=existing, keep="last").reset_index(drop=True)

    return df.drop_duplicates().reset_index(drop=True)


def summarize_results(
    df: pd.DataFrame,
    *,
    output_name: str,
    metric_cols=None,
    group_cols=None,
) -> pd.DataFrame:
    if df is None or len(df) == 0:
        out = pd.DataFrame()
    else:
        out = mb.summarize_cv_results(
            df,
            metric_cols=metric_cols,
            group_cols=group_cols,
        )
    save_table(out, output_name)
    return out


def make_or_load_splits(
    dataset_name: str,
    data: dict,
    *,
    n_splits: int,
    n_repeats: int,
    seed: int = 42,
    suffix: str = "main",
):
    split_path = OUTPUT_ROOT / "config" / "splits" / f"{dataset_name}_splits_{suffix}_seed{seed}.json"

    if split_path.exists():
        print(f"Loading existing splits: {split_path}")
        return mb.load_splits(split_path)

    video_ids, y_video = mb.get_video_labels_from_data(data)

    splits = mb.make_video_level_splits(
        video_ids,
        y_video,
        n_splits=int(n_splits),
        n_repeats=int(n_repeats),
        val_ratio=float(CONFIG["validation_split"]),
        seed=int(seed),
    )
    mb.save_splits(splits, split_path)
    print(f"Saved splits: {split_path}")
    return splits


def first_repeat_only(splits):
    return [s for s in splits if int(s["repeat"]) == 1]


def clean_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()


def safe_torch_load_checkpoint_local(path, map_location="cpu"):
    try:
        return torch.load(path, map_location=map_location, weights_only=False)
    except TypeError:
        return torch.load(path, map_location=map_location)


def save_full_model_reference_for_ablation(dataset_name: str):
    src_full = OUTPUT_ROOT / "fold_results" / f"MSTGNet_{dataset_name}.csv"
    dst_full_ref = OUTPUT_ROOT / "fold_results" / f"full_model_reference_{dataset_name}.csv"

    if src_full.exists():
        df_full = pd.read_csv(src_full)

        if "repeat" in df_full.columns:
            df_full_ref = df_full[df_full["repeat"].astype(int) == 1].copy()
        else:
            df_full_ref = df_full.copy()

        df_full_ref.to_csv(dst_full_ref, index=False)
        print(
            f"Saved full model reference for ablation: {dst_full_ref} "
            f"shape={df_full_ref.shape}"
        )
    else:
        print(f"Skip full model reference, not found: {src_full}")


def require_full_model_reference(dataset_name: str):
    ref_path = OUTPUT_ROOT / "fold_results" / f"full_model_reference_{dataset_name}.csv"
    if not ref_path.exists():
        raise FileNotFoundError(
            f"Missing full-model reference for {dataset_name}: {ref_path}. "
            "Run S1 first, or create full_model_reference_{dataset}.csv from repeat=1."
        )
    return ref_path


def get_param_column(df: pd.DataFrame):
    for c in ["n_trainable_params", "n_params", "trainable_params"]:
        if c in df.columns:
            return c
    return None


def deep_learning_baseline_names() -> list:
    return [
        "LSTM",
        "BiLSTM",
        "GRU",
        "CNN-LSTM",
        transformer_model_name(),
    ]


def traditional_ml_model_names() -> list:
    return list(mb.default_traditional_ml_models(seed=SEED).keys())


def cross_dataset_model_names() -> list:
    return [
        "MSTGNet_SourceOnly",
        "LogReg_temporal_stat_SourceOnly",
        "LogReg_temporal_stat_CORAL",
        "RF_temporal_stat_SourceOnly",
        "RF_temporal_stat_CORAL",
        "SVM_temporal_stat_SourceOnly",
        "SVM_temporal_stat_CORAL",
        "GradBoost_temporal_stat_SourceOnly",
        "GradBoost_temporal_stat_CORAL",
    ]


def architecture_ablation_model_names() -> list:
    return [
        "MSTGNet_NoGraph",
        "MSTGNet_NoTemporal",
        "MSTGNet_NoPooling",
        "MSTGNet_CrossModalAblation",
    ]


def modality_ablation_model_names() -> list:
    return [
        "MSTGNet_FaceOnly",
        "MSTGNet_EyesOnly",
        "MSTGNet_BodyOnly",
        "MSTGNet_FaceEyes",
        "MSTGNet_FaceBody",
        "MSTGNet_EyesBody",
    ]


def all_baseline_model_names() -> list:
    return ["MSTGNet"] + deep_learning_baseline_names() + traditional_ml_model_names()


def baseline_fold_result_files() -> list:
    files = []
    for model_name in all_baseline_model_names():
        for ds in DATASETS:
            files.append(OUTPUT_ROOT / "fold_results" / f"{model_name}_{ds}.csv")
    return files


def run_cv_resume_safe(
    *,
    dataset_name: str,
    model_name: str,
    model_factory,
    X_seq,
    y_seq,
    video_seq_ids,
    splits,
    seed: int,
    save_checkpoint: bool = True,
) -> pd.DataFrame:
    existing_path = fold_results_file(model_name, dataset_name)
    splits_to_run = mb.filter_completed_splits(
        splits,
        fold_results_path=existing_path,
        seed=seed,
    )

    df_new = pd.DataFrame()

    if len(splits_to_run) > 0:
        df_new = mb.run_cv_experiment(
            dataset_name=dataset_name,
            model_name=model_name,
            model_factory=model_factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_to_run,
            device=DEVICE,
            output_dir=OUTPUT_ROOT,
            batch_size=int(CONFIG["batch_size"]),
            epochs=int(CONFIG["epochs"]),
            patience=int(CONFIG["patience"]),
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            seed=seed,
            save_checkpoint=save_checkpoint,
        )
    else:
        print(f"{model_name} | {dataset_name}: all splits already complete.")

    if existing_path.exists():
        return pd.read_csv(existing_path)

    return df_new


def find_best_checkpoint(
    dataset_name: str,
    model_name: str = "MSTGNet",
    *,
    seed_whitelist=None,
    repeat_whitelist=None,
):
    path = OUTPUT_ROOT / "fold_results" / f"{model_name}_{dataset_name}.csv"

    return mb.select_checkpoint_validation_only(
        path,
        seed_whitelist=seed_whitelist,
        repeat_whitelist=repeat_whitelist,
        checkpoint_col="checkpoint_path",
    )


def standardize_table_for_paper_if_exists(table_name: str):
    path = OUTPUT_ROOT / "tables" / table_name
    if not path.exists():
        return

    df = pd.read_csv(path)
    if "model" in df.columns:
        df = mb.standardize_model_names_for_paper(df)
        df.to_csv(path, index=False)
        print(f"Standardized paper model names in: {path}")


# ============================================================
# Load processed datasets
# ============================================================

data_dict = {}

for ds in DATASETS:
    data_dict[ds] = mb.load_processed_dataset(
        ds,
        processed_dir=PROCESSED_DIR,
        expected_observed_features=1533,
        expected_active_features=1503,
    )


# ============================================================
# Dataset summary
# ============================================================

dataset_summary_rows = []

for ds, data in data_dict.items():
    video_ids, y = mb.get_video_labels_from_data(data)

    dataset_summary_rows.append(
        {
            "dataset": ds,
            "n_videos": int(len(video_ids)),
            "n_class_0": int(np.sum(y == 0)),
            "n_class_1": int(np.sum(y == 1)),
            "n_observed_features": int(len(data["coord_cols_observed"])),
            "n_active_features": int(len(data["coord_cols_active"])),
            "face_slice": str(data["active_modality_slices"].get("face")),
            "eyes_slice": str(data["active_modality_slices"].get("eyes")),
            "body_slice": str(data["active_modality_slices"].get("body")),
        }
    )

dataset_summary_df = pd.DataFrame(dataset_summary_rows)
save_table(dataset_summary_df, "dataset_summary.csv")
print(dataset_summary_df)


# ============================================================
# Splits
# ============================================================

splits_main = {}
splits_ablation = {}

for ds, data in data_dict.items():
    cvp = dataset_cv_params(ds)
    splits_main[ds] = make_or_load_splits(
        ds,
        data,
        n_splits=cvp["n_splits"],
        n_repeats=cvp["n_repeats"],
        seed=SEED,
        suffix="main",
    )

    canonical_path = (
        OUTPUT_ROOT
        / "config"
        / "splits"
        / f"{ds}_splits_CANONICAL_main_seed{SEED}.json"
    )
    mb.save_splits(splits_main[ds], canonical_path)

    splits_ablation[ds] = first_repeat_only(splits_main[ds])

print(
    {k: len(v) for k, v in splits_main.items()},
    {k: len(v) for k, v in splits_ablation.items()},
)

for ds in DATASETS:
    audit = mb.audit_video_split_overlap(splits_main[ds])
    print(ds)
    print(audit["status"].value_counts(dropna=False))
    assert (audit["status"] == "PASS").all(), audit

print("PASS: all main splits have no video-level overlap")


# ============================================================
# Sequence cache
# ============================================================

sequence_cache = {}


def get_sequences(dataset_name: str, *, seq_len=None, stride=None, cache_key=None):
    if seq_len is None:
        seq_len = int(CONFIG["sequence_length"])
    if stride is None:
        stride = int(CONFIG["stride"])

    if cache_key is None:
        cache_key = f"{dataset_name}_L{seq_len}_S{stride}"

    if cache_key in sequence_cache:
        return sequence_cache[cache_key]

    X_seq, y_seq, video_seq_ids = mb.prepare_sequences(
        data_dict[dataset_name],
        seq_len=int(seq_len),
        stride=int(stride),
        use_active_features=True,
        pad_short_videos=True,
        pad_mode="edge",
        verbose=True,
    )

    sequence_cache[cache_key] = (X_seq, y_seq, video_seq_ids)
    return X_seq, y_seq, video_seq_ids


# ============================================================
# Capacity check
# ============================================================

def capacity_factories_for_dataset(ds: str) -> dict:
    n_features = active_feature_dim(ds)
    hidden_dim = int(CONFIG["hidden_features"])
    dropout = dataset_dropout(ds)

    factories = {
        "MSTGNet": build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        ),
        "LSTM": mb.build_lstm_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            num_layers=1,
        ),
        "BiLSTM": mb.build_bilstm_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            num_layers=1,
        ),
        "GRU": mb.build_gru_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            num_layers=1,
        ),
        "CNN-LSTM": mb.build_cnn_lstm_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            conv_kernel_size=5,
            lstm_layers=1,
            use_batchnorm=True,
        ),
    }

    layers = sorted(set([4, 6, int(CONFIG["transformer_num_layers"])]))
    for layer in layers:
        factories[f"Transformer_L{layer}"] = build_transformer_for_dataset(
            ds,
            num_layers=layer,
        )

    return factories


if RUN_PRE_EXPERIMENT_CAPACITY_CHECK:
    capacity_rows = []

    for ds in DATASETS:
        cdf = mb.compute_model_capacity_table(capacity_factories_for_dataset(ds))
        cdf["dataset"] = ds

        param_col = get_param_column(cdf)
        if param_col is not None:
            mstg_params = cdf.loc[cdf["model"].eq("MSTGNet"), param_col]
            if len(mstg_params) == 1:
                ref = float(mstg_params.iloc[0])
                cdf["param_ratio_vs_MSTGNet_manual"] = cdf[param_col] / max(ref, 1.0)

        capacity_rows.append(cdf)

    capacity_check_df = (
        pd.concat(capacity_rows, ignore_index=True)
        if capacity_rows else pd.DataFrame()
    )

    capacity_path = OUTPUT_ROOT / "compute_cost" / "capacity_check_pre_S2.csv"
    capacity_check_df.to_csv(capacity_path, index=False)

    print(f"Saved pre-S2 capacity check: {capacity_path}")
    print(capacity_check_df)

    param_col = get_param_column(capacity_check_df)
    if param_col is not None:
        for ds in DATASETS:
            d = capacity_check_df[capacity_check_df["dataset"].eq(ds)].copy()
            if len(d) == 0:
                continue

            mstg = d.loc[d["model"].eq("MSTGNet"), param_col]
            tr_name = transformer_model_name()
            tr = d.loc[d["model"].eq(tr_name), param_col]

            if len(mstg) == 1 and len(tr) == 1:
                ratio = float(tr.iloc[0]) / max(float(mstg.iloc[0]), 1.0)
                if ratio < 0.5 or ratio > 2.0:
                    warnings.warn(
                        f"{ds}: {tr_name} capacity ratio vs MSTGNet is {ratio:.3f}. "
                        "Consider changing CONFIG['transformer_num_layers'] to 4 or 6.",
                        RuntimeWarning,
                    )


# ============================================================
# S1 preflight check
# ============================================================

if RUN_S1_PREFLIGHT_CHECK:
    print("\n" + "=" * 80)
    print("S1 PREFLIGHT CHECK")
    print("=" * 80)

    print("run_cv_experiment:", inspect.signature(mb.run_cv_experiment))
    print("build_mstgnet_factory:", inspect.signature(mb.build_mstgnet_factory))

    assert hasattr(mb, "dry_run_one_fold")
    assert hasattr(mb, "run_cv_experiment")
    assert hasattr(mb, "filter_completed_splits")
    assert hasattr(mb, "build_mstgnet_factory")

    for ds in DATASETS:
        assert ds in data_dict
        assert len(data_dict[ds]["coord_cols_active"]) == 1503
        assert "face" in data_dict[ds]["active_modality_slices"]
        assert "eyes" in data_dict[ds]["active_modality_slices"]
        assert "body" in data_dict[ds]["active_modality_slices"]

    print("PASS: S1 preflight checks OK")


# ============================================================
# S0 — Dry-run
# ============================================================

s0_outputs = {}

if RUN_S0_DRYRUN:
    for ds in DATASETS:
        print("\n" + "=" * 80)
        print(f"S0 Dry-run: {ds}")
        print("=" * 80)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        model_factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        row = mb.dry_run_one_fold(
            dataset_name=ds,
            model_name="MSTGNet",
            model_factory=model_factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_ablation[ds],
            device=DEVICE,
            output_dir=OUTPUT_ROOT / f"S0_dryrun_{ds}",
            batch_size=int(CONFIG["batch_size"]),
            epochs=2,
            patience=2,
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            seed=SEED,
        )

        dry_status = str(row.get("dry_run_status", "")).upper()
        gate_status = "PASS" if dry_status.startswith("PASS") else "FAIL"
        best_val_auc = row.get("best_val_auc", np.nan)

        out = {
            "gate_status": gate_status,
            "dry_run_status": dry_status,
            "fold_result": row,
            "gate_checks": {
                "dry_run_status_pass": bool(gate_status == "PASS"),
                "auc_gt_0_5_desirable_not_hard_gate": bool(
                    np.isfinite(best_val_auc) and float(best_val_auc) > 0.5
                ),
            },
        }

        s0_outputs[ds] = out

        print(f"{ds} gate_status:", out["gate_status"])
        print("dry_run_status:", out["dry_run_status"])
        print("gate_checks:", out["gate_checks"])

    print(s0_outputs)


if RUN_S0_DRYRUN and AUTO_RUN_S1_AFTER_S0_PASS:
    s0_pass = all(
        str(s0_outputs.get(ds, {}).get("gate_status", "")).upper() == "PASS"
        for ds in DATASETS
    )

    print("AUTO_RUN_S1_AFTER_S0_PASS:", AUTO_RUN_S1_AFTER_S0_PASS)
    print("S0 all PASS:", s0_pass)

    if s0_pass:
        RUN_S1_MAIN_CV = True
        CONFIRM_LONG_RUNS = True
        print("S0 passed for all datasets. Enabling RUN_S1_MAIN_CV=True.")
    else:
        RUN_S1_MAIN_CV = False
        print("S0 did not pass for all datasets. S1 will not run.")
elif AUTO_RUN_S1_AFTER_S0_PASS and not RUN_S0_DRYRUN:
    print(
        "AUTO_RUN_S1_AFTER_S0_PASS=True but RUN_S0_DRYRUN=False; "
        "auto S1 gate skipped. RUN_S1_MAIN_CV remains:",
        RUN_S1_MAIN_CV,
    )


# ============================================================
# S1 — Main CV: MSTGNet
# ============================================================

if RUN_S1_MAIN_CV:
    require_long_run("S1_MAIN_CV")

    s1_results = []

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S1 Main CV — MSTGNet Final — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        model_factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        df = run_cv_resume_safe(
            dataset_name=ds,
            model_name="MSTGNet",
            model_factory=model_factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_main[ds],
            seed=SEED,
            save_checkpoint=True,
        )

        s1_results.append(df)
        clean_memory()

        copy_if_exists(
            OUTPUT_ROOT / "fold_results" / f"MSTGNet_{ds}.csv",
            OUTPUT_ROOT / "fold_results" / f"main_{ds}.csv",
        )

        save_full_model_reference_for_ablation(ds)

        copy_if_exists(
            OUTPUT_ROOT / "predictions" / f"MSTGNet_{ds}_video_predictions.csv",
            OUTPUT_ROOT / "predictions" / f"main_{ds}_video_predictions.csv",
        )

    s1_all = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "MSTGNet_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "MSTGNet_RLT.csv",
    ])
    s1_all = drop_duplicate_fold_rows(s1_all)

    summarize_results(s1_all, output_name="main_results_summary.csv")
    print(s1_all)


# ============================================================
# S2 — Baselines: DL baselines + Traditional ML
# ============================================================

if RUN_S2_BASELINES:
    require_long_run("S2_BASELINES")

    s2_results = []

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S2 — Deep Learning Baselines — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        df_dl = mb.run_deep_learning_baselines(
            dataset_name=ds,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_main[ds],
            device=DEVICE,
            output_dir=OUTPUT_ROOT,
            input_dim=active_feature_dim(ds),
            hidden_dim=int(CONFIG["hidden_features"]),
            num_heads=int(CONFIG["num_heads"]),
            transformer_num_layers=int(CONFIG["transformer_num_layers"]),
            dropout=dataset_dropout(ds),
            cnn_lstm_use_batchnorm=True,
            batch_size=int(CONFIG["batch_size"]),
            epochs=int(CONFIG["epochs"]),
            patience=int(CONFIG["patience"]),
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            seed=SEED,
            save_checkpoint=True,
            model_whitelist=deep_learning_baseline_names(),
        )
        s2_results.append(df_dl)
        clean_memory()

        print("\n" + "#" * 90)
        print(f"S2 — Traditional ML temporal-stat — {ds}")
        print("#" * 90)

        df_ml = mb.run_traditional_ml_baseline(
            dataset_name=ds,
            data=data_dict[ds],
            splits=splits_main[ds],
            output_dir=OUTPUT_ROOT,
            seed=SEED,
            feature_mode="temporal_stat",
        )
        s2_results.append(df_ml)
        clean_memory()

    baseline_all = combine_fold_results(baseline_fold_result_files())
    baseline_all = drop_duplicate_fold_rows(baseline_all)

    summarize_results(
        baseline_all,
        output_name="table_baseline_comparison.csv",
    )

    baseline_all.to_csv(
        OUTPUT_ROOT / "tables" / "baseline_fold_results_all.csv",
        index=False,
    )
    print(baseline_all)


# ============================================================
# S3 — Architecture ablation
# ============================================================

if RUN_S3_ARCH_ABLATION:
    require_long_run("S3_ARCH_ABLATION")

    for ds in DATASETS:
        require_full_model_reference(ds)

    arch_variants = {
        "MSTGNet_NoGraph": {
            "use_graph": False,
            "use_temporal": True,
            "use_pooling": True,
            "use_cross_modal": False,
        },
        "MSTGNet_NoTemporal": {
            "use_graph": True,
            "use_temporal": False,
            "use_pooling": True,
            "use_cross_modal": False,
        },
        "MSTGNet_NoPooling": {
            "use_graph": True,
            "use_temporal": True,
            "use_pooling": False,
            "use_cross_modal": False,
        },
        "MSTGNet_CrossModalAblation": {
            "use_graph": True,
            "use_temporal": True,
            "use_pooling": True,
            "use_cross_modal": True,
        },
    }

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S3 Architecture Ablation — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)
        ab_splits = splits_ablation[ds]

        for model_name, kwargs in arch_variants.items():
            print("\n" + "-" * 70)
            print(f"{model_name} — {ds}")
            print("-" * 70)

            factory = build_mstgnet_for_dataset(
                ds,
                data_dict[ds],
                use_graph=kwargs["use_graph"],
                use_temporal=kwargs["use_temporal"],
                use_pooling=kwargs["use_pooling"],
                use_cross_modal=kwargs["use_cross_modal"],
                enabled_modalities=("face", "eyes", "body"),
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name=model_name,
                model_factory=factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=ab_splits,
                seed=SEED,
                save_checkpoint=True,
            )
            clean_memory()

    arch_files = [
        OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "full_model_reference_RLT.csv",
    ]
    for model_name in architecture_ablation_model_names():
        for ds in DATASETS:
            arch_files.append(OUTPUT_ROOT / "fold_results" / f"{model_name}_{ds}.csv")

    arch_all = combine_fold_results(arch_files)
    arch_all = drop_duplicate_fold_rows(arch_all)

    summarize_results(
        arch_all,
        output_name="table_architecture_ablation.csv",
    )

    arch_all.to_csv(
        OUTPUT_ROOT / "fold_results" / "arch_ablation_all.csv",
        index=False,
    )
    print(arch_all)


# ============================================================
# S3B — Temporal sensitivity
# ============================================================

if RUN_S3B_TEMPORAL_SENSITIVITY:
    require_long_run("S3B_TEMPORAL_SENSITIVITY")
    require_full_model_reference("I3D")

    ds = "I3D"

    temporal_settings = [
        {"name": "MSTGNet_Window100", "seq_len": 100, "stride": 50},
    ]

    for setting in temporal_settings:
        print("\n" + "#" * 90)
        print(f"S3B Temporal Sensitivity — {setting['name']} — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(
            ds,
            seq_len=setting["seq_len"],
            stride=setting["stride"],
            cache_key=f"{ds}_L{setting['seq_len']}_S{setting['stride']}",
        )

        factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        _ = run_cv_resume_safe(
            dataset_name=ds,
            model_name=setting["name"],
            model_factory=factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_ablation[ds],
            seed=SEED,
            save_checkpoint=True,
        )
        clean_memory()

    temporal_all = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "MSTGNet_Window100_I3D.csv",
    ])
    temporal_all = drop_duplicate_fold_rows(temporal_all)

    summarize_results(
        temporal_all,
        output_name="table_temporal_sensitivity.csv",
    )

    temporal_all.to_csv(
        OUTPUT_ROOT / "fold_results" / "temporal_sensitivity_all.csv",
        index=False,
    )
    print(temporal_all)


# ============================================================
# S4 — Modality ablation
# ============================================================

if RUN_S4_MODAL_ABLATION:
    require_long_run("S4_MODAL_ABLATION")

    for ds in DATASETS:
        require_full_model_reference(ds)

    modality_variants = {
        "MSTGNet_FaceOnly": ("face",),
        "MSTGNet_EyesOnly": ("eyes",),
        "MSTGNet_BodyOnly": ("body",),
        "MSTGNet_FaceEyes": ("face", "eyes"),
        "MSTGNet_FaceBody": ("face", "body"),
        "MSTGNet_EyesBody": ("eyes", "body"),
    }

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S4 Modality Ablation — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)
        ab_splits = splits_ablation[ds]

        for model_name, modalities in modality_variants.items():
            print("\n" + "-" * 70)
            print(f"{model_name} modalities={modalities} — {ds}")
            print("-" * 70)

            factory = build_mstgnet_for_dataset(
                ds,
                data_dict[ds],
                use_graph=True,
                use_temporal=True,
                use_pooling=True,
                use_cross_modal=False,
                enabled_modalities=modalities,
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name=model_name,
                model_factory=factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=ab_splits,
                seed=SEED,
                save_checkpoint=True,
            )
            clean_memory()

    modal_files = [
        OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "full_model_reference_RLT.csv",
    ]
    for model_name in modality_ablation_model_names():
        for ds in DATASETS:
            modal_files.append(OUTPUT_ROOT / "fold_results" / f"{model_name}_{ds}.csv")

    modal_all = combine_fold_results(modal_files)
    modal_all = drop_duplicate_fold_rows(modal_all)

    summarize_results(
        modal_all,
        output_name="table_modality_ablation.csv",
    )

    modal_all.to_csv(
        OUTPUT_ROOT / "fold_results" / "modal_ablation_all.csv",
        index=False,
    )
    print(modal_all)


# ============================================================
# S5 — Landmark quality
# ============================================================

if RUN_S5_LANDMARK_QUALITY:
    quality_dfs = []

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S5 Landmark Quality — {ds}")
        print("#" * 90)

        qdf = mb.compute_landmark_quality_table(
            data_dict[ds],
            dataset_name=ds,
            use_active_features=True,
            long_format=True,
        )
        quality_dfs.append(qdf)

    quality_all = (
        pd.concat(quality_dfs, ignore_index=True)
        if quality_dfs else pd.DataFrame()
    )

    quality_path = OUTPUT_ROOT / "landmark_quality" / "quality_by_video.csv"
    quality_all.to_csv(quality_path, index=False)
    print(f"Saved landmark quality table: {quality_path} shape={quality_all.shape}")

    if len(quality_all) > 0:
        quality_summary = (
            quality_all
            .groupby(["dataset", "modality"], dropna=False)
            .agg(
                n_videos=("video_id", "nunique"),
                finite_rate_mean=("finite_rate", "mean"),
                finite_rate_std=("finite_rate", "std"),
                nonfinite_rate_mean=("nonfinite_rate", "mean"),
                nonfinite_rate_std=("nonfinite_rate", "std"),
                zero_rate_mean=("zero_rate", "mean"),
                zero_rate_std=("zero_rate", "std"),
                mean_abs_value_mean=("mean_abs_value", "mean"),
                mean_abs_value_std=("mean_abs_value", "std"),
                std_abs_value_mean=("std_abs_value", "mean"),
                std_abs_value_std=("std_abs_value", "std"),
                mean_abs_velocity_mean=("mean_abs_velocity", "mean"),
                mean_abs_velocity_std=("mean_abs_velocity", "std"),
                std_abs_velocity_mean=("std_abs_velocity", "mean"),
                std_abs_velocity_std=("std_abs_velocity", "std"),
                p95_abs_velocity_mean=("p95_abs_velocity", "mean"),
                p95_abs_velocity_std=("p95_abs_velocity", "std"),
            )
            .reset_index()
        )
    else:
        quality_summary = pd.DataFrame()

    save_table(quality_summary, "table_landmark_quality.csv")
    print(quality_summary)

    quality_corr_dfs = []

    for ds in DATASETS:
        pred_path = OUTPUT_ROOT / "predictions" / f"MSTGNet_{ds}_video_predictions.csv"

        if not pred_path.exists():
            print(f"Skip quality-prediction correlation for {ds}; missing: {pred_path}")
            continue

        if len(quality_all) == 0:
            print(f"Skip quality-prediction correlation for {ds}; quality_all empty.")
            continue

        pred_df = pd.read_csv(pred_path)
        q_ds = quality_all[quality_all["dataset"].astype(str) == str(ds)].copy()

        if len(q_ds) == 0:
            print(f"Skip quality-prediction correlation for {ds}; no quality rows.")
            continue

        corr_df = mb.compute_landmark_quality_prediction_correlation(
            q_ds,
            pred_df,
            prediction_split="test",
            model_filter="MSTGNet",
            aggregate_predictions_per_video=True,
        )

        corr_df["dataset_requested"] = ds
        quality_corr_dfs.append(corr_df)

        corr_path = (
            OUTPUT_ROOT
            / "landmark_quality"
            / f"quality_prediction_correlation_{ds}.csv"
        )
        corr_df.to_csv(corr_path, index=False)
        print(f"Quality-prediction correlation {ds}: {corr_path} shape={corr_df.shape}")

    quality_corr_all = (
        pd.concat(quality_corr_dfs, ignore_index=True)
        if quality_corr_dfs else pd.DataFrame()
    )

    quality_corr_all.to_csv(
        OUTPUT_ROOT / "landmark_quality" / "quality_prediction_correlation_all.csv",
        index=False,
    )

    save_table(
        quality_corr_all,
        "table_landmark_quality_prediction_correlation.csv",
    )


# ============================================================
# S6 — Cross-dataset generalization
# ============================================================

if RUN_S6_CROSS_DATASET:
    require_long_run("S6_CROSS_DATASET")

    s6_pairs = [
        ("I3D", "RLT"),
        ("RLT", "I3D"),
    ]

    s6_results = []

    for source_ds, target_ds in s6_pairs:
        print("\n" + "#" * 90)
        print(f"S6 Cross-Dataset: {source_ds} -> {target_ds}")
        print("#" * 90)

        print("\n" + "-" * 70)
        print(f"S6A MSTGNet source-only: {source_ds} -> {target_ds}")
        print("-" * 70)

        source_model_factory = build_mstgnet_for_dataset(
            source_ds,
            data_dict[source_ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        df_mstg_source_only = mb.run_cross_dataset_mstgnet_source_only(
            source_dataset_name=source_ds,
            target_dataset_name=target_ds,
            source_data=data_dict[source_ds],
            target_data=data_dict[target_ds],
            target_splits=splits_ablation[target_ds],
            model_factory=source_model_factory,
            device=DEVICE,
            output_dir=OUTPUT_ROOT,
            seed=SEED,
            source_val_ratio=0.2,
            seq_len=int(CONFIG["sequence_length"]),
            stride=int(CONFIG["stride"]),
            batch_size=int(CONFIG["batch_size"]),
            epochs=int(CONFIG["epochs"]),
            patience=int(CONFIG["patience"]),
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            num_workers=0,
            model_name="MSTGNet_SourceOnly",
            save_checkpoint=True,
        )

        s6_results.append(df_mstg_source_only)
        clean_memory()

        print("\n" + "-" * 70)
        print(f"S6B Traditional ML source-only/CORAL: {source_ds} -> {target_ds}")
        print("-" * 70)

        df_trad_cd = mb.run_cross_dataset_methods(
            source_dataset_name=source_ds,
            target_dataset_name=target_ds,
            source_data=data_dict[source_ds],
            target_data=data_dict[target_ds],
            target_splits=splits_ablation[target_ds],
            output_dir=OUTPUT_ROOT,
            seed=SEED,
            source_val_ratio=0.2,
            models=mb.default_traditional_ml_models(seed=SEED),
            run_coral=True,
            coral_mode="diagonal",
            feature_mode="temporal_stat",
        )

        s6_results.append(df_trad_cd)
        clean_memory()

    s6_all = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "*_to_*.csv",
    ])
    s6_all = drop_duplicate_fold_rows(s6_all)

    save_table(s6_all, "table_cross_dataset.csv")
    s6_all.to_csv(
        OUTPUT_ROOT / "cross_dataset" / "cross_dataset_all_fold_results.csv",
        index=False,
    )

    print(s6_all)


# ============================================================
# S7 — Multi-seed robustness
# ============================================================

if RUN_S7_MULTI_SEED:
    require_long_run("S7_MULTI_SEED")

    tr_name = transformer_model_name()
    extra_seeds = [s for s in CONFIG["multiseeds"] if int(s) != 42]

    for seed in extra_seeds:
        seed = int(seed)

        print("\n" + "#" * 90)
        print(f"S7 Multi-seed additional seed={seed}")
        print("#" * 90)

        for ds in DATASETS:
            print("\n" + "=" * 80)
            print(f"S7 — {ds} — seed={seed}")
            print("=" * 80)

            X_seq, y_seq, video_seq_ids = get_sequences(ds)

            mstg_factory = build_mstgnet_for_dataset(
                ds,
                data_dict[ds],
                use_graph=True,
                use_temporal=True,
                use_pooling=True,
                use_cross_modal=False,
                enabled_modalities=("face", "eyes", "body"),
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name="MSTGNet",
                model_factory=mstg_factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=splits_main[ds],
                seed=seed,
                save_checkpoint=True,
            )
            clean_memory()

            transformer_factory = build_transformer_for_dataset(
                ds,
                num_layers=int(CONFIG["transformer_num_layers"]),
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name=tr_name,
                model_factory=transformer_factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=splits_main[ds],
                seed=seed,
                save_checkpoint=True,
            )
            clean_memory()

    multiseed_df = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "MSTGNet_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "MSTGNet_RLT.csv",
        OUTPUT_ROOT / "fold_results" / f"{tr_name}_I3D.csv",
        OUTPUT_ROOT / "fold_results" / f"{tr_name}_RLT.csv",
    ])
    multiseed_df = drop_duplicate_fold_rows(multiseed_df)

    multiseed_df.to_csv(
        OUTPUT_ROOT / "stats" / "multiseed_results.csv",
        index=False,
    )

    stat_rows = []
    stat_json = {}

    for ds in DATASETS:
        wilcoxon_result = mb.wilcoxon_signed_rank_test(
            multiseed_df,
            model_a="MSTGNet",
            model_b=tr_name,
            metric="test_auc",
            dataset=ds,
        )

        ttest_result = mb.paired_ttest(
            multiseed_df,
            model_a="MSTGNet",
            model_b=tr_name,
            metric="test_auc",
            dataset=ds,
        )

        stat_json[ds] = {
            "wilcoxon_mstgnet_vs_transformer": wilcoxon_result,
            "paired_ttest_mstgnet_vs_transformer": ttest_result,
        }

        stat_rows.append(
            {
                "dataset": ds,
                "metric": "test_auc",
                "model_a": "MSTGNet",
                "model_b": tr_name,
                "wilcoxon_p_value": wilcoxon_result.get("p_value", np.nan),
                "wilcoxon_n_pairs": wilcoxon_result.get("n_pairs", np.nan),
                "paired_ttest_p_value": ttest_result.get("p_value", np.nan),
                "paired_ttest_n_pairs": ttest_result.get("n_pairs", np.nan),
                "mean_diff_mstgnet_minus_transformer": wilcoxon_result.get(
                    "mean_diff_a_minus_b",
                    np.nan,
                ),
            }
        )

    stats_df = pd.DataFrame(stat_rows)
    stats_df.to_csv(
        OUTPUT_ROOT / "stats" / "statistical_tests_summary.csv",
        index=False,
    )

    multiseed_summary = mb.summarize_cv_results(
        multiseed_df,
        metric_cols=[
            "test_auc",
            "test_accuracy",
            "test_balanced_accuracy",
            "test_mcc",
            "test_f1",
        ],
        group_cols=["dataset", "model"],
    )

    save_table(multiseed_summary, "table_multiseed_robustness.csv")

    repeat_ci_metrics = [
        "test_auc",
        "test_f1",
        "test_mcc",
        "test_balanced_accuracy",
    ]

    repeat_ci_path = mb.save_repeat_level_ci_table(
        multiseed_df,
        OUTPUT_ROOT,
        filename="repeat_level_ci_multiseed.csv",
        metrics=repeat_ci_metrics,
        group_cols=["dataset", "model"],
        ci=0.95,
    )
    print(f"Saved repeat-level CI table: {repeat_ci_path}")

    for ds in DATASETS:
        ds_df = multiseed_df[multiseed_df["dataset"].astype(str) == str(ds)].copy()

        if len(ds_df) == 0:
            print(f"Skip repeat-level CI for {ds}: no data.")
            continue

        n_repeats_available = (
            int(ds_df["repeat"].nunique())
            if "repeat" in ds_df.columns else 1
        )
        print(f"\n{ds}: n_repeats_available={n_repeats_available}")

        ds_ci_parts = []

        for metric in repeat_ci_metrics:
            ci_df = mb.compute_repeat_level_ci(
                ds_df,
                metric=metric,
                group_cols=["dataset", "model"],
                ci=0.95,
            )

            if ci_df is not None and len(ci_df) > 0:
                ci_df["n_repeats_available"] = n_repeats_available
                ds_ci_parts.append(ci_df)

        ds_ci_all = (
            pd.concat(ds_ci_parts, ignore_index=True)
            if ds_ci_parts else pd.DataFrame()
        )

        ds_ci_path = OUTPUT_ROOT / "stats" / f"repeat_level_ci_{ds}.csv"
        ds_ci_all.to_csv(ds_ci_path, index=False)
        print(f"  Saved: {ds_ci_path} shape={ds_ci_all.shape}")

        preview_cols = [
            "dataset",
            "model",
            "metric",
            "repeat_n",
            "mean",
            "ci_low",
            "ci_high",
        ]
        existing_preview_cols = [c for c in preview_cols if c in ds_ci_all.columns]

        if len(ds_ci_all) > 0 and len(existing_preview_cols) > 0:
            print(ds_ci_all[existing_preview_cols].to_string(index=False))

    repeat_ci_all_parts = []

    for ds in DATASETS:
        p = OUTPUT_ROOT / "stats" / f"repeat_level_ci_{ds}.csv"
        if p.exists():
            repeat_ci_all_parts.append(pd.read_csv(p))

    repeat_ci_all = (
        pd.concat(repeat_ci_all_parts, ignore_index=True)
        if repeat_ci_all_parts else pd.DataFrame()
    )

    repeat_ci_all.to_csv(
        OUTPUT_ROOT / "stats" / "repeat_level_ci_all_datasets.csv",
        index=False,
    )

    save_table(repeat_ci_all, "table_repeat_level_ci.csv")
    print(f"\nRepeat-level CI all datasets: {repeat_ci_all.shape}")

    all_results_for_stats = combine_fold_results(baseline_fold_result_files())
    all_results_for_stats = drop_duplicate_fold_rows(all_results_for_stats)

    if len(all_results_for_stats) > 0:
        full_comparison_df = mb.compare_models_statistically(
            all_results_for_stats,
            reference_model="MSTGNet",
            metric="test_auc",
            adjust_pvalues=True,
        )

        full_comparison_df.to_csv(
            OUTPUT_ROOT / "stats" / "statistical_comparison_all_models.csv",
            index=False,
        )

        save_table(full_comparison_df, "table_statistical_comparison.csv")

        stat_json["all_model_comparison_note"] = (
            "Full comparison computed against all available paired fold results "
            "from baseline_fold_result_files(). Pairing uses dataset/seed/repeat/fold."
        )
    else:
        full_comparison_df = pd.DataFrame()
        warnings.warn(
            "No baseline fold results available for full statistical comparison.",
            RuntimeWarning,
        )

    mb.safe_json_dump(
        stat_json,
        OUTPUT_ROOT / "stats" / "statistical_tests.json",
    )

    print(stats_df)
    print(full_comparison_df)


# ============================================================
# S8 — Computational cost
# ============================================================

if RUN_S8_COMPUTE_COST:
    cost_sources = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "*.csv",
    ])
    cost_sources = drop_duplicate_fold_rows(cost_sources)

    cost_models = [
        "MSTGNet",
        "LSTM",
        "BiLSTM",
        "GRU",
        "CNN-LSTM",
        transformer_model_name(),
        "LogReg_temporal_stat",
        "RF_temporal_stat",
        "SVM_temporal_stat",
        "GradBoost_temporal_stat",
        "MSTGNet_NoGraph",
        "MSTGNet_NoTemporal",
        "MSTGNet_NoPooling",
        "MSTGNet_CrossModalAblation",
        "MSTGNet_FaceOnly",
        "MSTGNet_EyesOnly",
        "MSTGNet_BodyOnly",
        "MSTGNet_FaceEyes",
        "MSTGNet_FaceBody",
        "MSTGNet_EyesBody",
        "MSTGNet_Window100",
    ]

    cost_models += cross_dataset_model_names()

    if "model" in cost_sources.columns:
        cost_sources = cost_sources[cost_sources["model"].isin(cost_models)].copy()

    keep_cols = [
        "dataset",
        "source_dataset",
        "target_dataset",
        "model",
        "seed",
        "repeat",
        "fold",
        "n_params",
        "n_trainable_params",
        "n_total_params",
        "train_time_sec",
        "ms_per_batch",
        "ms_per_sequence",
        "ms_per_video",
        "n_train_seq",
        "n_val_seq",
        "n_test_seq",
        "n_train_videos",
        "n_val_videos",
        "n_test_videos",
        "n_source_train_videos",
        "n_source_val_videos",
        "n_target_adapt_videos",
        "n_target_test_videos",
    ]

    if len(cost_sources) > 0:
        existing_cols = [c for c in keep_cols if c in cost_sources.columns]
        cost_fold = cost_sources[existing_cols].copy()
    else:
        cost_fold = pd.DataFrame(columns=keep_cols)

    cost_fold.to_csv(
        OUTPUT_ROOT / "compute_cost" / "cost_table.csv",
        index=False,
    )

    param_col = get_param_column(cost_fold)

    if len(cost_fold) > 0:
        agg_kwargs = {
            "n_folds": ("fold", "count"),
            "train_time_sec_mean": ("train_time_sec", "mean"),
            "train_time_sec_std": ("train_time_sec", "std"),
            "ms_per_video_mean": ("ms_per_video", "mean"),
            "ms_per_video_std": ("ms_per_video", "std"),
            "ms_per_sequence_mean": ("ms_per_sequence", "mean"),
            "ms_per_sequence_std": ("ms_per_sequence", "std"),
        }

        if param_col is not None:
            agg_kwargs["n_params_mean"] = (param_col, "mean")
            agg_kwargs["n_params_median"] = (param_col, "median")

        cost_summary = (
            cost_fold
            .groupby(["dataset", "model"], dropna=False)
            .agg(**agg_kwargs)
            .reset_index()
        )
    else:
        cost_summary = pd.DataFrame()

    save_table(cost_summary, "table_computational_cost.csv")

    capacity_rows = []

    for ds in DATASETS:
        cdf = mb.compute_model_capacity_table(capacity_factories_for_dataset(ds))
        cdf["dataset"] = ds
        capacity_rows.append(cdf)

    capacity_df = (
        pd.concat(capacity_rows, ignore_index=True)
        if capacity_rows else pd.DataFrame()
    )

    capacity_df.to_csv(
        OUTPUT_ROOT / "compute_cost" / "model_capacity_table.csv",
        index=False,
    )

    print(capacity_df)


# ============================================================
# S9 — Calibration export
# ============================================================

if RUN_S9_CALIBRATION_EXPORT:
    pred_files = sorted((OUTPUT_ROOT / "predictions").glob("*video_predictions.csv"))

    pred_dfs = []

    for p in pred_files:
        try:
            d = pd.read_csv(p)
            d["source_file"] = str(p)
            pred_dfs.append(d)
        except Exception as e:
            warnings.warn(f"Could not read {p}: {e}", RuntimeWarning)

    pred_all = pd.concat(pred_dfs, ignore_index=True) if pred_dfs else pd.DataFrame()
    pred_all = drop_duplicate_prediction_rows(pred_all)

    pred_all.to_csv(
        OUTPUT_ROOT / "figures_data" / "all_video_predictions_for_calibration.csv",
        index=False,
    )

    if len(pred_all) > 0:
        cal_summary = (
            pred_all
            .groupby(["dataset", "model", "split"], dropna=False)
            .agg(
                n=("video_id", "count"),
                mean_y_true=("y_true", "mean"),
                mean_y_prob=("y_prob", "mean"),
                threshold_mean=("threshold", "mean"),
            )
            .reset_index()
        )
    else:
        cal_summary = pd.DataFrame()

    save_table(cal_summary, "table_calibration_prediction_summary.csv")
    print(cal_summary)


# ============================================================
# S10 — Interpretability
# ============================================================

if RUN_S10_INTERPRETABILITY:
    require_long_run("S10_INTERPRETABILITY")

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S10 Interpretability — {ds}")
        print("#" * 90)

        ckpt_path = find_best_checkpoint(
            ds,
            "MSTGNet",
            seed_whitelist=[43, 44, 45, 46, 47],
            repeat_whitelist=[1],
        )

        if ckpt_path is None:
            print(f"{ds}: no checkpoint with seed_whitelist=[43..47], trying repeat=1 only.")
            ckpt_path = find_best_checkpoint(
                ds,
                "MSTGNet",
                repeat_whitelist=[1],
            )

        if ckpt_path is None:
            print(f"{ds}: no checkpoint with repeat=1 filter, trying no filter.")
            ckpt_path = find_best_checkpoint(
                ds,
                "MSTGNet",
            )

        if ckpt_path is None:
            warnings.warn(f"No checkpoint found for interpretability: {ds}", RuntimeWarning)
            continue

        factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        ckpt = safe_torch_load_checkpoint_local(ckpt_path, map_location="cpu")
        split = ckpt.get("split", ckpt.get("source_split", {}))
        split_videos = split.get("val_videos", None)

        imp_df = mb.compute_gradient_importance_from_checkpoint(
            checkpoint_path=ckpt_path,
            model_factory=factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            device=DEVICE,
            feature_names=data_dict[ds].get("coord_cols_active", None),
            modality_slices=data_dict[ds].get("active_modality_slices", None),
            split_videos=split_videos,
            batch_size=int(CONFIG["batch_size"]),
            max_sequences=2048,
            seed=SEED,
        )

        if imp_df is None or len(imp_df) == 0:
            warnings.warn(
                f"Empty importance dataframe for {ds}: {ckpt_path}",
                RuntimeWarning,
            )
            continue

        suffix = (
            f"seed{imp_df['seed'].iloc[0]}"
            f"_rep{imp_df['repeat'].iloc[0]}"
            f"_fold{imp_df['fold'].iloc[0]}"
        )

        paths = mb.save_gradient_importance(
            imp_df,
            OUTPUT_ROOT,
            dataset_name=ds,
            model_name="MSTGNet",
            top_k=100,
            suffix=suffix,
        )

        print("Saved gradient importance:", paths)

        imp_df.to_csv(
            OUTPUT_ROOT / "interpretability" / f"{ds}_MSTGNet_gradient_importance_all.csv",
            index=False,
        )

        clean_memory()


# ============================================================
# S11 — Export paper tables
# ============================================================

if RUN_S11_EXPORT_PAPER_TABLES:
    if not (OUTPUT_ROOT / "tables" / "table_baseline_comparison.csv").exists():
        baseline_all = combine_fold_results(baseline_fold_result_files())
        baseline_all = drop_duplicate_fold_rows(baseline_all)
        summarize_results(baseline_all, output_name="table_baseline_comparison.csv")

    for table_name in [
        "table_baseline_comparison.csv",
        "table_modality_ablation.csv",
        "table_architecture_ablation.csv",
        "table_multiseed_robustness.csv",
        "table_cross_dataset.csv",
        "table_computational_cost.csv",
        "table_temporal_sensitivity.csv",
        "table_statistical_comparison.csv",
        "table_landmark_quality_prediction_correlation.csv",
        "table_repeat_level_ci.csv",
    ]:
        standardize_table_for_paper_if_exists(table_name)

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "dataset_summary.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table1_dataset_summary.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_baseline_comparison.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table2_baseline_comparison.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_modality_ablation.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table3_modality_ablation.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_architecture_ablation.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table4_architecture_ablation.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_multiseed_robustness.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table5_multiseed_robustness.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_cross_dataset.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table6_cross_dataset.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_landmark_quality.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table7_landmark_quality.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_computational_cost.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table8_computational_cost.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_temporal_sensitivity.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table9_temporal_sensitivity.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_statistical_comparison.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table10_statistical_comparison.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_landmark_quality_prediction_correlation.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table11_landmark_quality_prediction_correlation.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_repeat_level_ci.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table12_repeat_level_ci.csv",
    )

    paper_tables = sorted((OUTPUT_ROOT / "tables").glob("PAPER_Table*.csv"))

    paper_index = pd.DataFrame(
        {
            "paper_table": [p.name for p in paper_tables],
            "path": [str(p) for p in paper_tables],
            "exists": [p.exists() for p in paper_tables],
        }
    )

    paper_index.to_csv(
        OUTPUT_ROOT / "tables" / "PAPER_Table_index.csv",
        index=False,
    )

    print(paper_index)


# ============================================================
# Final checklist
# ============================================================

final_files = {
    "manifest": OUTPUT_ROOT / "config" / "experiment_manifest.json",
    "dataset_summary": OUTPUT_ROOT / "tables" / "dataset_summary.csv",
    "capacity_check_pre_S2": OUTPUT_ROOT / "compute_cost" / "capacity_check_pre_S2.csv",
    "main_I3D": OUTPUT_ROOT / "fold_results" / "main_I3D.csv",
    "main_RLT": OUTPUT_ROOT / "fold_results" / "main_RLT.csv",
    "full_ref_I3D": OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
    "full_ref_RLT": OUTPUT_ROOT / "fold_results" / "full_model_reference_RLT.csv",
    "baseline_table": OUTPUT_ROOT / "tables" / "table_baseline_comparison.csv",
    "arch_table": OUTPUT_ROOT / "tables" / "table_architecture_ablation.csv",
    "modal_table": OUTPUT_ROOT / "tables" / "table_modality_ablation.csv",
    "landmark_table": OUTPUT_ROOT / "tables" / "table_landmark_quality.csv",
    "landmark_prediction_corr": OUTPUT_ROOT / "tables" / "table_landmark_quality_prediction_correlation.csv",
    "cross_dataset_table": OUTPUT_ROOT / "tables" / "table_cross_dataset.csv",
    "compute_cost_table": OUTPUT_ROOT / "tables" / "table_computational_cost.csv",
    "temporal_sensitivity_table": OUTPUT_ROOT / "tables" / "table_temporal_sensitivity.csv",
    "multiseed_stats": OUTPUT_ROOT / "stats" / "statistical_tests.json",
    "statistical_comparison": OUTPUT_ROOT / "stats" / "statistical_comparison_all_models.csv",
    "repeat_level_ci_I3D": OUTPUT_ROOT / "stats" / "repeat_level_ci_I3D.csv",
    "repeat_level_ci_RLT": OUTPUT_ROOT / "stats" / "repeat_level_ci_RLT.csv",
    "repeat_level_ci_all": OUTPUT_ROOT / "stats" / "repeat_level_ci_all_datasets.csv",
    "repeat_level_ci_multiseed": OUTPUT_ROOT / "tables" / "repeat_level_ci_multiseed.csv",
    "repeat_level_ci_table": OUTPUT_ROOT / "tables" / "table_repeat_level_ci.csv",
    "paper_table_index": OUTPUT_ROOT / "tables" / "PAPER_Table_index.csv",
    "paper_table12_repeat_ci": OUTPUT_ROOT / "tables" / "PAPER_Table12_repeat_level_ci.csv",
    "interpretability_dir": OUTPUT_ROOT / "interpretability",
}

final_check = pd.DataFrame(
    {
        "item": list(final_files.keys()),
        "path": [str(p) for p in final_files.values()],
        "exists": [Path(p).exists() for p in final_files.values()],
    }
)

final_check.to_csv(
    OUTPUT_ROOT / "tables" / "final_file_checklist.csv",
    index=False,
)

print(final_check)
# Out:
# Using device: cuda
# OUTPUT_ROOT: outputs\revision_final_20260501
# DEVICE: cuda
# PASS: model_base API compatible with notebook
# Loading processed dataset: data\processed\mstgnet_I3D.pkl
# ✓ I3D loaded
#   Videos: 1568
#   Observed features: 1533
#   Active features:   1503
#   Active slices:     {'face': [0, 1374], 'eyes': [1374, 1404], 'body': [1404, 1503]}
# Loading processed dataset: data\processed\mstgnet_RLT.pkl
# ✓ RLT loaded
#   Videos: 121
#   Observed features: 1533
#   Active features:   1503
#   Active slices:     {'face': [0, 1374], 'eyes': [1374, 1404], 'body': [1404, 1503]}
# Saved table: outputs\revision_final_20260501\tables\dataset_summary.csv shape=(2, 9)
#   dataset  n_videos  n_class_0  n_class_1  n_observed_features  \
# 0     I3D      1568        784        784                 1533
# 1     RLT       121         60         61                 1533
#
#    n_active_features face_slice    eyes_slice    body_slice
# 0               1503  [0, 1374]  [1374, 1404]  [1404, 1503]
# 1               1503  [0, 1374]  [1374, 1404]  [1404, 1503]
# Loading existing splits: outputs\revision_final_20260501\config\splits\I3D_splits_main_seed42.json
# Loading existing splits: outputs\revision_final_20260501\config\splits\RLT_splits_main_seed42.json
# {'I3D': 5, 'RLT': 15} {'I3D': 5, 'RLT': 5}
# I3D
# status
# PASS    5
# Name: count, dtype: int64
# RLT
# status
# PASS    15
# Name: count, dtype: int64
# PASS: all main splits have no video-level overlap
#
# ##########################################################################################
# S2 — Deep Learning Baselines — I3D
# ##########################################################################################
# Prepared sequences:
#   X_seq: (23599, 50, 1503)
#   y_seq: (23599,)
#   video_seq_ids: (23599,)
#   unique videos: 1568
#   class balance seq: [13047 10552]
#
# ======================================================================
# Running LSTM | I3D | repeat=1 fold=1
# ======================================================================
# Fold setup: dataset=I3D, model=LSTM, repeat=1, fold=1, seed=43, n_params=358402
# Sequences: train=13465, val=5162, test=4972 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6907 | val_auc=0.4815 | best_val_auc=0.4815 | bad_epochs=0
#   epoch=002 | loss=0.6587 | val_auc=0.5038 | best_val_auc=0.5038 | bad_epochs=0
#   epoch=003 | loss=0.6243 | val_auc=0.5123 | best_val_auc=0.5123 | bad_epochs=0
#   epoch=004 | loss=0.5850 | val_auc=0.5347 | best_val_auc=0.5347 | bad_epochs=0
#   epoch=005 | loss=0.5567 | val_auc=0.5968 | best_val_auc=0.5968 | bad_epochs=0
#   epoch=008 | loss=0.4798 | val_auc=0.6371 | best_val_auc=0.6371 | bad_epochs=0
#   epoch=009 | loss=0.4597 | val_auc=0.6417 | best_val_auc=0.6417 | bad_epochs=0
#   epoch=010 | loss=0.4307 | val_auc=0.6614 | best_val_auc=0.6614 | bad_epochs=0
#   epoch=011 | loss=0.4196 | val_auc=0.6617 | best_val_auc=0.6617 | bad_epochs=0
#   epoch=013 | loss=0.3904 | val_auc=0.7071 | best_val_auc=0.7071 | bad_epochs=0
#   epoch=015 | loss=0.3606 | val_auc=0.6792 | best_val_auc=0.7071 | bad_epochs=2
#   epoch=018 | loss=0.3249 | val_auc=0.7183 | best_val_auc=0.7183 | bad_epochs=0
#   epoch=019 | loss=0.3129 | val_auc=0.7324 | best_val_auc=0.7324 | bad_epochs=0
#   epoch=020 | loss=0.3065 | val_auc=0.6949 | best_val_auc=0.7324 | bad_epochs=1
#   epoch=021 | loss=0.2898 | val_auc=0.7540 | best_val_auc=0.7540 | bad_epochs=0
#   epoch=024 | loss=0.2687 | val_auc=0.7580 | best_val_auc=0.7580 | bad_epochs=0
#   epoch=025 | loss=0.2580 | val_auc=0.7243 | best_val_auc=0.7580 | bad_epochs=1
#   epoch=030 | loss=0.2260 | val_auc=0.7596 | best_val_auc=0.7596 | bad_epochs=0
#   epoch=032 | loss=0.2073 | val_auc=0.7825 | best_val_auc=0.7825 | bad_epochs=0
#   epoch=035 | loss=0.1966 | val_auc=0.7675 | best_val_auc=0.7825 | bad_epochs=3
#   epoch=040 | loss=0.1785 | val_auc=0.7688 | best_val_auc=0.7825 | bad_epochs=8
#   epoch=041 | loss=0.1683 | val_auc=0.7841 | best_val_auc=0.7841 | bad_epochs=0
#   epoch=043 | loss=0.1669 | val_auc=0.7853 | best_val_auc=0.7853 | bad_epochs=0
#   epoch=044 | loss=0.1633 | val_auc=0.7961 | best_val_auc=0.7961 | bad_epochs=0
#   epoch=045 | loss=0.1603 | val_auc=0.7954 | best_val_auc=0.7961 | bad_epochs=1
#   epoch=047 | loss=0.1551 | val_auc=0.8002 | best_val_auc=0.8002 | bad_epochs=0
#   epoch=050 | loss=0.1485 | val_auc=0.8023 | best_val_auc=0.8023 | bad_epochs=0
#   epoch=055 | loss=0.1282 | val_auc=0.7961 | best_val_auc=0.8023 | bad_epochs=5
#   epoch=059 | loss=0.1269 | val_auc=0.8066 | best_val_auc=0.8066 | bad_epochs=0
#   epoch=060 | loss=0.1126 | val_auc=0.8214 | best_val_auc=0.8214 | bad_epochs=0
#   epoch=065 | loss=0.1094 | val_auc=0.8075 | best_val_auc=0.8214 | bad_epochs=5
#   epoch=070 | loss=0.1035 | val_auc=0.8009 | best_val_auc=0.8214 | bad_epochs=10
#   epoch=073 | loss=0.0952 | val_auc=0.8222 | best_val_auc=0.8222 | bad_epochs=0
#   epoch=075 | loss=0.1018 | val_auc=0.8095 | best_val_auc=0.8222 | bad_epochs=2
#   epoch=080 | loss=0.0811 | val_auc=0.8098 | best_val_auc=0.8222 | bad_epochs=7
#   epoch=085 | loss=0.0853 | val_auc=0.8051 | best_val_auc=0.8222 | bad_epochs=12
#   Early stopping at epoch=88. Best epoch=73, best val AUC=0.8222
#
# ======================================================================
# Running LSTM | I3D | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=I3D, model=LSTM, repeat=1, fold=2, seed=44, n_params=358402
# Sequences: train=13663, val=5336, test=4600 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6779 | val_auc=0.5206 | best_val_auc=0.5206 | bad_epochs=0
#   epoch=002 | loss=0.6396 | val_auc=0.5320 | best_val_auc=0.5320 | bad_epochs=0
#   epoch=003 | loss=0.5940 | val_auc=0.5510 | best_val_auc=0.5510 | bad_epochs=0
#   epoch=004 | loss=0.5536 | val_auc=0.5705 | best_val_auc=0.5705 | bad_epochs=0
#   epoch=005 | loss=0.5166 | val_auc=0.5784 | best_val_auc=0.5784 | bad_epochs=0
#   epoch=006 | loss=0.4864 | val_auc=0.5885 | best_val_auc=0.5885 | bad_epochs=0
#   epoch=007 | loss=0.4619 | val_auc=0.6073 | best_val_auc=0.6073 | bad_epochs=0
#   epoch=008 | loss=0.4381 | val_auc=0.6277 | best_val_auc=0.6277 | bad_epochs=0
#   epoch=009 | loss=0.4211 | val_auc=0.6512 | best_val_auc=0.6512 | bad_epochs=0
#   epoch=010 | loss=0.3983 | val_auc=0.6756 | best_val_auc=0.6756 | bad_epochs=0
#   epoch=011 | loss=0.3820 | val_auc=0.6778 | best_val_auc=0.6778 | bad_epochs=0
#   epoch=014 | loss=0.3432 | val_auc=0.6970 | best_val_auc=0.6970 | bad_epochs=0
#   epoch=015 | loss=0.3238 | val_auc=0.6975 | best_val_auc=0.6975 | bad_epochs=0
#   epoch=016 | loss=0.3143 | val_auc=0.7037 | best_val_auc=0.7037 | bad_epochs=0
#   epoch=019 | loss=0.2833 | val_auc=0.7056 | best_val_auc=0.7056 | bad_epochs=0
#   epoch=020 | loss=0.2675 | val_auc=0.6830 | best_val_auc=0.7056 | bad_epochs=1
#   epoch=022 | loss=0.2565 | val_auc=0.7239 | best_val_auc=0.7239 | bad_epochs=0
#   epoch=025 | loss=0.2325 | val_auc=0.7185 | best_val_auc=0.7239 | bad_epochs=3
#   epoch=026 | loss=0.2287 | val_auc=0.7437 | best_val_auc=0.7437 | bad_epochs=0
#   epoch=027 | loss=0.2182 | val_auc=0.7498 | best_val_auc=0.7498 | bad_epochs=0
#   epoch=030 | loss=0.2043 | val_auc=0.7252 | best_val_auc=0.7498 | bad_epochs=3
#   epoch=031 | loss=0.1990 | val_auc=0.7575 | best_val_auc=0.7575 | bad_epochs=0
#   epoch=035 | loss=0.1764 | val_auc=0.7394 | best_val_auc=0.7575 | bad_epochs=4
#   epoch=037 | loss=0.1709 | val_auc=0.7585 | best_val_auc=0.7585 | bad_epochs=0
#   epoch=039 | loss=0.1629 | val_auc=0.7604 | best_val_auc=0.7604 | bad_epochs=0
#   epoch=040 | loss=0.1573 | val_auc=0.7649 | best_val_auc=0.7649 | bad_epochs=0
#   epoch=041 | loss=0.1492 | val_auc=0.7740 | best_val_auc=0.7740 | bad_epochs=0
#   epoch=045 | loss=0.1394 | val_auc=0.7655 | best_val_auc=0.7740 | bad_epochs=4
#   epoch=048 | loss=0.1297 | val_auc=0.7745 | best_val_auc=0.7745 | bad_epochs=0
#   epoch=050 | loss=0.1254 | val_auc=0.7755 | best_val_auc=0.7755 | bad_epochs=0
#   epoch=052 | loss=0.1135 | val_auc=0.7798 | best_val_auc=0.7798 | bad_epochs=0
#   epoch=053 | loss=0.1192 | val_auc=0.8002 | best_val_auc=0.8002 | bad_epochs=0
#   epoch=055 | loss=0.1166 | val_auc=0.7618 | best_val_auc=0.8002 | bad_epochs=2
#   epoch=060 | loss=0.1005 | val_auc=0.7953 | best_val_auc=0.8002 | bad_epochs=7
#   epoch=065 | loss=0.0994 | val_auc=0.8018 | best_val_auc=0.8018 | bad_epochs=0
#   epoch=070 | loss=0.0872 | val_auc=0.7681 | best_val_auc=0.8018 | bad_epochs=5
#   epoch=075 | loss=0.0825 | val_auc=0.7912 | best_val_auc=0.8018 | bad_epochs=10
#   epoch=080 | loss=0.0812 | val_auc=0.7656 | best_val_auc=0.8018 | bad_epochs=15
#   Early stopping at epoch=80. Best epoch=65, best val AUC=0.8018
#
# ======================================================================
# Running LSTM | I3D | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=I3D, model=LSTM, repeat=1, fold=3, seed=45, n_params=358402
# Sequences: train=13760, val=5234, test=4605 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6837 | val_auc=0.4821 | best_val_auc=0.4821 | bad_epochs=0
#   epoch=002 | loss=0.6406 | val_auc=0.4978 | best_val_auc=0.4978 | bad_epochs=0
#   epoch=003 | loss=0.5909 | val_auc=0.5109 | best_val_auc=0.5109 | bad_epochs=0
#   epoch=004 | loss=0.5527 | val_auc=0.5449 | best_val_auc=0.5449 | bad_epochs=0
#   epoch=005 | loss=0.5227 | val_auc=0.5576 | best_val_auc=0.5576 | bad_epochs=0
#   epoch=006 | loss=0.4897 | val_auc=0.5817 | best_val_auc=0.5817 | bad_epochs=0
#   epoch=007 | loss=0.4661 | val_auc=0.6169 | best_val_auc=0.6169 | bad_epochs=0
#   epoch=010 | loss=0.4070 | val_auc=0.6086 | best_val_auc=0.6169 | bad_epochs=3
#   epoch=011 | loss=0.3808 | val_auc=0.6445 | best_val_auc=0.6445 | bad_epochs=0
#   epoch=015 | loss=0.3223 | val_auc=0.6647 | best_val_auc=0.6647 | bad_epochs=0
#   epoch=016 | loss=0.3146 | val_auc=0.6669 | best_val_auc=0.6669 | bad_epochs=0
#   epoch=018 | loss=0.2926 | val_auc=0.7023 | best_val_auc=0.7023 | bad_epochs=0
#   epoch=020 | loss=0.2765 | val_auc=0.6833 | best_val_auc=0.7023 | bad_epochs=2
#   epoch=021 | loss=0.2643 | val_auc=0.7073 | best_val_auc=0.7073 | bad_epochs=0
#   epoch=022 | loss=0.2638 | val_auc=0.7132 | best_val_auc=0.7132 | bad_epochs=0
#   epoch=025 | loss=0.2393 | val_auc=0.7139 | best_val_auc=0.7139 | bad_epochs=0
#   epoch=026 | loss=0.2291 | val_auc=0.7202 | best_val_auc=0.7202 | bad_epochs=0
#   epoch=030 | loss=0.1973 | val_auc=0.7112 | best_val_auc=0.7202 | bad_epochs=4
#   epoch=031 | loss=0.2005 | val_auc=0.7240 | best_val_auc=0.7240 | bad_epochs=0
#   epoch=034 | loss=0.1827 | val_auc=0.7295 | best_val_auc=0.7295 | bad_epochs=0
#   epoch=035 | loss=0.1802 | val_auc=0.7356 | best_val_auc=0.7356 | bad_epochs=0
#   epoch=038 | loss=0.1685 | val_auc=0.7400 | best_val_auc=0.7400 | bad_epochs=0
#   epoch=040 | loss=0.1586 | val_auc=0.7216 | best_val_auc=0.7400 | bad_epochs=2
#   epoch=041 | loss=0.1513 | val_auc=0.7498 | best_val_auc=0.7498 | bad_epochs=0
#   epoch=043 | loss=0.1434 | val_auc=0.7562 | best_val_auc=0.7562 | bad_epochs=0
#   epoch=045 | loss=0.1351 | val_auc=0.7514 | best_val_auc=0.7562 | bad_epochs=2
#   epoch=046 | loss=0.1259 | val_auc=0.7609 | best_val_auc=0.7609 | bad_epochs=0
#   epoch=050 | loss=0.1177 | val_auc=0.7483 | best_val_auc=0.7609 | bad_epochs=4
#   epoch=055 | loss=0.1160 | val_auc=0.7556 | best_val_auc=0.7609 | bad_epochs=9
#   epoch=058 | loss=0.1101 | val_auc=0.7638 | best_val_auc=0.7638 | bad_epochs=0
#   epoch=059 | loss=0.1060 | val_auc=0.7655 | best_val_auc=0.7655 | bad_epochs=0
#   epoch=060 | loss=0.1063 | val_auc=0.7518 | best_val_auc=0.7655 | bad_epochs=1
#   epoch=062 | loss=0.0975 | val_auc=0.7803 | best_val_auc=0.7803 | bad_epochs=0
#   epoch=065 | loss=0.0964 | val_auc=0.7535 | best_val_auc=0.7803 | bad_epochs=3
#   epoch=070 | loss=0.0882 | val_auc=0.7681 | best_val_auc=0.7803 | bad_epochs=8
#   epoch=075 | loss=0.0797 | val_auc=0.7675 | best_val_auc=0.7803 | bad_epochs=13
#   Early stopping at epoch=77. Best epoch=62, best val AUC=0.7803
#
# ======================================================================
# Running LSTM | I3D | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=I3D, model=LSTM, repeat=1, fold=4, seed=46, n_params=358402
# Sequences: train=13818, val=5141, test=4640 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6810 | val_auc=0.4672 | best_val_auc=0.4672 | bad_epochs=0
#   epoch=003 | loss=0.6070 | val_auc=0.5238 | best_val_auc=0.5238 | bad_epochs=0
#   epoch=005 | loss=0.5389 | val_auc=0.6009 | best_val_auc=0.6009 | bad_epochs=0
#   epoch=006 | loss=0.5092 | val_auc=0.6252 | best_val_auc=0.6252 | bad_epochs=0
#   epoch=008 | loss=0.4549 | val_auc=0.6860 | best_val_auc=0.6860 | bad_epochs=0
#   epoch=010 | loss=0.4111 | val_auc=0.6646 | best_val_auc=0.6860 | bad_epochs=2
#   epoch=012 | loss=0.3826 | val_auc=0.7104 | best_val_auc=0.7104 | bad_epochs=0
#   epoch=013 | loss=0.3612 | val_auc=0.7218 | best_val_auc=0.7218 | bad_epochs=0
#   epoch=014 | loss=0.3448 | val_auc=0.7361 | best_val_auc=0.7361 | bad_epochs=0
#   epoch=015 | loss=0.3398 | val_auc=0.7025 | best_val_auc=0.7361 | bad_epochs=1
#   epoch=017 | loss=0.3143 | val_auc=0.7394 | best_val_auc=0.7394 | bad_epochs=0
#   epoch=019 | loss=0.2956 | val_auc=0.7414 | best_val_auc=0.7414 | bad_epochs=0
#   epoch=020 | loss=0.2849 | val_auc=0.7519 | best_val_auc=0.7519 | bad_epochs=0
#   epoch=022 | loss=0.2682 | val_auc=0.7634 | best_val_auc=0.7634 | bad_epochs=0
#   epoch=023 | loss=0.2622 | val_auc=0.7666 | best_val_auc=0.7666 | bad_epochs=0
#   epoch=024 | loss=0.2561 | val_auc=0.7808 | best_val_auc=0.7808 | bad_epochs=0
#   epoch=025 | loss=0.2461 | val_auc=0.7761 | best_val_auc=0.7808 | bad_epochs=1
#   epoch=030 | loss=0.2181 | val_auc=0.7865 | best_val_auc=0.7865 | bad_epochs=0
#   epoch=032 | loss=0.2115 | val_auc=0.7875 | best_val_auc=0.7875 | bad_epochs=0
#   epoch=033 | loss=0.2043 | val_auc=0.8037 | best_val_auc=0.8037 | bad_epochs=0
#   epoch=034 | loss=0.1977 | val_auc=0.8089 | best_val_auc=0.8089 | bad_epochs=0
#   epoch=035 | loss=0.1936 | val_auc=0.7818 | best_val_auc=0.8089 | bad_epochs=1
#   epoch=040 | loss=0.1725 | val_auc=0.7824 | best_val_auc=0.8089 | bad_epochs=6
#   epoch=041 | loss=0.1663 | val_auc=0.8163 | best_val_auc=0.8163 | bad_epochs=0
#   epoch=042 | loss=0.1608 | val_auc=0.8190 | best_val_auc=0.8190 | bad_epochs=0
#   epoch=045 | loss=0.1600 | val_auc=0.8081 | best_val_auc=0.8190 | bad_epochs=3
#   epoch=047 | loss=0.1524 | val_auc=0.8223 | best_val_auc=0.8223 | bad_epochs=0
#   epoch=050 | loss=0.1439 | val_auc=0.7950 | best_val_auc=0.8223 | bad_epochs=3
#   epoch=053 | loss=0.1283 | val_auc=0.8238 | best_val_auc=0.8238 | bad_epochs=0
#   epoch=054 | loss=0.1366 | val_auc=0.8239 | best_val_auc=0.8239 | bad_epochs=0
#   epoch=055 | loss=0.1250 | val_auc=0.8304 | best_val_auc=0.8304 | bad_epochs=0
#   epoch=056 | loss=0.1280 | val_auc=0.8393 | best_val_auc=0.8393 | bad_epochs=0
#   epoch=060 | loss=0.1154 | val_auc=0.8283 | best_val_auc=0.8393 | bad_epochs=4
#   epoch=064 | loss=0.1098 | val_auc=0.8457 | best_val_auc=0.8457 | bad_epochs=0
#   epoch=065 | loss=0.1172 | val_auc=0.8333 | best_val_auc=0.8457 | bad_epochs=1
#   epoch=070 | loss=0.0957 | val_auc=0.8263 | best_val_auc=0.8457 | bad_epochs=6
#   epoch=075 | loss=0.0934 | val_auc=0.8259 | best_val_auc=0.8457 | bad_epochs=11
#   Early stopping at epoch=79. Best epoch=64, best val AUC=0.8457
#
# ======================================================================
# Running LSTM | I3D | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=I3D, model=LSTM, repeat=1, fold=5, seed=47, n_params=358402
# Sequences: train=13595, val=5222, test=4782 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6816 | val_auc=0.5400 | best_val_auc=0.5400 | bad_epochs=0
#   epoch=002 | loss=0.6398 | val_auc=0.5449 | best_val_auc=0.5449 | bad_epochs=0
#   epoch=003 | loss=0.5951 | val_auc=0.5736 | best_val_auc=0.5736 | bad_epochs=0
#   epoch=005 | loss=0.5168 | val_auc=0.5784 | best_val_auc=0.5784 | bad_epochs=0
#   epoch=008 | loss=0.4512 | val_auc=0.6045 | best_val_auc=0.6045 | bad_epochs=0
#   epoch=010 | loss=0.4077 | val_auc=0.6165 | best_val_auc=0.6165 | bad_epochs=0
#   epoch=011 | loss=0.3960 | val_auc=0.6353 | best_val_auc=0.6353 | bad_epochs=0
#   epoch=012 | loss=0.3803 | val_auc=0.6380 | best_val_auc=0.6380 | bad_epochs=0
#   epoch=013 | loss=0.3679 | val_auc=0.6530 | best_val_auc=0.6530 | bad_epochs=0
#   epoch=014 | loss=0.3555 | val_auc=0.6580 | best_val_auc=0.6580 | bad_epochs=0
#   epoch=015 | loss=0.3409 | val_auc=0.6689 | best_val_auc=0.6689 | bad_epochs=0
#   epoch=016 | loss=0.3277 | val_auc=0.6809 | best_val_auc=0.6809 | bad_epochs=0
#   epoch=017 | loss=0.3241 | val_auc=0.7018 | best_val_auc=0.7018 | bad_epochs=0
#   epoch=020 | loss=0.2853 | val_auc=0.6981 | best_val_auc=0.7018 | bad_epochs=3
#   epoch=022 | loss=0.2717 | val_auc=0.7070 | best_val_auc=0.7070 | bad_epochs=0
#   epoch=025 | loss=0.2505 | val_auc=0.7163 | best_val_auc=0.7163 | bad_epochs=0
#   epoch=026 | loss=0.2424 | val_auc=0.7255 | best_val_auc=0.7255 | bad_epochs=0
#   epoch=030 | loss=0.2159 | val_auc=0.7228 | best_val_auc=0.7255 | bad_epochs=4
#   epoch=032 | loss=0.2066 | val_auc=0.7297 | best_val_auc=0.7297 | bad_epochs=0
#   epoch=034 | loss=0.2029 | val_auc=0.7316 | best_val_auc=0.7316 | bad_epochs=0
#   epoch=035 | loss=0.1942 | val_auc=0.7269 | best_val_auc=0.7316 | bad_epochs=1
#   epoch=036 | loss=0.1904 | val_auc=0.7496 | best_val_auc=0.7496 | bad_epochs=0
#   epoch=040 | loss=0.1677 | val_auc=0.7372 | best_val_auc=0.7496 | bad_epochs=4
#   epoch=045 | loss=0.1507 | val_auc=0.7346 | best_val_auc=0.7496 | bad_epochs=9
#   epoch=048 | loss=0.1473 | val_auc=0.7578 | best_val_auc=0.7578 | bad_epochs=0
#   epoch=050 | loss=0.1372 | val_auc=0.7483 | best_val_auc=0.7578 | bad_epochs=2
#   epoch=055 | loss=0.1345 | val_auc=0.7584 | best_val_auc=0.7584 | bad_epochs=0
#   epoch=060 | loss=0.1167 | val_auc=0.7618 | best_val_auc=0.7618 | bad_epochs=0
#   epoch=065 | loss=0.1063 | val_auc=0.7625 | best_val_auc=0.7625 | bad_epochs=0
#   epoch=067 | loss=0.1075 | val_auc=0.7634 | best_val_auc=0.7634 | bad_epochs=0
#   epoch=070 | loss=0.1062 | val_auc=0.7606 | best_val_auc=0.7634 | bad_epochs=3
#   epoch=072 | loss=0.0934 | val_auc=0.7780 | best_val_auc=0.7780 | bad_epochs=0
#   epoch=075 | loss=0.0964 | val_auc=0.7538 | best_val_auc=0.7780 | bad_epochs=3
#   epoch=080 | loss=0.0863 | val_auc=0.7704 | best_val_auc=0.7780 | bad_epochs=8
#   epoch=085 | loss=0.0825 | val_auc=0.7538 | best_val_auc=0.7780 | bad_epochs=13
#   Early stopping at epoch=87. Best epoch=72, best val AUC=0.7780
#
# ======================================================================
# Running BiLSTM | I3D | repeat=1 fold=1
# ======================================================================
# Fold setup: dataset=I3D, model=BiLSTM, repeat=1, fold=1, seed=43, n_params=531586
# Sequences: train=13465, val=5162, test=4972 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6905 | val_auc=0.4795 | best_val_auc=0.4795 | bad_epochs=0
#   epoch=002 | loss=0.6552 | val_auc=0.4922 | best_val_auc=0.4922 | bad_epochs=0
#   epoch=003 | loss=0.6231 | val_auc=0.5207 | best_val_auc=0.5207 | bad_epochs=0
#   epoch=004 | loss=0.5847 | val_auc=0.5523 | best_val_auc=0.5523 | bad_epochs=0
#   epoch=005 | loss=0.5471 | val_auc=0.5973 | best_val_auc=0.5973 | bad_epochs=0
#   epoch=007 | loss=0.4931 | val_auc=0.6166 | best_val_auc=0.6166 | bad_epochs=0
#   epoch=008 | loss=0.4720 | val_auc=0.6219 | best_val_auc=0.6219 | bad_epochs=0
#   epoch=009 | loss=0.4443 | val_auc=0.6474 | best_val_auc=0.6474 | bad_epochs=0
#   epoch=010 | loss=0.4256 | val_auc=0.6346 | best_val_auc=0.6474 | bad_epochs=1
#   epoch=011 | loss=0.4073 | val_auc=0.6844 | best_val_auc=0.6844 | bad_epochs=0
#   epoch=015 | loss=0.3442 | val_auc=0.7035 | best_val_auc=0.7035 | bad_epochs=0
#   epoch=018 | loss=0.3186 | val_auc=0.7304 | best_val_auc=0.7304 | bad_epochs=0
#   epoch=019 | loss=0.2978 | val_auc=0.7338 | best_val_auc=0.7338 | bad_epochs=0
#   epoch=020 | loss=0.2936 | val_auc=0.6876 | best_val_auc=0.7338 | bad_epochs=1
#   epoch=025 | loss=0.2515 | val_auc=0.7357 | best_val_auc=0.7357 | bad_epochs=0
#   epoch=026 | loss=0.2396 | val_auc=0.7454 | best_val_auc=0.7454 | bad_epochs=0
#   epoch=028 | loss=0.2267 | val_auc=0.7589 | best_val_auc=0.7589 | bad_epochs=0
#   epoch=029 | loss=0.2222 | val_auc=0.7590 | best_val_auc=0.7590 | bad_epochs=0
#   epoch=030 | loss=0.2100 | val_auc=0.7573 | best_val_auc=0.7590 | bad_epochs=1
#   epoch=032 | loss=0.2003 | val_auc=0.7640 | best_val_auc=0.7640 | bad_epochs=0
#   epoch=033 | loss=0.1964 | val_auc=0.7680 | best_val_auc=0.7680 | bad_epochs=0
#   epoch=035 | loss=0.1864 | val_auc=0.7698 | best_val_auc=0.7698 | bad_epochs=0
#   epoch=036 | loss=0.1828 | val_auc=0.7774 | best_val_auc=0.7774 | bad_epochs=0
#   epoch=037 | loss=0.1728 | val_auc=0.7853 | best_val_auc=0.7853 | bad_epochs=0
#   epoch=040 | loss=0.1580 | val_auc=0.7679 | best_val_auc=0.7853 | bad_epochs=3
#   epoch=043 | loss=0.1511 | val_auc=0.7927 | best_val_auc=0.7927 | bad_epochs=0
#   epoch=045 | loss=0.1419 | val_auc=0.7892 | best_val_auc=0.7927 | bad_epochs=2
#   epoch=047 | loss=0.1337 | val_auc=0.8042 | best_val_auc=0.8042 | bad_epochs=0
#   epoch=050 | loss=0.1354 | val_auc=0.8101 | best_val_auc=0.8101 | bad_epochs=0
#   epoch=055 | loss=0.1146 | val_auc=0.8056 | best_val_auc=0.8101 | bad_epochs=5
#   epoch=056 | loss=0.1106 | val_auc=0.8212 | best_val_auc=0.8212 | bad_epochs=0
#   epoch=060 | loss=0.1062 | val_auc=0.7965 | best_val_auc=0.8212 | bad_epochs=4
#   epoch=065 | loss=0.0919 | val_auc=0.8016 | best_val_auc=0.8212 | bad_epochs=9
#   epoch=070 | loss=0.0871 | val_auc=0.7946 | best_val_auc=0.8212 | bad_epochs=14
#   Early stopping at epoch=71. Best epoch=56, best val AUC=0.8212
#
# ======================================================================
# Running BiLSTM | I3D | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=I3D, model=BiLSTM, repeat=1, fold=2, seed=44, n_params=531586
# Sequences: train=13663, val=5336, test=4600 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6774 | val_auc=0.5129 | best_val_auc=0.5129 | bad_epochs=0
#   epoch=002 | loss=0.6349 | val_auc=0.5242 | best_val_auc=0.5242 | bad_epochs=0
#   epoch=003 | loss=0.5908 | val_auc=0.5297 | best_val_auc=0.5297 | bad_epochs=0
#   epoch=004 | loss=0.5540 | val_auc=0.5570 | best_val_auc=0.5570 | bad_epochs=0
#   epoch=005 | loss=0.5159 | val_auc=0.6054 | best_val_auc=0.6054 | bad_epochs=0
#   epoch=006 | loss=0.4919 | val_auc=0.6246 | best_val_auc=0.6246 | bad_epochs=0
#   epoch=007 | loss=0.4600 | val_auc=0.6288 | best_val_auc=0.6288 | bad_epochs=0
#   epoch=008 | loss=0.4410 | val_auc=0.6377 | best_val_auc=0.6377 | bad_epochs=0
#   epoch=010 | loss=0.3974 | val_auc=0.6885 | best_val_auc=0.6885 | bad_epochs=0
#   epoch=014 | loss=0.3295 | val_auc=0.6938 | best_val_auc=0.6938 | bad_epochs=0
#   epoch=015 | loss=0.3178 | val_auc=0.6893 | best_val_auc=0.6938 | bad_epochs=1
#   epoch=019 | loss=0.2777 | val_auc=0.6951 | best_val_auc=0.6951 | bad_epochs=0
#   epoch=020 | loss=0.2646 | val_auc=0.7325 | best_val_auc=0.7325 | bad_epochs=0
#   epoch=022 | loss=0.2495 | val_auc=0.7388 | best_val_auc=0.7388 | bad_epochs=0
#   epoch=025 | loss=0.2272 | val_auc=0.6994 | best_val_auc=0.7388 | bad_epochs=3
#   epoch=028 | loss=0.2053 | val_auc=0.7430 | best_val_auc=0.7430 | bad_epochs=0
#   epoch=030 | loss=0.1863 | val_auc=0.7170 | best_val_auc=0.7430 | bad_epochs=2
#   epoch=034 | loss=0.1690 | val_auc=0.7669 | best_val_auc=0.7669 | bad_epochs=0
#   epoch=035 | loss=0.1658 | val_auc=0.7546 | best_val_auc=0.7669 | bad_epochs=1
#   epoch=039 | loss=0.1483 | val_auc=0.7697 | best_val_auc=0.7697 | bad_epochs=0
#   epoch=040 | loss=0.1501 | val_auc=0.7721 | best_val_auc=0.7721 | bad_epochs=0
#   epoch=041 | loss=0.1376 | val_auc=0.7796 | best_val_auc=0.7796 | bad_epochs=0
#   epoch=045 | loss=0.1359 | val_auc=0.7542 | best_val_auc=0.7796 | bad_epochs=4
#   epoch=050 | loss=0.1184 | val_auc=0.7622 | best_val_auc=0.7796 | bad_epochs=9
#   epoch=055 | loss=0.1002 | val_auc=0.7812 | best_val_auc=0.7812 | bad_epochs=0
#   epoch=058 | loss=0.0961 | val_auc=0.7906 | best_val_auc=0.7906 | bad_epochs=0
#   epoch=060 | loss=0.0864 | val_auc=0.7740 | best_val_auc=0.7906 | bad_epochs=2
#   epoch=061 | loss=0.0940 | val_auc=0.7963 | best_val_auc=0.7963 | bad_epochs=0
#   epoch=065 | loss=0.0813 | val_auc=0.7722 | best_val_auc=0.7963 | bad_epochs=4
#   epoch=069 | loss=0.0797 | val_auc=0.8033 | best_val_auc=0.8033 | bad_epochs=0
#   epoch=070 | loss=0.0770 | val_auc=0.7803 | best_val_auc=0.8033 | bad_epochs=1
#   epoch=075 | loss=0.0702 | val_auc=0.7752 | best_val_auc=0.8033 | bad_epochs=6
#   epoch=080 | loss=0.0709 | val_auc=0.7955 | best_val_auc=0.8033 | bad_epochs=11
#   Early stopping at epoch=84. Best epoch=69, best val AUC=0.8033
#
# ======================================================================
# Running BiLSTM | I3D | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=I3D, model=BiLSTM, repeat=1, fold=3, seed=45, n_params=531586
# Sequences: train=13760, val=5234, test=4605 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6826 | val_auc=0.4908 | best_val_auc=0.4908 | bad_epochs=0
#   epoch=002 | loss=0.6321 | val_auc=0.5268 | best_val_auc=0.5268 | bad_epochs=0
#   epoch=003 | loss=0.5820 | val_auc=0.5342 | best_val_auc=0.5342 | bad_epochs=0
#   epoch=004 | loss=0.5453 | val_auc=0.5501 | best_val_auc=0.5501 | bad_epochs=0
#   epoch=005 | loss=0.5146 | val_auc=0.5410 | best_val_auc=0.5501 | bad_epochs=1
#   epoch=006 | loss=0.4877 | val_auc=0.5781 | best_val_auc=0.5781 | bad_epochs=0
#   epoch=007 | loss=0.4578 | val_auc=0.6049 | best_val_auc=0.6049 | bad_epochs=0
#   epoch=009 | loss=0.4203 | val_auc=0.6112 | best_val_auc=0.6112 | bad_epochs=0
#   epoch=010 | loss=0.3999 | val_auc=0.6111 | best_val_auc=0.6112 | bad_epochs=1
#   epoch=011 | loss=0.3845 | val_auc=0.6453 | best_val_auc=0.6453 | bad_epochs=0
#   epoch=015 | loss=0.3243 | val_auc=0.6299 | best_val_auc=0.6453 | bad_epochs=4
#   epoch=016 | loss=0.3141 | val_auc=0.6490 | best_val_auc=0.6490 | bad_epochs=0
#   epoch=018 | loss=0.2901 | val_auc=0.6645 | best_val_auc=0.6645 | bad_epochs=0
#   epoch=019 | loss=0.2804 | val_auc=0.6646 | best_val_auc=0.6646 | bad_epochs=0
#   epoch=020 | loss=0.2668 | val_auc=0.6570 | best_val_auc=0.6646 | bad_epochs=1
#   epoch=021 | loss=0.2652 | val_auc=0.6774 | best_val_auc=0.6774 | bad_epochs=0
#   epoch=025 | loss=0.2256 | val_auc=0.7201 | best_val_auc=0.7201 | bad_epochs=0
#   epoch=030 | loss=0.2010 | val_auc=0.6987 | best_val_auc=0.7201 | bad_epochs=5
#   epoch=035 | loss=0.1678 | val_auc=0.7123 | best_val_auc=0.7201 | bad_epochs=10
#   epoch=040 | loss=0.1456 | val_auc=0.7133 | best_val_auc=0.7201 | bad_epochs=15
#   Early stopping at epoch=40. Best epoch=25, best val AUC=0.7201
#
# ======================================================================
# Running BiLSTM | I3D | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=I3D, model=BiLSTM, repeat=1, fold=4, seed=46, n_params=531586
# Sequences: train=13818, val=5141, test=4640 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6771 | val_auc=0.4715 | best_val_auc=0.4715 | bad_epochs=0
#   epoch=002 | loss=0.6399 | val_auc=0.4909 | best_val_auc=0.4909 | bad_epochs=0
#   epoch=003 | loss=0.6048 | val_auc=0.5180 | best_val_auc=0.5180 | bad_epochs=0
#   epoch=004 | loss=0.5695 | val_auc=0.5319 | best_val_auc=0.5319 | bad_epochs=0
#   epoch=005 | loss=0.5322 | val_auc=0.6043 | best_val_auc=0.6043 | bad_epochs=0
#   epoch=006 | loss=0.5048 | val_auc=0.6147 | best_val_auc=0.6147 | bad_epochs=0
#   epoch=007 | loss=0.4761 | val_auc=0.6414 | best_val_auc=0.6414 | bad_epochs=0
#   epoch=008 | loss=0.4513 | val_auc=0.6845 | best_val_auc=0.6845 | bad_epochs=0
#   epoch=010 | loss=0.4040 | val_auc=0.6899 | best_val_auc=0.6899 | bad_epochs=0
#   epoch=012 | loss=0.3675 | val_auc=0.7016 | best_val_auc=0.7016 | bad_epochs=0
#   epoch=013 | loss=0.3519 | val_auc=0.7095 | best_val_auc=0.7095 | bad_epochs=0
#   epoch=014 | loss=0.3390 | val_auc=0.7539 | best_val_auc=0.7539 | bad_epochs=0
#   epoch=015 | loss=0.3295 | val_auc=0.7208 | best_val_auc=0.7539 | bad_epochs=1
#   epoch=016 | loss=0.3166 | val_auc=0.7571 | best_val_auc=0.7571 | bad_epochs=0
#   epoch=018 | loss=0.2927 | val_auc=0.7695 | best_val_auc=0.7695 | bad_epochs=0
#   epoch=020 | loss=0.2730 | val_auc=0.7930 | best_val_auc=0.7930 | bad_epochs=0
#   epoch=024 | loss=0.2446 | val_auc=0.7935 | best_val_auc=0.7935 | bad_epochs=0
#   epoch=025 | loss=0.2335 | val_auc=0.7914 | best_val_auc=0.7935 | bad_epochs=1
#   epoch=028 | loss=0.2094 | val_auc=0.7953 | best_val_auc=0.7953 | bad_epochs=0
#   epoch=029 | loss=0.2169 | val_auc=0.8150 | best_val_auc=0.8150 | bad_epochs=0
#   epoch=030 | loss=0.2046 | val_auc=0.8105 | best_val_auc=0.8150 | bad_epochs=1
#   epoch=034 | loss=0.1900 | val_auc=0.8169 | best_val_auc=0.8169 | bad_epochs=0
#   epoch=035 | loss=0.1699 | val_auc=0.8199 | best_val_auc=0.8199 | bad_epochs=0
#   epoch=037 | loss=0.1711 | val_auc=0.8250 | best_val_auc=0.8250 | bad_epochs=0
#   epoch=040 | loss=0.1566 | val_auc=0.8110 | best_val_auc=0.8250 | bad_epochs=3
#   epoch=043 | loss=0.1458 | val_auc=0.8270 | best_val_auc=0.8270 | bad_epochs=0
#   epoch=045 | loss=0.1364 | val_auc=0.8217 | best_val_auc=0.8270 | bad_epochs=2
#   epoch=050 | loss=0.1249 | val_auc=0.7994 | best_val_auc=0.8270 | bad_epochs=7
#   epoch=052 | loss=0.1225 | val_auc=0.8294 | best_val_auc=0.8294 | bad_epochs=0
#   epoch=053 | loss=0.1204 | val_auc=0.8407 | best_val_auc=0.8407 | bad_epochs=0
#   epoch=055 | loss=0.1100 | val_auc=0.8220 | best_val_auc=0.8407 | bad_epochs=2
#   epoch=060 | loss=0.1043 | val_auc=0.8396 | best_val_auc=0.8407 | bad_epochs=7
#   epoch=065 | loss=0.0968 | val_auc=0.8279 | best_val_auc=0.8407 | bad_epochs=12
#   Early stopping at epoch=68. Best epoch=53, best val AUC=0.8407
#
# ======================================================================
# Running BiLSTM | I3D | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=I3D, model=BiLSTM, repeat=1, fold=5, seed=47, n_params=531586
# Sequences: train=13595, val=5222, test=4782 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6778 | val_auc=0.5365 | best_val_auc=0.5365 | bad_epochs=0
#   epoch=002 | loss=0.6363 | val_auc=0.5397 | best_val_auc=0.5397 | bad_epochs=0
#   epoch=003 | loss=0.5898 | val_auc=0.5870 | best_val_auc=0.5870 | bad_epochs=0
#   epoch=005 | loss=0.5140 | val_auc=0.5966 | best_val_auc=0.5966 | bad_epochs=0
#   epoch=007 | loss=0.4623 | val_auc=0.5983 | best_val_auc=0.5983 | bad_epochs=0
#   epoch=008 | loss=0.4427 | val_auc=0.6225 | best_val_auc=0.6225 | bad_epochs=0
#   epoch=010 | loss=0.4036 | val_auc=0.6526 | best_val_auc=0.6526 | bad_epochs=0
#   epoch=011 | loss=0.3902 | val_auc=0.6547 | best_val_auc=0.6547 | bad_epochs=0
#   epoch=013 | loss=0.3625 | val_auc=0.6664 | best_val_auc=0.6664 | bad_epochs=0
#   epoch=015 | loss=0.3348 | val_auc=0.6724 | best_val_auc=0.6724 | bad_epochs=0
#   epoch=016 | loss=0.3138 | val_auc=0.6821 | best_val_auc=0.6821 | bad_epochs=0
#   epoch=017 | loss=0.3109 | val_auc=0.6907 | best_val_auc=0.6907 | bad_epochs=0
#   epoch=018 | loss=0.2975 | val_auc=0.7088 | best_val_auc=0.7088 | bad_epochs=0
#   epoch=020 | loss=0.2712 | val_auc=0.6893 | best_val_auc=0.7088 | bad_epochs=2
#   epoch=023 | loss=0.2454 | val_auc=0.7204 | best_val_auc=0.7204 | bad_epochs=0
#   epoch=025 | loss=0.2292 | val_auc=0.7249 | best_val_auc=0.7249 | bad_epochs=0
#   epoch=027 | loss=0.2240 | val_auc=0.7250 | best_val_auc=0.7250 | bad_epochs=0
#   epoch=028 | loss=0.2189 | val_auc=0.7306 | best_val_auc=0.7306 | bad_epochs=0
#   epoch=030 | loss=0.2037 | val_auc=0.7356 | best_val_auc=0.7356 | bad_epochs=0
#   epoch=031 | loss=0.2017 | val_auc=0.7380 | best_val_auc=0.7380 | bad_epochs=0
#   epoch=032 | loss=0.1922 | val_auc=0.7495 | best_val_auc=0.7495 | bad_epochs=0
#   epoch=033 | loss=0.1881 | val_auc=0.7675 | best_val_auc=0.7675 | bad_epochs=0
#   epoch=035 | loss=0.1812 | val_auc=0.7388 | best_val_auc=0.7675 | bad_epochs=2
#   epoch=039 | loss=0.1568 | val_auc=0.7727 | best_val_auc=0.7727 | bad_epochs=0
#   epoch=040 | loss=0.1538 | val_auc=0.7479 | best_val_auc=0.7727 | bad_epochs=1
#   epoch=044 | loss=0.1452 | val_auc=0.7762 | best_val_auc=0.7762 | bad_epochs=0
#   epoch=045 | loss=0.1422 | val_auc=0.7655 | best_val_auc=0.7762 | bad_epochs=1
#   epoch=048 | loss=0.1311 | val_auc=0.7832 | best_val_auc=0.7832 | bad_epochs=0
#   epoch=050 | loss=0.1296 | val_auc=0.7726 | best_val_auc=0.7832 | bad_epochs=2
#   epoch=054 | loss=0.1164 | val_auc=0.7916 | best_val_auc=0.7916 | bad_epochs=0
#   epoch=055 | loss=0.1198 | val_auc=0.7648 | best_val_auc=0.7916 | bad_epochs=1
#   epoch=060 | loss=0.1058 | val_auc=0.7734 | best_val_auc=0.7916 | bad_epochs=6
#   epoch=065 | loss=0.0959 | val_auc=0.7694 | best_val_auc=0.7916 | bad_epochs=11
#   Early stopping at epoch=69. Best epoch=54, best val AUC=0.7916
#
# ======================================================================
# Running GRU | I3D | repeat=1 fold=1
# ======================================================================
# Fold setup: dataset=I3D, model=GRU, repeat=1, fold=1, seed=43, n_params=325378
# Sequences: train=13465, val=5162, test=4972 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6890 | val_auc=0.4492 | best_val_auc=0.4492 | bad_epochs=0
#   epoch=002 | loss=0.6670 | val_auc=0.4965 | best_val_auc=0.4965 | bad_epochs=0
#   epoch=003 | loss=0.6472 | val_auc=0.4982 | best_val_auc=0.4982 | bad_epochs=0
#   epoch=005 | loss=0.5956 | val_auc=0.5487 | best_val_auc=0.5487 | bad_epochs=0
#   epoch=008 | loss=0.5265 | val_auc=0.5898 | best_val_auc=0.5898 | bad_epochs=0
#   epoch=009 | loss=0.5120 | val_auc=0.6015 | best_val_auc=0.6015 | bad_epochs=0
#   epoch=010 | loss=0.4930 | val_auc=0.5791 | best_val_auc=0.6015 | bad_epochs=1
#   epoch=013 | loss=0.4593 | val_auc=0.6072 | best_val_auc=0.6072 | bad_epochs=0
#   epoch=014 | loss=0.4484 | val_auc=0.6197 | best_val_auc=0.6197 | bad_epochs=0
#   epoch=015 | loss=0.4362 | val_auc=0.6576 | best_val_auc=0.6576 | bad_epochs=0
#   epoch=020 | loss=0.3911 | val_auc=0.6370 | best_val_auc=0.6576 | bad_epochs=5
#   epoch=023 | loss=0.3697 | val_auc=0.6645 | best_val_auc=0.6645 | bad_epochs=0
#   epoch=024 | loss=0.3655 | val_auc=0.6779 | best_val_auc=0.6779 | bad_epochs=0
#   epoch=025 | loss=0.3546 | val_auc=0.6702 | best_val_auc=0.6779 | bad_epochs=1
#   epoch=028 | loss=0.3369 | val_auc=0.6914 | best_val_auc=0.6914 | bad_epochs=0
#   epoch=030 | loss=0.3278 | val_auc=0.6917 | best_val_auc=0.6917 | bad_epochs=0
#   epoch=031 | loss=0.3172 | val_auc=0.6945 | best_val_auc=0.6945 | bad_epochs=0
#   epoch=033 | loss=0.3081 | val_auc=0.6955 | best_val_auc=0.6955 | bad_epochs=0
#   epoch=034 | loss=0.3005 | val_auc=0.7207 | best_val_auc=0.7207 | bad_epochs=0
#   epoch=035 | loss=0.2943 | val_auc=0.7033 | best_val_auc=0.7207 | bad_epochs=1
#   epoch=040 | loss=0.2699 | val_auc=0.7213 | best_val_auc=0.7213 | bad_epochs=0
#   epoch=042 | loss=0.2628 | val_auc=0.7225 | best_val_auc=0.7225 | bad_epochs=0
#   epoch=044 | loss=0.2541 | val_auc=0.7471 | best_val_auc=0.7471 | bad_epochs=0
#   epoch=045 | loss=0.2509 | val_auc=0.7285 | best_val_auc=0.7471 | bad_epochs=1
#   epoch=048 | loss=0.2381 | val_auc=0.7482 | best_val_auc=0.7482 | bad_epochs=0
#   epoch=049 | loss=0.2394 | val_auc=0.7493 | best_val_auc=0.7493 | bad_epochs=0
#   epoch=050 | loss=0.2350 | val_auc=0.7407 | best_val_auc=0.7493 | bad_epochs=1
#   epoch=055 | loss=0.2122 | val_auc=0.7376 | best_val_auc=0.7493 | bad_epochs=6
#   epoch=057 | loss=0.2082 | val_auc=0.7544 | best_val_auc=0.7544 | bad_epochs=0
#   epoch=058 | loss=0.2044 | val_auc=0.7583 | best_val_auc=0.7583 | bad_epochs=0
#   epoch=060 | loss=0.1967 | val_auc=0.7589 | best_val_auc=0.7589 | bad_epochs=0
#   epoch=061 | loss=0.2008 | val_auc=0.7594 | best_val_auc=0.7594 | bad_epochs=0
#   epoch=062 | loss=0.1932 | val_auc=0.7687 | best_val_auc=0.7687 | bad_epochs=0
#   epoch=064 | loss=0.1893 | val_auc=0.7912 | best_val_auc=0.7912 | bad_epochs=0
#   epoch=065 | loss=0.1810 | val_auc=0.7693 | best_val_auc=0.7912 | bad_epochs=1
#   epoch=070 | loss=0.1742 | val_auc=0.7530 | best_val_auc=0.7912 | bad_epochs=6
#   epoch=075 | loss=0.1590 | val_auc=0.7786 | best_val_auc=0.7912 | bad_epochs=11
#   Early stopping at epoch=79. Best epoch=64, best val AUC=0.7912
#
# ======================================================================
# Running GRU | I3D | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=I3D, model=GRU, repeat=1, fold=2, seed=44, n_params=325378
# Sequences: train=13663, val=5336, test=4600 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6803 | val_auc=0.5338 | best_val_auc=0.5338 | bad_epochs=0
#   epoch=004 | loss=0.5863 | val_auc=0.5442 | best_val_auc=0.5442 | bad_epochs=0
#   epoch=005 | loss=0.5608 | val_auc=0.5604 | best_val_auc=0.5604 | bad_epochs=0
#   epoch=006 | loss=0.5423 | val_auc=0.5873 | best_val_auc=0.5873 | bad_epochs=0
#   epoch=008 | loss=0.4959 | val_auc=0.5905 | best_val_auc=0.5905 | bad_epochs=0
#   epoch=009 | loss=0.4813 | val_auc=0.6113 | best_val_auc=0.6113 | bad_epochs=0
#   epoch=010 | loss=0.4685 | val_auc=0.6336 | best_val_auc=0.6336 | bad_epochs=0
#   epoch=012 | loss=0.4422 | val_auc=0.6398 | best_val_auc=0.6398 | bad_epochs=0
#   epoch=014 | loss=0.4148 | val_auc=0.6565 | best_val_auc=0.6565 | bad_epochs=0
#   epoch=015 | loss=0.4063 | val_auc=0.6644 | best_val_auc=0.6644 | bad_epochs=0
#   epoch=019 | loss=0.3699 | val_auc=0.6802 | best_val_auc=0.6802 | bad_epochs=0
#   epoch=020 | loss=0.3653 | val_auc=0.6700 | best_val_auc=0.6802 | bad_epochs=1
#   epoch=021 | loss=0.3542 | val_auc=0.6818 | best_val_auc=0.6818 | bad_epochs=0
#   epoch=025 | loss=0.3339 | val_auc=0.6842 | best_val_auc=0.6842 | bad_epochs=0
#   epoch=028 | loss=0.3165 | val_auc=0.6910 | best_val_auc=0.6910 | bad_epochs=0
#   epoch=030 | loss=0.3039 | val_auc=0.6897 | best_val_auc=0.6910 | bad_epochs=2
#   epoch=031 | loss=0.2962 | val_auc=0.6914 | best_val_auc=0.6914 | bad_epochs=0
#   epoch=032 | loss=0.2923 | val_auc=0.7038 | best_val_auc=0.7038 | bad_epochs=0
#   epoch=033 | loss=0.2874 | val_auc=0.7085 | best_val_auc=0.7085 | bad_epochs=0
#   epoch=034 | loss=0.2809 | val_auc=0.7127 | best_val_auc=0.7127 | bad_epochs=0
#   epoch=035 | loss=0.2796 | val_auc=0.7003 | best_val_auc=0.7127 | bad_epochs=1
#   epoch=037 | loss=0.2677 | val_auc=0.7299 | best_val_auc=0.7299 | bad_epochs=0
#   epoch=039 | loss=0.2569 | val_auc=0.7350 | best_val_auc=0.7350 | bad_epochs=0
#   epoch=040 | loss=0.2464 | val_auc=0.7222 | best_val_auc=0.7350 | bad_epochs=1
#   epoch=045 | loss=0.2316 | val_auc=0.7230 | best_val_auc=0.7350 | bad_epochs=6
#   epoch=046 | loss=0.2324 | val_auc=0.7509 | best_val_auc=0.7509 | bad_epochs=0
#   epoch=050 | loss=0.2135 | val_auc=0.7146 | best_val_auc=0.7509 | bad_epochs=4
#   epoch=052 | loss=0.2102 | val_auc=0.7527 | best_val_auc=0.7527 | bad_epochs=0
#   epoch=055 | loss=0.1996 | val_auc=0.7435 | best_val_auc=0.7527 | bad_epochs=3
#   epoch=056 | loss=0.1925 | val_auc=0.7577 | best_val_auc=0.7577 | bad_epochs=0
#   epoch=058 | loss=0.1887 | val_auc=0.7596 | best_val_auc=0.7596 | bad_epochs=0
#   epoch=060 | loss=0.1878 | val_auc=0.7561 | best_val_auc=0.7596 | bad_epochs=2
#   epoch=065 | loss=0.1771 | val_auc=0.7471 | best_val_auc=0.7596 | bad_epochs=7
#   epoch=066 | loss=0.1650 | val_auc=0.7633 | best_val_auc=0.7633 | bad_epochs=0
#   epoch=067 | loss=0.1651 | val_auc=0.7690 | best_val_auc=0.7690 | bad_epochs=0
#   epoch=070 | loss=0.1577 | val_auc=0.7536 | best_val_auc=0.7690 | bad_epochs=3
#   epoch=074 | loss=0.1483 | val_auc=0.7831 | best_val_auc=0.7831 | bad_epochs=0
#   epoch=075 | loss=0.1506 | val_auc=0.7705 | best_val_auc=0.7831 | bad_epochs=1
#   epoch=080 | loss=0.1355 | val_auc=0.7695 | best_val_auc=0.7831 | bad_epochs=6
#   epoch=085 | loss=0.1295 | val_auc=0.7802 | best_val_auc=0.7831 | bad_epochs=11
#   epoch=088 | loss=0.1284 | val_auc=0.7886 | best_val_auc=0.7886 | bad_epochs=0
#   epoch=089 | loss=0.1217 | val_auc=0.7938 | best_val_auc=0.7938 | bad_epochs=0
#   epoch=090 | loss=0.1217 | val_auc=0.7666 | best_val_auc=0.7938 | bad_epochs=1
#   epoch=095 | loss=0.1112 | val_auc=0.7807 | best_val_auc=0.7938 | bad_epochs=6
#   epoch=100 | loss=0.1193 | val_auc=0.7814 | best_val_auc=0.7938 | bad_epochs=11
#
# ======================================================================
# Running GRU | I3D | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=I3D, model=GRU, repeat=1, fold=3, seed=45, n_params=325378
# Sequences: train=13760, val=5234, test=4605 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6836 | val_auc=0.4774 | best_val_auc=0.4774 | bad_epochs=0
#   epoch=002 | loss=0.6548 | val_auc=0.4870 | best_val_auc=0.4870 | bad_epochs=0
#   epoch=003 | loss=0.6259 | val_auc=0.4971 | best_val_auc=0.4971 | bad_epochs=0
#   epoch=004 | loss=0.5955 | val_auc=0.5278 | best_val_auc=0.5278 | bad_epochs=0
#   epoch=005 | loss=0.5696 | val_auc=0.5399 | best_val_auc=0.5399 | bad_epochs=0
#   epoch=006 | loss=0.5368 | val_auc=0.5718 | best_val_auc=0.5718 | bad_epochs=0
#   epoch=007 | loss=0.5158 | val_auc=0.5835 | best_val_auc=0.5835 | bad_epochs=0
#   epoch=009 | loss=0.4747 | val_auc=0.6087 | best_val_auc=0.6087 | bad_epochs=0
#   epoch=010 | loss=0.4610 | val_auc=0.6007 | best_val_auc=0.6087 | bad_epochs=1
#   epoch=012 | loss=0.4306 | val_auc=0.6090 | best_val_auc=0.6090 | bad_epochs=0
#   epoch=013 | loss=0.4196 | val_auc=0.6340 | best_val_auc=0.6340 | bad_epochs=0
#   epoch=015 | loss=0.3966 | val_auc=0.6266 | best_val_auc=0.6340 | bad_epochs=2
#   epoch=017 | loss=0.3712 | val_auc=0.6441 | best_val_auc=0.6441 | bad_epochs=0
#   epoch=018 | loss=0.3691 | val_auc=0.6589 | best_val_auc=0.6589 | bad_epochs=0
#   epoch=020 | loss=0.3450 | val_auc=0.6429 | best_val_auc=0.6589 | bad_epochs=2
#   epoch=022 | loss=0.3314 | val_auc=0.6623 | best_val_auc=0.6623 | bad_epochs=0
#   epoch=025 | loss=0.3181 | val_auc=0.6765 | best_val_auc=0.6765 | bad_epochs=0
#   epoch=030 | loss=0.2879 | val_auc=0.6718 | best_val_auc=0.6765 | bad_epochs=5
#   epoch=035 | loss=0.2677 | val_auc=0.6657 | best_val_auc=0.6765 | bad_epochs=10
#   epoch=037 | loss=0.2539 | val_auc=0.6816 | best_val_auc=0.6816 | bad_epochs=0
#   epoch=040 | loss=0.2425 | val_auc=0.6835 | best_val_auc=0.6835 | bad_epochs=0
#   epoch=041 | loss=0.2427 | val_auc=0.6960 | best_val_auc=0.6960 | bad_epochs=0
#   epoch=045 | loss=0.2284 | val_auc=0.6876 | best_val_auc=0.6960 | bad_epochs=4
#   epoch=048 | loss=0.2145 | val_auc=0.6972 | best_val_auc=0.6972 | bad_epochs=0
#   epoch=050 | loss=0.2078 | val_auc=0.7012 | best_val_auc=0.7012 | bad_epochs=0
#   epoch=051 | loss=0.2002 | val_auc=0.7071 | best_val_auc=0.7071 | bad_epochs=0
#   epoch=052 | loss=0.2072 | val_auc=0.7073 | best_val_auc=0.7073 | bad_epochs=0
#   epoch=054 | loss=0.1956 | val_auc=0.7163 | best_val_auc=0.7163 | bad_epochs=0
#   epoch=055 | loss=0.1956 | val_auc=0.7017 | best_val_auc=0.7163 | bad_epochs=1
#   epoch=058 | loss=0.1793 | val_auc=0.7165 | best_val_auc=0.7165 | bad_epochs=0
#   epoch=060 | loss=0.1754 | val_auc=0.7098 | best_val_auc=0.7165 | bad_epochs=2
#   epoch=064 | loss=0.1659 | val_auc=0.7205 | best_val_auc=0.7205 | bad_epochs=0
#   epoch=065 | loss=0.1650 | val_auc=0.7172 | best_val_auc=0.7205 | bad_epochs=1
#   epoch=066 | loss=0.1602 | val_auc=0.7239 | best_val_auc=0.7239 | bad_epochs=0
#   epoch=069 | loss=0.1569 | val_auc=0.7275 | best_val_auc=0.7275 | bad_epochs=0
#   epoch=070 | loss=0.1523 | val_auc=0.7216 | best_val_auc=0.7275 | bad_epochs=1
#   epoch=075 | loss=0.1404 | val_auc=0.7206 | best_val_auc=0.7275 | bad_epochs=6
#   epoch=080 | loss=0.1364 | val_auc=0.7152 | best_val_auc=0.7275 | bad_epochs=11
#   epoch=082 | loss=0.1335 | val_auc=0.7300 | best_val_auc=0.7300 | bad_epochs=0
#   epoch=085 | loss=0.1273 | val_auc=0.7093 | best_val_auc=0.7300 | bad_epochs=3
#   epoch=088 | loss=0.1226 | val_auc=0.7437 | best_val_auc=0.7437 | bad_epochs=0
#   epoch=090 | loss=0.1172 | val_auc=0.7192 | best_val_auc=0.7437 | bad_epochs=2
#   epoch=095 | loss=0.1145 | val_auc=0.7200 | best_val_auc=0.7437 | bad_epochs=7
#   epoch=100 | loss=0.1061 | val_auc=0.7361 | best_val_auc=0.7437 | bad_epochs=12
#
# ======================================================================
# Running GRU | I3D | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=I3D, model=GRU, repeat=1, fold=4, seed=46, n_params=325378
# Sequences: train=13818, val=5141, test=4640 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6800 | val_auc=0.4597 | best_val_auc=0.4597 | bad_epochs=0
#   epoch=002 | loss=0.6539 | val_auc=0.4643 | best_val_auc=0.4643 | bad_epochs=0
#   epoch=003 | loss=0.6268 | val_auc=0.5128 | best_val_auc=0.5128 | bad_epochs=0
#   epoch=005 | loss=0.5766 | val_auc=0.5577 | best_val_auc=0.5577 | bad_epochs=0
#   epoch=008 | loss=0.5156 | val_auc=0.6001 | best_val_auc=0.6001 | bad_epochs=0
#   epoch=010 | loss=0.4835 | val_auc=0.5831 | best_val_auc=0.6001 | bad_epochs=2
#   epoch=012 | loss=0.4592 | val_auc=0.6344 | best_val_auc=0.6344 | bad_epochs=0
#   epoch=013 | loss=0.4452 | val_auc=0.6703 | best_val_auc=0.6703 | bad_epochs=0
#   epoch=014 | loss=0.4288 | val_auc=0.6841 | best_val_auc=0.6841 | bad_epochs=0
#   epoch=015 | loss=0.4175 | val_auc=0.6615 | best_val_auc=0.6841 | bad_epochs=1
#   epoch=020 | loss=0.3764 | val_auc=0.6990 | best_val_auc=0.6990 | bad_epochs=0
#   epoch=022 | loss=0.3622 | val_auc=0.7009 | best_val_auc=0.7009 | bad_epochs=0
#   epoch=023 | loss=0.3526 | val_auc=0.7147 | best_val_auc=0.7147 | bad_epochs=0
#   epoch=025 | loss=0.3369 | val_auc=0.6901 | best_val_auc=0.7147 | bad_epochs=2
#   epoch=026 | loss=0.3332 | val_auc=0.7264 | best_val_auc=0.7264 | bad_epochs=0
#   epoch=028 | loss=0.3126 | val_auc=0.7387 | best_val_auc=0.7387 | bad_epochs=0
#   epoch=030 | loss=0.3059 | val_auc=0.7223 | best_val_auc=0.7387 | bad_epochs=2
#   epoch=032 | loss=0.2910 | val_auc=0.7542 | best_val_auc=0.7542 | bad_epochs=0
#   epoch=035 | loss=0.2784 | val_auc=0.7512 | best_val_auc=0.7542 | bad_epochs=3
#   epoch=037 | loss=0.2642 | val_auc=0.7623 | best_val_auc=0.7623 | bad_epochs=0
#   epoch=040 | loss=0.2573 | val_auc=0.7587 | best_val_auc=0.7623 | bad_epochs=3
#   epoch=043 | loss=0.2448 | val_auc=0.7706 | best_val_auc=0.7706 | bad_epochs=0
#   epoch=044 | loss=0.2402 | val_auc=0.7744 | best_val_auc=0.7744 | bad_epochs=0
#   epoch=045 | loss=0.2383 | val_auc=0.7830 | best_val_auc=0.7830 | bad_epochs=0
#   epoch=047 | loss=0.2333 | val_auc=0.7859 | best_val_auc=0.7859 | bad_epochs=0
#   epoch=050 | loss=0.2156 | val_auc=0.7291 | best_val_auc=0.7859 | bad_epochs=3
#   epoch=052 | loss=0.2124 | val_auc=0.7868 | best_val_auc=0.7868 | bad_epochs=0
#   epoch=053 | loss=0.2120 | val_auc=0.7868 | best_val_auc=0.7868 | bad_epochs=0
#   epoch=055 | loss=0.2070 | val_auc=0.7698 | best_val_auc=0.7868 | bad_epochs=2
#   epoch=058 | loss=0.1974 | val_auc=0.7950 | best_val_auc=0.7950 | bad_epochs=0
#   epoch=060 | loss=0.1905 | val_auc=0.7593 | best_val_auc=0.7950 | bad_epochs=2
#   epoch=065 | loss=0.1804 | val_auc=0.7872 | best_val_auc=0.7950 | bad_epochs=7
#   epoch=067 | loss=0.1708 | val_auc=0.8112 | best_val_auc=0.8112 | bad_epochs=0
#   epoch=070 | loss=0.1613 | val_auc=0.7999 | best_val_auc=0.8112 | bad_epochs=3
#   epoch=075 | loss=0.1603 | val_auc=0.7871 | best_val_auc=0.8112 | bad_epochs=8
#   epoch=080 | loss=0.1458 | val_auc=0.7982 | best_val_auc=0.8112 | bad_epochs=13
#   epoch=081 | loss=0.1466 | val_auc=0.8205 | best_val_auc=0.8205 | bad_epochs=0
#   epoch=083 | loss=0.1397 | val_auc=0.8335 | best_val_auc=0.8335 | bad_epochs=0
#   epoch=085 | loss=0.1411 | val_auc=0.8182 | best_val_auc=0.8335 | bad_epochs=2
#   epoch=090 | loss=0.1348 | val_auc=0.8175 | best_val_auc=0.8335 | bad_epochs=7
#   epoch=095 | loss=0.1265 | val_auc=0.8254 | best_val_auc=0.8335 | bad_epochs=12
#   Early stopping at epoch=98. Best epoch=83, best val AUC=0.8335
#
# ======================================================================
# Running GRU | I3D | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=I3D, model=GRU, repeat=1, fold=5, seed=47, n_params=325378
# Sequences: train=13595, val=5222, test=4782 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6866 | val_auc=0.5105 | best_val_auc=0.5105 | bad_epochs=0
# ...
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=2, fold=1, seed=143, n_params=756226
# Sequences: train=2039, val=787, test=600 | Videos: train=69, val=27, test=25
#   epoch=001 | loss=0.5028 | val_auc=0.6813 | best_val_auc=0.6813 | bad_epochs=0
#   epoch=002 | loss=0.3530 | val_auc=0.7308 | best_val_auc=0.7308 | bad_epochs=0
#   epoch=004 | loss=0.2309 | val_auc=0.7527 | best_val_auc=0.7527 | bad_epochs=0
#   epoch=005 | loss=0.1880 | val_auc=0.7967 | best_val_auc=0.7967 | bad_epochs=0
#   epoch=010 | loss=0.1096 | val_auc=0.7088 | best_val_auc=0.7967 | bad_epochs=5
#   epoch=015 | loss=0.0699 | val_auc=0.6978 | best_val_auc=0.7967 | bad_epochs=10
#   epoch=020 | loss=0.0603 | val_auc=0.7692 | best_val_auc=0.7967 | bad_epochs=15
#   Early stopping at epoch=20. Best epoch=5, best val AUC=0.7967
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=2 fold=2
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=2, fold=2, seed=144, n_params=756226
# Sequences: train=1756, val=887, test=783 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4872 | val_auc=0.7449 | best_val_auc=0.7449 | bad_epochs=0
#   epoch=004 | loss=0.2813 | val_auc=0.7653 | best_val_auc=0.7653 | bad_epochs=0
#   epoch=005 | loss=0.2356 | val_auc=0.7500 | best_val_auc=0.7653 | bad_epochs=1
#   epoch=006 | loss=0.2068 | val_auc=0.7704 | best_val_auc=0.7704 | bad_epochs=0
#   epoch=007 | loss=0.1828 | val_auc=0.7857 | best_val_auc=0.7857 | bad_epochs=0
#   epoch=008 | loss=0.1347 | val_auc=0.8418 | best_val_auc=0.8418 | bad_epochs=0
#   epoch=010 | loss=0.1098 | val_auc=0.8010 | best_val_auc=0.8418 | bad_epochs=2
#   epoch=015 | loss=0.0955 | val_auc=0.7602 | best_val_auc=0.8418 | bad_epochs=7
#   epoch=017 | loss=0.0697 | val_auc=0.8469 | best_val_auc=0.8469 | bad_epochs=0
#   epoch=020 | loss=0.0601 | val_auc=0.8010 | best_val_auc=0.8469 | bad_epochs=3
#   epoch=025 | loss=0.0637 | val_auc=0.7908 | best_val_auc=0.8469 | bad_epochs=8
#   epoch=030 | loss=0.0349 | val_auc=0.7908 | best_val_auc=0.8469 | bad_epochs=13
#   Early stopping at epoch=32. Best epoch=17, best val AUC=0.8469
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=2 fold=3
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=2, fold=3, seed=145, n_params=756226
# Sequences: train=1950, val=762, test=714 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.5045 | val_auc=0.7704 | best_val_auc=0.7704 | bad_epochs=0
#   epoch=002 | loss=0.3557 | val_auc=0.8469 | best_val_auc=0.8469 | bad_epochs=0
#   epoch=005 | loss=0.2036 | val_auc=0.7857 | best_val_auc=0.8469 | bad_epochs=3
#   epoch=010 | loss=0.1184 | val_auc=0.7908 | best_val_auc=0.8469 | bad_epochs=8
#   epoch=015 | loss=0.0683 | val_auc=0.7602 | best_val_auc=0.8469 | bad_epochs=13
#   Early stopping at epoch=17. Best epoch=2, best val AUC=0.8469
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=2 fold=4
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=2, fold=4, seed=146, n_params=756226
# Sequences: train=1882, val=853, test=691 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.5379 | val_auc=0.6990 | best_val_auc=0.6990 | bad_epochs=0
#   epoch=002 | loss=0.4293 | val_auc=0.7143 | best_val_auc=0.7143 | bad_epochs=0
#   epoch=004 | loss=0.3116 | val_auc=0.7653 | best_val_auc=0.7653 | bad_epochs=0
#   epoch=005 | loss=0.2822 | val_auc=0.7857 | best_val_auc=0.7857 | bad_epochs=0
#   epoch=010 | loss=0.1373 | val_auc=0.7143 | best_val_auc=0.7857 | bad_epochs=5
#   epoch=015 | loss=0.0941 | val_auc=0.6122 | best_val_auc=0.7857 | bad_epochs=10
#   epoch=020 | loss=0.0791 | val_auc=0.6531 | best_val_auc=0.7857 | bad_epochs=15
#   Early stopping at epoch=20. Best epoch=5, best val AUC=0.7857
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=2 fold=5
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=2, fold=5, seed=147, n_params=756226
# Sequences: train=1979, val=809, test=638 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4781 | val_auc=0.7245 | best_val_auc=0.7245 | bad_epochs=0
#   epoch=005 | loss=0.2116 | val_auc=0.6378 | best_val_auc=0.7245 | bad_epochs=4
#   epoch=010 | loss=0.1392 | val_auc=0.6020 | best_val_auc=0.7245 | bad_epochs=9
#   epoch=015 | loss=0.0968 | val_auc=0.6020 | best_val_auc=0.7245 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.7245
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=3 fold=1
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=3, fold=1, seed=243, n_params=756226
# Sequences: train=1921, val=741, test=764 | Videos: train=69, val=27, test=25
#   epoch=001 | loss=0.4766 | val_auc=0.6374 | best_val_auc=0.6374 | bad_epochs=0
#   epoch=002 | loss=0.3146 | val_auc=0.6978 | best_val_auc=0.6978 | bad_epochs=0
#   epoch=003 | loss=0.2458 | val_auc=0.7582 | best_val_auc=0.7582 | bad_epochs=0
#   epoch=005 | loss=0.1758 | val_auc=0.6813 | best_val_auc=0.7582 | bad_epochs=2
#   epoch=006 | loss=0.1351 | val_auc=0.7747 | best_val_auc=0.7747 | bad_epochs=0
#   epoch=010 | loss=0.1107 | val_auc=0.7637 | best_val_auc=0.7747 | bad_epochs=4
#   epoch=015 | loss=0.0717 | val_auc=0.6758 | best_val_auc=0.7747 | bad_epochs=9
#   epoch=020 | loss=0.0618 | val_auc=0.6868 | best_val_auc=0.7747 | bad_epochs=14
#   Early stopping at epoch=21. Best epoch=6, best val AUC=0.7747
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=3 fold=2
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=3, fold=2, seed=244, n_params=756226
# Sequences: train=2018, val=760, test=648 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.5067 | val_auc=0.7704 | best_val_auc=0.7704 | bad_epochs=0
#   epoch=005 | loss=0.2407 | val_auc=0.7398 | best_val_auc=0.7704 | bad_epochs=4
#   epoch=009 | loss=0.1731 | val_auc=0.7857 | best_val_auc=0.7857 | bad_epochs=0
#   epoch=010 | loss=0.1481 | val_auc=0.7347 | best_val_auc=0.7857 | bad_epochs=1
#   epoch=015 | loss=0.1094 | val_auc=0.7143 | best_val_auc=0.7857 | bad_epochs=6
#   epoch=020 | loss=0.0785 | val_auc=0.7347 | best_val_auc=0.7857 | bad_epochs=11
#   Early stopping at epoch=24. Best epoch=9, best val AUC=0.7857
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=3 fold=3
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=3, fold=3, seed=245, n_params=756226
# Sequences: train=1918, val=857, test=651 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.5042 | val_auc=0.6582 | best_val_auc=0.6582 | bad_epochs=0
#   epoch=005 | loss=0.2369 | val_auc=0.6276 | best_val_auc=0.6582 | bad_epochs=4
#   epoch=010 | loss=0.1633 | val_auc=0.6276 | best_val_auc=0.6582 | bad_epochs=9
#   epoch=015 | loss=0.1358 | val_auc=0.5561 | best_val_auc=0.6582 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.6582
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=3 fold=4
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=3, fold=4, seed=246, n_params=756226
# Sequences: train=1968, val=885, test=573 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.5066 | val_auc=0.8316 | best_val_auc=0.8316 | bad_epochs=0
#   epoch=004 | loss=0.2538 | val_auc=0.8367 | best_val_auc=0.8367 | bad_epochs=0
#   epoch=005 | loss=0.2213 | val_auc=0.7245 | best_val_auc=0.8367 | bad_epochs=1
#   epoch=010 | loss=0.1427 | val_auc=0.6990 | best_val_auc=0.8367 | bad_epochs=6
#   epoch=015 | loss=0.1119 | val_auc=0.7653 | best_val_auc=0.8367 | bad_epochs=11
#   Early stopping at epoch=19. Best epoch=4, best val AUC=0.8367
#
# ======================================================================
# Running Transformer_L4 | RLT | repeat=3 fold=5
# ======================================================================
# Fold setup: dataset=RLT, model=Transformer_L4, repeat=3, fold=5, seed=247, n_params=756226
# Sequences: train=1907, val=729, test=790 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4941 | val_auc=0.7092 | best_val_auc=0.7092 | bad_epochs=0
#   epoch=003 | loss=0.2653 | val_auc=0.7143 | best_val_auc=0.7143 | bad_epochs=0
#   epoch=004 | loss=0.2253 | val_auc=0.7347 | best_val_auc=0.7347 | bad_epochs=0
#   epoch=005 | loss=0.1890 | val_auc=0.7194 | best_val_auc=0.7347 | bad_epochs=1
#   epoch=006 | loss=0.1406 | val_auc=0.7449 | best_val_auc=0.7449 | bad_epochs=0
#   epoch=009 | loss=0.1046 | val_auc=0.7653 | best_val_auc=0.7653 | bad_epochs=0
#   epoch=010 | loss=0.0936 | val_auc=0.7347 | best_val_auc=0.7653 | bad_epochs=1
#   epoch=015 | loss=0.0442 | val_auc=0.7296 | best_val_auc=0.7653 | bad_epochs=6
#   epoch=018 | loss=0.0542 | val_auc=0.7959 | best_val_auc=0.7959 | bad_epochs=0
#   epoch=020 | loss=0.0454 | val_auc=0.7296 | best_val_auc=0.7959 | bad_epochs=2
#   epoch=025 | loss=0.0381 | val_auc=0.7551 | best_val_auc=0.7959 | bad_epochs=7
#   epoch=030 | loss=0.0436 | val_auc=0.6531 | best_val_auc=0.7959 | bad_epochs=12
#   Early stopping at epoch=33. Best epoch=18, best val AUC=0.7959
#
# ##########################################################################################
# S2 — Traditional ML temporal-stat — RLT
# ##########################################################################################
# Saved table: outputs\revision_final_20260501\tables\table_baseline_comparison.csv shape=(20, 47)
#     dataset                    model  seed  repeat  fold  best_epoch  \
# 0       I3D                  MSTGNet    43       1     1        60.0
# 1       I3D                  MSTGNet    44       1     2        61.0
# 2       I3D                  MSTGNet    45       1     3        38.0
# 3       I3D                  MSTGNet    46       1     4        72.0
# 4       I3D                  MSTGNet    47       1     5        52.0
# ..      ...                      ...   ...     ...   ...         ...
# 195     RLT  GradBoost_temporal_stat   243       3     1         NaN
# 196     RLT  GradBoost_temporal_stat   244       3     2         NaN
# 197     RLT  GradBoost_temporal_stat   245       3     3         NaN
# 198     RLT  GradBoost_temporal_stat   246       3     4         NaN
# 199     RLT  GradBoost_temporal_stat   247       3     5         NaN
#
#      best_val_auc  last_train_loss  threshold   threshold_source  ...  \
# 0        0.860634         0.045745   0.264879  validation_youden  ...
# 1        0.807432         0.037703   0.451381  validation_youden  ...
# 2        0.841329         0.061221   0.555223  validation_youden  ...
# 3        0.865283         0.035453   0.444590  validation_youden  ...
# 4        0.850659         0.045366   0.334289  validation_youden  ...
# ..            ...              ...        ...                ...  ...
# 195           NaN              NaN   0.988613  validation_youden  ...
# 196           NaN              NaN   0.999978  validation_youden  ...
# 197           NaN              NaN   0.979622  validation_youden  ...
# 198           NaN              NaN   0.995038  validation_youden  ...
# 199           NaN              NaN   0.999978  validation_youden  ...
#
#      test_mcc  test_sensitivity  test_specificity  test_brier  test_tn  \
# 0    0.536064          0.847134          0.681529    0.180390      107
# 1    0.598738          0.796178          0.802548    0.168834      126
# 2    0.497310          0.770701          0.726115    0.209193      114
# 3    0.631157          0.853503          0.775641    0.153733      121
# 4    0.566160          0.756410          0.808917    0.187003      127
# ..        ...               ...               ...         ...      ...
# 195  0.457604          0.615385          0.833333    0.257863       10
# 196  0.447214          0.333333          1.000000    0.283111       12
# 197  0.338062          0.583333          0.750000    0.333901        9
# 198  0.000000          0.416667          0.583333    0.465849        7
# 199  0.000000          0.250000          0.750000    0.311529        9
#
#      test_fp  test_fn  test_tp   feature_mode  feature_dim
# 0         50       24      133            NaN          NaN
# 1         31       32      125            NaN          NaN
# 2         43       36      121            NaN          NaN
# 3         35       23      134            NaN          NaN
# 4         30       38      118            NaN          NaN
# ..       ...      ...      ...            ...          ...
# 195        2        5        8  temporal_stat      13527.0
# 196        0        8        4  temporal_stat      13527.0
# 197        3        5        7  temporal_stat      13527.0
# 198        5        7        5  temporal_stat      13527.0
# 199        3        9        3  temporal_stat      13527.0
#
# [200 rows x 54 columns]
#                           item  \
# 0                     manifest
# 1              dataset_summary
# 2        capacity_check_pre_S2
# 3                     main_I3D
# 4                     main_RLT
# 5                 full_ref_I3D
# 6                 full_ref_RLT
# 7               baseline_table
# 8                   arch_table
# 9                  modal_table
# 10              landmark_table
# 11    landmark_prediction_corr
# 12         cross_dataset_table
# 13          compute_cost_table
# 14  temporal_sensitivity_table
# 15             multiseed_stats
# 16      statistical_comparison
# 17         repeat_level_ci_I3D
# 18         repeat_level_ci_RLT
# 19         repeat_level_ci_all
# 20   repeat_level_ci_multiseed
# 21       repeat_level_ci_table
# 22           paper_table_index
# 23     paper_table12_repeat_ci
# 24        interpretability_dir
#
#                                                  path  exists
# 0   outputs\revision_final_20260501\config\experim...    True
# 1   outputs\revision_final_20260501\tables\dataset...    True
# 2   outputs\revision_final_20260501\compute_cost\c...   False
# 3   outputs\revision_final_20260501\fold_results\m...    True
# 4   outputs\revision_final_20260501\fold_results\m...    True
# 5   outputs\revision_final_20260501\fold_results\f...    True
# 6   outputs\revision_final_20260501\fold_results\f...    True
# 7   outputs\revision_final_20260501\tables\table_b...    True
# 8   outputs\revision_final_20260501\tables\table_a...   False
# 9   outputs\revision_final_20260501\tables\table_m...   False
# 10  outputs\revision_final_20260501\tables\table_l...    True
# 11  outputs\revision_final_20260501\tables\table_l...    True
# 12  outputs\revision_final_20260501\tables\table_c...   False
# 13  outputs\revision_final_20260501\tables\table_c...   False
# 14  outputs\revision_final_20260501\tables\table_t...   False
# 15  outputs\revision_final_20260501\stats\statisti...   False
# 16  outputs\revision_final_20260501\stats\statisti...   False
# 17  outputs\revision_final_20260501\stats\repeat_l...   False
# 18  outputs\revision_final_20260501\stats\repeat_l...   False
# 19  outputs\revision_final_20260501\stats\repeat_l...   False
# 20  outputs\revision_final_20260501\tables\repeat_...   False
# 21  outputs\revision_final_20260501\tables\table_r...   False
# 22  outputs\revision_final_20260501\tables\PAPER_T...   False
# 23  outputs\revision_final_20260501\tables\PAPER_T...   False
# 24   outputs\revision_final_20260501\interpretability    True
