# %%
from pathlib import Path
from datetime import datetime
import gc
import shutil
import warnings
import inspect

import numpy as np
import pandas as pd
import torch

import model_base as mb

warnings.simplefilter("default")


# ============================================================
# Run switches
# ============================================================
# Final default below is prepared for running S1 now.
# If you want only dry-run again, set RUN_S0_DRYRUN=True and RUN_S1_MAIN_CV=False.

RUN_S0_DRYRUN = False

# Keep this False so S1 is controlled explicitly.
AUTO_RUN_S1_AFTER_S0_PASS = False

RUN_S1_MAIN_CV = False
RUN_S2_BASELINES = False
RUN_S3_ARCH_ABLATION = False
RUN_S3B_TEMPORAL_SENSITIVITY = False
RUN_S4_MODAL_ABLATION = True
RUN_S5_LANDMARK_QUALITY = False
RUN_S6_CROSS_DATASET = False
RUN_S7_MULTI_SEED = False
RUN_S8_COMPUTE_COST = False
RUN_S9_CALIBRATION_EXPORT = False
RUN_S10_INTERPRETABILITY = False
RUN_S11_EXPORT_PAPER_TABLES = False

CONFIRM_LONG_RUNS = True
RUN_S1_PREFLIGHT_CHECK = False
RUN_PRE_EXPERIMENT_CAPACITY_CHECK = False




# ============================================================
# Global setup
# ============================================================

SEED = 42
mb.set_all_seeds(SEED)

DEVICE = mb.get_device()

RUN_DATE_OVERRIDE = "20260501"

if RUN_DATE_OVERRIDE is None:
    RUN_DATE = datetime.now().strftime("%Y%m%d")
else:
    RUN_DATE = str(RUN_DATE_OVERRIDE)

OUTPUT_ROOT = Path(f"outputs/revision_final_{RUN_DATE}")
PROCESSED_DIR = Path("data/processed")

CONFIG = {
    "sequence_length": 50,
    "stride": 25,
    "hidden_features": 128,
    "num_heads": 4,
    "dropout_i3d": 0.4,
    "dropout_rlt": 0.3,
    "batch_size": 16,
    "epochs": 100,
    "patience": 15,
    "lr": 1e-4,
    "weight_decay": 1e-2,
    "validation_split": 0.28,
    "threshold_strategy": "validation_youden",
    "early_stopping_metric": "validation_auc",
    "main_seed": 42,
    "multiseeds": [42, 123, 2024, 2025, 3407],
    "fallback_multiseeds": [42, 123, 2024],
    "i3d_cv": {"n_splits": 5, "n_repeats": 1},
    "rlt_cv": {"n_splits": 5, "n_repeats": 3},
    "rlt_ablation_cv": {"n_splits": 5, "n_repeats": 1},
    "full_model_use_cross_modal": False,
    "transformer_num_layers": 4,
    "s7_multiseed_split_protocol": (
        "All seeds share identical video-level splits generated with seed=42 "
        "to isolate random initialization/training stochasticity from data partition variance."
    ),
    "s6_cross_dataset_protocol": (
        "MSTGNet source-only is trained on source train and thresholded on source validation; "
        "traditional temporal-stat source-only and diagonal CORAL are run separately. "
        "Target test is never used for training, scaling, thresholding, or adaptation."
    ),
    "notes": {
        "canonical_split_files": (
            "Use *_splits_main_seed42.json or *_splits_CANONICAL_main_seed42.json "
            "as canonical split definitions. Files named *_splits_seed*.json may be "
            "created internally by run_cv_experiment and can contain only remaining splits."
        ),
        "s6_mstgnet_source_only": (
            "S6 MSTGNet source-only is trained specifically on the source dataset for transfer. "
            "It does not reuse S1 best checkpoints."
        ),
        "manuscript_consistency": (
            "Manuscript must say sigmoid binary logit, not softmax; traditional ML uses "
            "temporal-stat 13,527-D descriptors, not mean-only 1,503-D; mixed precision "
            "should not be claimed unless AMP is added; dropout is dataset-specific "
            "I3D=0.4 and RLT=0.3."
        ),
    },
}

DATASETS = ["I3D", "RLT"]

for subdir in [
    "config",
    "config/splits",
    "tables",
    "predictions",
    "fold_results",
    "stats",
    "checkpoints",
    "interpretability",
    "cross_dataset",
    "landmark_quality",
    "compute_cost",
    "figures_data",
    "logs",
    "manuscript_exports",
]:
    mb.ensure_dir(OUTPUT_ROOT / subdir)

print("OUTPUT_ROOT:", OUTPUT_ROOT)
print("DEVICE:", DEVICE)

manifest = mb.create_experiment_manifest(
    output_dir=OUTPUT_ROOT,
    config=CONFIG,
    run_name="revision_final_v5",
)
mb.save_experiment_manifest(manifest, OUTPUT_ROOT)


# ============================================================
# model_base API validation
# ============================================================

required_mb_functions = [
    "dry_run_one_fold",
    "run_cv_experiment",
    "run_deep_learning_baselines",
    "run_traditional_ml_baseline",
    "run_cross_dataset_methods",
    "run_cross_dataset_mstgnet_source_only",
    "compute_landmark_quality_table",
    "compute_landmark_quality_prediction_correlation",
    "compute_gradient_importance_from_checkpoint",
    "save_gradient_importance",
    "select_checkpoint_validation_only",
    "compare_models_statistically",
    "compute_repeat_level_ci",
    "save_repeat_level_ci_table",
    "audit_video_split_overlap",
    "get_video_labels_from_data",
    "filter_completed_splits",
    "summarize_cv_results",
    "default_traditional_ml_models",
    "make_video_level_splits",
    "save_splits",
    "load_splits",
    "prepare_sequences",
    "compute_model_capacity_table",
    "wilcoxon_signed_rank_test",
    "paired_ttest",
    "safe_json_dump",
    "standardize_model_names_for_paper",
    "build_mstgnet_factory",
    "build_transformer_factory",
    "build_lstm_factory",
    "build_bilstm_factory",
    "build_gru_factory",
    "build_cnn_lstm_factory",
]

for name in required_mb_functions:
    assert hasattr(mb, name), f"model_base missing: {name}"

print("PASS: model_base API compatible with notebook")


# ============================================================
# Helper functions
# ============================================================

def transformer_model_name() -> str:
    return f"Transformer_L{int(CONFIG['transformer_num_layers'])}"


def dataset_dropout(dataset_name: str) -> float:
    name = str(dataset_name).upper()
    if name == "I3D":
        return float(CONFIG["dropout_i3d"])
    if name == "RLT":
        return float(CONFIG["dropout_rlt"])
    return 0.3


def dataset_cv_params(dataset_name: str) -> dict:
    name = str(dataset_name).upper()
    if name == "I3D":
        return CONFIG["i3d_cv"]
    if name == "RLT":
        return CONFIG["rlt_cv"]
    raise ValueError(f"Unknown dataset: {dataset_name}")


def active_feature_dim(dataset_name: str) -> int:
    if "data_dict" in globals() and dataset_name in data_dict:
        return int(len(data_dict[dataset_name]["coord_cols_active"]))
    return 1503


def build_mstgnet_for_dataset(
    dataset_name: str,
    data: dict,
    *,
    use_graph: bool = True,
    use_temporal: bool = True,
    use_pooling: bool = True,
    use_cross_modal: bool = False,
    enabled_modalities=("face", "eyes", "body"),
    hidden_dim: int = None,
    dropout: float = None,
):
    if hidden_dim is None:
        hidden_dim = int(CONFIG["hidden_features"])
    if dropout is None:
        dropout = dataset_dropout(dataset_name)

    return mb.build_mstgnet_factory(
        input_dim=int(len(data["coord_cols_active"])),
        modality_slices=data["active_modality_slices"],
        hidden_dim=int(hidden_dim),
        num_heads=int(CONFIG["num_heads"]),
        dropout=float(dropout),
        enabled_modalities=tuple(enabled_modalities),
        use_graph=bool(use_graph),
        use_temporal=bool(use_temporal),
        use_pooling=bool(use_pooling),
        use_cross_modal=bool(use_cross_modal),
    )


def build_transformer_for_dataset(
    dataset_name: str,
    *,
    input_dim: int = None,
    hidden_dim: int = None,
    num_layers: int = None,
    dropout: float = None,
):
    if input_dim is None:
        input_dim = active_feature_dim(dataset_name)
    if hidden_dim is None:
        hidden_dim = int(CONFIG["hidden_features"])
    if dropout is None:
        dropout = dataset_dropout(dataset_name)
    if num_layers is None:
        num_layers = int(CONFIG["transformer_num_layers"])

    return mb.build_transformer_factory(
        input_dim=int(input_dim),
        hidden_dim=int(hidden_dim),
        num_heads=int(CONFIG["num_heads"]),
        num_layers=int(num_layers),
        dropout=float(dropout),
    )


def require_long_run(section_name: str):
    if not CONFIRM_LONG_RUNS:
        raise RuntimeError(
            f"{section_name} is a long run. Set CONFIRM_LONG_RUNS=True before running."
        )


def read_csv_if_exists(path):
    path = Path(path)
    if path.exists():
        return pd.read_csv(path)
    return pd.DataFrame()


def copy_if_exists(src, dst):
    src = Path(src)
    dst = Path(dst)
    if src.exists():
        mb.ensure_dir(dst.parent)
        shutil.copy(src, dst)
        print(f"Copied: {src} -> {dst}")
    else:
        print(f"Skip copy, not found: {src}")


def save_table(df: pd.DataFrame, name: str) -> Path:
    path = OUTPUT_ROOT / "tables" / name
    mb.ensure_dir(path.parent)
    df.to_csv(path, index=False)
    print(f"Saved table: {path} shape={df.shape}")
    return path


def fold_results_file(model_name: str, dataset_name: str) -> Path:
    return OUTPUT_ROOT / "fold_results" / f"{model_name}_{dataset_name}.csv"


def combine_fold_results(files_or_patterns) -> pd.DataFrame:
    rows = []

    for item in files_or_patterns:
        item_path = Path(item)
        item_str = str(item_path)

        if "*" in item_str or "?" in item_str:
            parent = item_path.parent
            pattern = item_path.name
            matched = sorted(parent.glob(pattern))
        else:
            matched = [item_path]

        for p in matched:
            if p.exists():
                try:
                    rows.append(pd.read_csv(p))
                except Exception as e:
                    warnings.warn(f"Could not read {p}: {e}", RuntimeWarning)

    if rows:
        return pd.concat(rows, ignore_index=True)

    return pd.DataFrame()


def drop_duplicate_fold_rows(df: pd.DataFrame) -> pd.DataFrame:
    if df is None or len(df) == 0:
        return pd.DataFrame()

    key_cols = [
        "dataset",
        "source_dataset",
        "target_dataset",
        "model",
        "seed",
        "repeat",
        "fold",
    ]
    existing = [c for c in key_cols if c in df.columns]

    required_base = {"dataset", "model", "seed", "repeat", "fold"}
    if required_base.issubset(set(existing)):
        return df.drop_duplicates(subset=existing, keep="last").reset_index(drop=True)

    return df.drop_duplicates().reset_index(drop=True)


def drop_duplicate_prediction_rows(df: pd.DataFrame) -> pd.DataFrame:
    if df is None or len(df) == 0:
        return pd.DataFrame()

    candidate_keys = [
        "dataset",
        "source_dataset",
        "target_dataset",
        "model",
        "seed",
        "repeat",
        "fold",
        "split",
        "video_id",
    ]
    existing = [c for c in candidate_keys if c in df.columns]

    required_base = {"dataset", "model", "seed", "repeat", "fold", "split", "video_id"}
    if required_base.issubset(set(existing)):
        return df.drop_duplicates(subset=existing, keep="last").reset_index(drop=True)

    return df.drop_duplicates().reset_index(drop=True)


def summarize_results(
    df: pd.DataFrame,
    *,
    output_name: str,
    metric_cols=None,
    group_cols=None,
) -> pd.DataFrame:
    if df is None or len(df) == 0:
        out = pd.DataFrame()
    else:
        out = mb.summarize_cv_results(
            df,
            metric_cols=metric_cols,
            group_cols=group_cols,
        )
    save_table(out, output_name)
    return out


def make_or_load_splits(
    dataset_name: str,
    data: dict,
    *,
    n_splits: int,
    n_repeats: int,
    seed: int = 42,
    suffix: str = "main",
):
    split_path = OUTPUT_ROOT / "config" / "splits" / f"{dataset_name}_splits_{suffix}_seed{seed}.json"

    if split_path.exists():
        print(f"Loading existing splits: {split_path}")
        return mb.load_splits(split_path)

    video_ids, y_video = mb.get_video_labels_from_data(data)

    splits = mb.make_video_level_splits(
        video_ids,
        y_video,
        n_splits=int(n_splits),
        n_repeats=int(n_repeats),
        val_ratio=float(CONFIG["validation_split"]),
        seed=int(seed),
    )
    mb.save_splits(splits, split_path)
    print(f"Saved splits: {split_path}")
    return splits


def first_repeat_only(splits):
    return [s for s in splits if int(s["repeat"]) == 1]


def clean_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()


def safe_torch_load_checkpoint_local(path, map_location="cpu"):
    try:
        return torch.load(path, map_location=map_location, weights_only=False)
    except TypeError:
        return torch.load(path, map_location=map_location)


def save_full_model_reference_for_ablation(dataset_name: str):
    src_full = OUTPUT_ROOT / "fold_results" / f"MSTGNet_{dataset_name}.csv"
    dst_full_ref = OUTPUT_ROOT / "fold_results" / f"full_model_reference_{dataset_name}.csv"

    if src_full.exists():
        df_full = pd.read_csv(src_full)

        if "repeat" in df_full.columns:
            df_full_ref = df_full[df_full["repeat"].astype(int) == 1].copy()
        else:
            df_full_ref = df_full.copy()

        df_full_ref.to_csv(dst_full_ref, index=False)
        print(
            f"Saved full model reference for ablation: {dst_full_ref} "
            f"shape={df_full_ref.shape}"
        )
    else:
        print(f"Skip full model reference, not found: {src_full}")


def require_full_model_reference(dataset_name: str):
    ref_path = OUTPUT_ROOT / "fold_results" / f"full_model_reference_{dataset_name}.csv"
    if not ref_path.exists():
        raise FileNotFoundError(
            f"Missing full-model reference for {dataset_name}: {ref_path}. "
            "Run S1 first, or create full_model_reference_{dataset}.csv from repeat=1."
        )
    return ref_path


def get_param_column(df: pd.DataFrame):
    for c in ["n_trainable_params", "n_params", "trainable_params"]:
        if c in df.columns:
            return c
    return None


def deep_learning_baseline_names() -> list:
    return [
        "LSTM",
        "BiLSTM",
        "GRU",
        "CNN-LSTM",
        transformer_model_name(),
    ]


def traditional_ml_model_names() -> list:
    return list(mb.default_traditional_ml_models(seed=SEED).keys())


def cross_dataset_model_names() -> list:
    return [
        "MSTGNet_SourceOnly",
        "LogReg_temporal_stat_SourceOnly",
        "LogReg_temporal_stat_CORAL",
        "RF_temporal_stat_SourceOnly",
        "RF_temporal_stat_CORAL",
        "SVM_temporal_stat_SourceOnly",
        "SVM_temporal_stat_CORAL",
        "GradBoost_temporal_stat_SourceOnly",
        "GradBoost_temporal_stat_CORAL",
    ]


def architecture_ablation_model_names() -> list:
    return [
        "MSTGNet_NoGraph",
        "MSTGNet_NoTemporal",
        "MSTGNet_NoPooling",
        "MSTGNet_CrossModalAblation",
    ]


def modality_ablation_model_names() -> list:
    return [
        "MSTGNet_FaceOnly",
        "MSTGNet_EyesOnly",
        "MSTGNet_BodyOnly",
        "MSTGNet_FaceEyes",
        "MSTGNet_FaceBody",
        "MSTGNet_EyesBody",
    ]


def all_baseline_model_names() -> list:
    return ["MSTGNet"] + deep_learning_baseline_names() + traditional_ml_model_names()


def baseline_fold_result_files() -> list:
    files = []
    for model_name in all_baseline_model_names():
        for ds in DATASETS:
            files.append(OUTPUT_ROOT / "fold_results" / f"{model_name}_{ds}.csv")
    return files


def run_cv_resume_safe(
    *,
    dataset_name: str,
    model_name: str,
    model_factory,
    X_seq,
    y_seq,
    video_seq_ids,
    splits,
    seed: int,
    save_checkpoint: bool = True,
) -> pd.DataFrame:
    existing_path = fold_results_file(model_name, dataset_name)
    splits_to_run = mb.filter_completed_splits(
        splits,
        fold_results_path=existing_path,
        seed=seed,
    )

    df_new = pd.DataFrame()

    if len(splits_to_run) > 0:
        df_new = mb.run_cv_experiment(
            dataset_name=dataset_name,
            model_name=model_name,
            model_factory=model_factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_to_run,
            device=DEVICE,
            output_dir=OUTPUT_ROOT,
            batch_size=int(CONFIG["batch_size"]),
            epochs=int(CONFIG["epochs"]),
            patience=int(CONFIG["patience"]),
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            seed=seed,
            save_checkpoint=save_checkpoint,
        )
    else:
        print(f"{model_name} | {dataset_name}: all splits already complete.")

    if existing_path.exists():
        return pd.read_csv(existing_path)

    return df_new


def find_best_checkpoint(
    dataset_name: str,
    model_name: str = "MSTGNet",
    *,
    seed_whitelist=None,
    repeat_whitelist=None,
):
    path = OUTPUT_ROOT / "fold_results" / f"{model_name}_{dataset_name}.csv"

    return mb.select_checkpoint_validation_only(
        path,
        seed_whitelist=seed_whitelist,
        repeat_whitelist=repeat_whitelist,
        checkpoint_col="checkpoint_path",
    )


def standardize_table_for_paper_if_exists(table_name: str):
    path = OUTPUT_ROOT / "tables" / table_name
    if not path.exists():
        return

    df = pd.read_csv(path)
    if "model" in df.columns:
        df = mb.standardize_model_names_for_paper(df)
        df.to_csv(path, index=False)
        print(f"Standardized paper model names in: {path}")


# ============================================================
# Load processed datasets
# ============================================================

data_dict = {}

for ds in DATASETS:
    data_dict[ds] = mb.load_processed_dataset(
        ds,
        processed_dir=PROCESSED_DIR,
        expected_observed_features=1533,
        expected_active_features=1503,
    )


# ============================================================
# Dataset summary
# ============================================================

dataset_summary_rows = []

for ds, data in data_dict.items():
    video_ids, y = mb.get_video_labels_from_data(data)

    dataset_summary_rows.append(
        {
            "dataset": ds,
            "n_videos": int(len(video_ids)),
            "n_class_0": int(np.sum(y == 0)),
            "n_class_1": int(np.sum(y == 1)),
            "n_observed_features": int(len(data["coord_cols_observed"])),
            "n_active_features": int(len(data["coord_cols_active"])),
            "face_slice": str(data["active_modality_slices"].get("face")),
            "eyes_slice": str(data["active_modality_slices"].get("eyes")),
            "body_slice": str(data["active_modality_slices"].get("body")),
        }
    )

dataset_summary_df = pd.DataFrame(dataset_summary_rows)
save_table(dataset_summary_df, "dataset_summary.csv")
print(dataset_summary_df)


# ============================================================
# Splits
# ============================================================

splits_main = {}
splits_ablation = {}

for ds, data in data_dict.items():
    cvp = dataset_cv_params(ds)
    splits_main[ds] = make_or_load_splits(
        ds,
        data,
        n_splits=cvp["n_splits"],
        n_repeats=cvp["n_repeats"],
        seed=SEED,
        suffix="main",
    )

    canonical_path = (
        OUTPUT_ROOT
        / "config"
        / "splits"
        / f"{ds}_splits_CANONICAL_main_seed{SEED}.json"
    )
    mb.save_splits(splits_main[ds], canonical_path)

    splits_ablation[ds] = first_repeat_only(splits_main[ds])

print(
    {k: len(v) for k, v in splits_main.items()},
    {k: len(v) for k, v in splits_ablation.items()},
)

for ds in DATASETS:
    audit = mb.audit_video_split_overlap(splits_main[ds])
    print(ds)
    print(audit["status"].value_counts(dropna=False))
    assert (audit["status"] == "PASS").all(), audit

print("PASS: all main splits have no video-level overlap")


# ============================================================
# Sequence cache
# ============================================================

sequence_cache = {}


def get_sequences(dataset_name: str, *, seq_len=None, stride=None, cache_key=None):
    if seq_len is None:
        seq_len = int(CONFIG["sequence_length"])
    if stride is None:
        stride = int(CONFIG["stride"])

    if cache_key is None:
        cache_key = f"{dataset_name}_L{seq_len}_S{stride}"

    if cache_key in sequence_cache:
        return sequence_cache[cache_key]

    X_seq, y_seq, video_seq_ids = mb.prepare_sequences(
        data_dict[dataset_name],
        seq_len=int(seq_len),
        stride=int(stride),
        use_active_features=True,
        pad_short_videos=True,
        pad_mode="edge",
        verbose=True,
    )

    sequence_cache[cache_key] = (X_seq, y_seq, video_seq_ids)
    return X_seq, y_seq, video_seq_ids


# ============================================================
# Capacity check
# ============================================================

def capacity_factories_for_dataset(ds: str) -> dict:
    n_features = active_feature_dim(ds)
    hidden_dim = int(CONFIG["hidden_features"])
    dropout = dataset_dropout(ds)

    factories = {
        "MSTGNet": build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        ),
        "LSTM": mb.build_lstm_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            num_layers=1,
        ),
        "BiLSTM": mb.build_bilstm_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            num_layers=1,
        ),
        "GRU": mb.build_gru_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            num_layers=1,
        ),
        "CNN-LSTM": mb.build_cnn_lstm_factory(
            input_dim=n_features,
            hidden_dim=hidden_dim,
            dropout=dropout,
            conv_kernel_size=5,
            lstm_layers=1,
            use_batchnorm=True,
        ),
    }

    layers = sorted(set([4, 6, int(CONFIG["transformer_num_layers"])]))
    for layer in layers:
        factories[f"Transformer_L{layer}"] = build_transformer_for_dataset(
            ds,
            num_layers=layer,
        )

    return factories


if RUN_PRE_EXPERIMENT_CAPACITY_CHECK:
    capacity_rows = []

    for ds in DATASETS:
        cdf = mb.compute_model_capacity_table(capacity_factories_for_dataset(ds))
        cdf["dataset"] = ds

        param_col = get_param_column(cdf)
        if param_col is not None:
            mstg_params = cdf.loc[cdf["model"].eq("MSTGNet"), param_col]
            if len(mstg_params) == 1:
                ref = float(mstg_params.iloc[0])
                cdf["param_ratio_vs_MSTGNet_manual"] = cdf[param_col] / max(ref, 1.0)

        capacity_rows.append(cdf)

    capacity_check_df = (
        pd.concat(capacity_rows, ignore_index=True)
        if capacity_rows else pd.DataFrame()
    )

    capacity_path = OUTPUT_ROOT / "compute_cost" / "capacity_check_pre_S2.csv"
    capacity_check_df.to_csv(capacity_path, index=False)

    print(f"Saved pre-S2 capacity check: {capacity_path}")
    print(capacity_check_df)

    param_col = get_param_column(capacity_check_df)
    if param_col is not None:
        for ds in DATASETS:
            d = capacity_check_df[capacity_check_df["dataset"].eq(ds)].copy()
            if len(d) == 0:
                continue

            mstg = d.loc[d["model"].eq("MSTGNet"), param_col]
            tr_name = transformer_model_name()
            tr = d.loc[d["model"].eq(tr_name), param_col]

            if len(mstg) == 1 and len(tr) == 1:
                ratio = float(tr.iloc[0]) / max(float(mstg.iloc[0]), 1.0)
                if ratio < 0.5 or ratio > 2.0:
                    warnings.warn(
                        f"{ds}: {tr_name} capacity ratio vs MSTGNet is {ratio:.3f}. "
                        "Consider changing CONFIG['transformer_num_layers'] to 4 or 6.",
                        RuntimeWarning,
                    )


# ============================================================
# S1 preflight check
# ============================================================

if RUN_S1_PREFLIGHT_CHECK:
    print("\n" + "=" * 80)
    print("S1 PREFLIGHT CHECK")
    print("=" * 80)

    print("run_cv_experiment:", inspect.signature(mb.run_cv_experiment))
    print("build_mstgnet_factory:", inspect.signature(mb.build_mstgnet_factory))

    assert hasattr(mb, "dry_run_one_fold")
    assert hasattr(mb, "run_cv_experiment")
    assert hasattr(mb, "filter_completed_splits")
    assert hasattr(mb, "build_mstgnet_factory")

    for ds in DATASETS:
        assert ds in data_dict
        assert len(data_dict[ds]["coord_cols_active"]) == 1503
        assert "face" in data_dict[ds]["active_modality_slices"]
        assert "eyes" in data_dict[ds]["active_modality_slices"]
        assert "body" in data_dict[ds]["active_modality_slices"]

    print("PASS: S1 preflight checks OK")


# ============================================================
# S0 — Dry-run
# ============================================================

s0_outputs = {}

if RUN_S0_DRYRUN:
    for ds in DATASETS:
        print("\n" + "=" * 80)
        print(f"S0 Dry-run: {ds}")
        print("=" * 80)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        model_factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        row = mb.dry_run_one_fold(
            dataset_name=ds,
            model_name="MSTGNet",
            model_factory=model_factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_ablation[ds],
            device=DEVICE,
            output_dir=OUTPUT_ROOT / f"S0_dryrun_{ds}",
            batch_size=int(CONFIG["batch_size"]),
            epochs=2,
            patience=2,
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            seed=SEED,
        )

        dry_status = str(row.get("dry_run_status", "")).upper()
        gate_status = "PASS" if dry_status.startswith("PASS") else "FAIL"
        best_val_auc = row.get("best_val_auc", np.nan)

        out = {
            "gate_status": gate_status,
            "dry_run_status": dry_status,
            "fold_result": row,
            "gate_checks": {
                "dry_run_status_pass": bool(gate_status == "PASS"),
                "auc_gt_0_5_desirable_not_hard_gate": bool(
                    np.isfinite(best_val_auc) and float(best_val_auc) > 0.5
                ),
            },
        }

        s0_outputs[ds] = out

        print(f"{ds} gate_status:", out["gate_status"])
        print("dry_run_status:", out["dry_run_status"])
        print("gate_checks:", out["gate_checks"])

    print(s0_outputs)


if RUN_S0_DRYRUN and AUTO_RUN_S1_AFTER_S0_PASS:
    s0_pass = all(
        str(s0_outputs.get(ds, {}).get("gate_status", "")).upper() == "PASS"
        for ds in DATASETS
    )

    print("AUTO_RUN_S1_AFTER_S0_PASS:", AUTO_RUN_S1_AFTER_S0_PASS)
    print("S0 all PASS:", s0_pass)

    if s0_pass:
        RUN_S1_MAIN_CV = True
        CONFIRM_LONG_RUNS = True
        print("S0 passed for all datasets. Enabling RUN_S1_MAIN_CV=True.")
    else:
        RUN_S1_MAIN_CV = False
        print("S0 did not pass for all datasets. S1 will not run.")
elif AUTO_RUN_S1_AFTER_S0_PASS and not RUN_S0_DRYRUN:
    print(
        "AUTO_RUN_S1_AFTER_S0_PASS=True but RUN_S0_DRYRUN=False; "
        "auto S1 gate skipped. RUN_S1_MAIN_CV remains:",
        RUN_S1_MAIN_CV,
    )


# ============================================================
# S1 — Main CV: MSTGNet
# ============================================================

if RUN_S1_MAIN_CV:
    require_long_run("S1_MAIN_CV")

    s1_results = []

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S1 Main CV — MSTGNet Final — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        model_factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        df = run_cv_resume_safe(
            dataset_name=ds,
            model_name="MSTGNet",
            model_factory=model_factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_main[ds],
            seed=SEED,
            save_checkpoint=True,
        )

        s1_results.append(df)
        clean_memory()

        copy_if_exists(
            OUTPUT_ROOT / "fold_results" / f"MSTGNet_{ds}.csv",
            OUTPUT_ROOT / "fold_results" / f"main_{ds}.csv",
        )

        save_full_model_reference_for_ablation(ds)

        copy_if_exists(
            OUTPUT_ROOT / "predictions" / f"MSTGNet_{ds}_video_predictions.csv",
            OUTPUT_ROOT / "predictions" / f"main_{ds}_video_predictions.csv",
        )

    s1_all = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "MSTGNet_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "MSTGNet_RLT.csv",
    ])
    s1_all = drop_duplicate_fold_rows(s1_all)

    summarize_results(s1_all, output_name="main_results_summary.csv")
    print(s1_all)


# ============================================================
# S2 — Baselines: DL baselines + Traditional ML
# ============================================================

if RUN_S2_BASELINES:
    require_long_run("S2_BASELINES")

    s2_results = []

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S2 — Deep Learning Baselines — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        df_dl = mb.run_deep_learning_baselines(
            dataset_name=ds,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_main[ds],
            device=DEVICE,
            output_dir=OUTPUT_ROOT,
            input_dim=active_feature_dim(ds),
            hidden_dim=int(CONFIG["hidden_features"]),
            num_heads=int(CONFIG["num_heads"]),
            transformer_num_layers=int(CONFIG["transformer_num_layers"]),
            dropout=dataset_dropout(ds),
            cnn_lstm_use_batchnorm=True,
            batch_size=int(CONFIG["batch_size"]),
            epochs=int(CONFIG["epochs"]),
            patience=int(CONFIG["patience"]),
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            seed=SEED,
            save_checkpoint=True,
            model_whitelist=deep_learning_baseline_names(),
        )
        s2_results.append(df_dl)
        clean_memory()

        print("\n" + "#" * 90)
        print(f"S2 — Traditional ML temporal-stat — {ds}")
        print("#" * 90)

        df_ml = mb.run_traditional_ml_baseline(
            dataset_name=ds,
            data=data_dict[ds],
            splits=splits_main[ds],
            output_dir=OUTPUT_ROOT,
            seed=SEED,
            feature_mode="temporal_stat",
        )
        s2_results.append(df_ml)
        clean_memory()

    baseline_all = combine_fold_results(baseline_fold_result_files())
    baseline_all = drop_duplicate_fold_rows(baseline_all)

    summarize_results(
        baseline_all,
        output_name="table_baseline_comparison.csv",
    )

    baseline_all.to_csv(
        OUTPUT_ROOT / "tables" / "baseline_fold_results_all.csv",
        index=False,
    )
    print(baseline_all)


# ============================================================
# S3 — Architecture ablation
# ============================================================

if RUN_S3_ARCH_ABLATION:
    require_long_run("S3_ARCH_ABLATION")

    for ds in DATASETS:
        require_full_model_reference(ds)

    arch_variants = {
        "MSTGNet_NoGraph": {
            "use_graph": False,
            "use_temporal": True,
            "use_pooling": True,
            "use_cross_modal": False,
        },
        "MSTGNet_NoTemporal": {
            "use_graph": True,
            "use_temporal": False,
            "use_pooling": True,
            "use_cross_modal": False,
        },
        "MSTGNet_NoPooling": {
            "use_graph": True,
            "use_temporal": True,
            "use_pooling": False,
            "use_cross_modal": False,
        },
        "MSTGNet_CrossModalAblation": {
            "use_graph": True,
            "use_temporal": True,
            "use_pooling": True,
            "use_cross_modal": True,
        },
    }

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S3 Architecture Ablation — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)
        ab_splits = splits_ablation[ds]

        for model_name, kwargs in arch_variants.items():
            print("\n" + "-" * 70)
            print(f"{model_name} — {ds}")
            print("-" * 70)

            factory = build_mstgnet_for_dataset(
                ds,
                data_dict[ds],
                use_graph=kwargs["use_graph"],
                use_temporal=kwargs["use_temporal"],
                use_pooling=kwargs["use_pooling"],
                use_cross_modal=kwargs["use_cross_modal"],
                enabled_modalities=("face", "eyes", "body"),
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name=model_name,
                model_factory=factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=ab_splits,
                seed=SEED,
                save_checkpoint=True,
            )
            clean_memory()

    arch_files = [
        OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "full_model_reference_RLT.csv",
    ]
    for model_name in architecture_ablation_model_names():
        for ds in DATASETS:
            arch_files.append(OUTPUT_ROOT / "fold_results" / f"{model_name}_{ds}.csv")

    arch_all = combine_fold_results(arch_files)
    arch_all = drop_duplicate_fold_rows(arch_all)

    summarize_results(
        arch_all,
        output_name="table_architecture_ablation.csv",
    )

    arch_all.to_csv(
        OUTPUT_ROOT / "fold_results" / "arch_ablation_all.csv",
        index=False,
    )
    print(arch_all)


# ============================================================
# S3B — Temporal sensitivity
# ============================================================

if RUN_S3B_TEMPORAL_SENSITIVITY:
    require_long_run("S3B_TEMPORAL_SENSITIVITY")
    require_full_model_reference("I3D")

    ds = "I3D"

    temporal_settings = [
        {"name": "MSTGNet_Window100", "seq_len": 100, "stride": 50},
    ]

    for setting in temporal_settings:
        print("\n" + "#" * 90)
        print(f"S3B Temporal Sensitivity — {setting['name']} — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(
            ds,
            seq_len=setting["seq_len"],
            stride=setting["stride"],
            cache_key=f"{ds}_L{setting['seq_len']}_S{setting['stride']}",
        )

        factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        _ = run_cv_resume_safe(
            dataset_name=ds,
            model_name=setting["name"],
            model_factory=factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            splits=splits_ablation[ds],
            seed=SEED,
            save_checkpoint=True,
        )
        clean_memory()

    temporal_all = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "MSTGNet_Window100_I3D.csv",
    ])
    temporal_all = drop_duplicate_fold_rows(temporal_all)

    summarize_results(
        temporal_all,
        output_name="table_temporal_sensitivity.csv",
    )

    temporal_all.to_csv(
        OUTPUT_ROOT / "fold_results" / "temporal_sensitivity_all.csv",
        index=False,
    )
    print(temporal_all)


# ============================================================
# S4 — Modality ablation
# ============================================================

if RUN_S4_MODAL_ABLATION:
    require_long_run("S4_MODAL_ABLATION")

    for ds in DATASETS:
        require_full_model_reference(ds)

    modality_variants = {
        "MSTGNet_FaceOnly": ("face",),
        "MSTGNet_EyesOnly": ("eyes",),
        "MSTGNet_BodyOnly": ("body",),
        "MSTGNet_FaceEyes": ("face", "eyes"),
        "MSTGNet_FaceBody": ("face", "body"),
        "MSTGNet_EyesBody": ("eyes", "body"),
    }

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S4 Modality Ablation — {ds}")
        print("#" * 90)

        X_seq, y_seq, video_seq_ids = get_sequences(ds)
        ab_splits = splits_ablation[ds]

        for model_name, modalities in modality_variants.items():
            print("\n" + "-" * 70)
            print(f"{model_name} modalities={modalities} — {ds}")
            print("-" * 70)

            factory = build_mstgnet_for_dataset(
                ds,
                data_dict[ds],
                use_graph=True,
                use_temporal=True,
                use_pooling=True,
                use_cross_modal=False,
                enabled_modalities=modalities,
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name=model_name,
                model_factory=factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=ab_splits,
                seed=SEED,
                save_checkpoint=True,
            )
            clean_memory()

    modal_files = [
        OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "full_model_reference_RLT.csv",
    ]
    for model_name in modality_ablation_model_names():
        for ds in DATASETS:
            modal_files.append(OUTPUT_ROOT / "fold_results" / f"{model_name}_{ds}.csv")

    modal_all = combine_fold_results(modal_files)
    modal_all = drop_duplicate_fold_rows(modal_all)

    summarize_results(
        modal_all,
        output_name="table_modality_ablation.csv",
    )

    modal_all.to_csv(
        OUTPUT_ROOT / "fold_results" / "modal_ablation_all.csv",
        index=False,
    )
    print(modal_all)


# ============================================================
# S5 — Landmark quality
# ============================================================

if RUN_S5_LANDMARK_QUALITY:
    quality_dfs = []

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S5 Landmark Quality — {ds}")
        print("#" * 90)

        qdf = mb.compute_landmark_quality_table(
            data_dict[ds],
            dataset_name=ds,
            use_active_features=True,
            long_format=True,
        )
        quality_dfs.append(qdf)

    quality_all = (
        pd.concat(quality_dfs, ignore_index=True)
        if quality_dfs else pd.DataFrame()
    )

    quality_path = OUTPUT_ROOT / "landmark_quality" / "quality_by_video.csv"
    quality_all.to_csv(quality_path, index=False)
    print(f"Saved landmark quality table: {quality_path} shape={quality_all.shape}")

    if len(quality_all) > 0:
        quality_summary = (
            quality_all
            .groupby(["dataset", "modality"], dropna=False)
            .agg(
                n_videos=("video_id", "nunique"),
                finite_rate_mean=("finite_rate", "mean"),
                finite_rate_std=("finite_rate", "std"),
                nonfinite_rate_mean=("nonfinite_rate", "mean"),
                nonfinite_rate_std=("nonfinite_rate", "std"),
                zero_rate_mean=("zero_rate", "mean"),
                zero_rate_std=("zero_rate", "std"),
                mean_abs_value_mean=("mean_abs_value", "mean"),
                mean_abs_value_std=("mean_abs_value", "std"),
                std_abs_value_mean=("std_abs_value", "mean"),
                std_abs_value_std=("std_abs_value", "std"),
                mean_abs_velocity_mean=("mean_abs_velocity", "mean"),
                mean_abs_velocity_std=("mean_abs_velocity", "std"),
                std_abs_velocity_mean=("std_abs_velocity", "mean"),
                std_abs_velocity_std=("std_abs_velocity", "std"),
                p95_abs_velocity_mean=("p95_abs_velocity", "mean"),
                p95_abs_velocity_std=("p95_abs_velocity", "std"),
            )
            .reset_index()
        )
    else:
        quality_summary = pd.DataFrame()

    save_table(quality_summary, "table_landmark_quality.csv")
    print(quality_summary)

    quality_corr_dfs = []

    for ds in DATASETS:
        pred_path = OUTPUT_ROOT / "predictions" / f"MSTGNet_{ds}_video_predictions.csv"

        if not pred_path.exists():
            print(f"Skip quality-prediction correlation for {ds}; missing: {pred_path}")
            continue

        if len(quality_all) == 0:
            print(f"Skip quality-prediction correlation for {ds}; quality_all empty.")
            continue

        pred_df = pd.read_csv(pred_path)
        q_ds = quality_all[quality_all["dataset"].astype(str) == str(ds)].copy()

        if len(q_ds) == 0:
            print(f"Skip quality-prediction correlation for {ds}; no quality rows.")
            continue

        corr_df = mb.compute_landmark_quality_prediction_correlation(
            q_ds,
            pred_df,
            prediction_split="test",
            model_filter="MSTGNet",
            aggregate_predictions_per_video=True,
        )

        corr_df["dataset_requested"] = ds
        quality_corr_dfs.append(corr_df)

        corr_path = (
            OUTPUT_ROOT
            / "landmark_quality"
            / f"quality_prediction_correlation_{ds}.csv"
        )
        corr_df.to_csv(corr_path, index=False)
        print(f"Quality-prediction correlation {ds}: {corr_path} shape={corr_df.shape}")

    quality_corr_all = (
        pd.concat(quality_corr_dfs, ignore_index=True)
        if quality_corr_dfs else pd.DataFrame()
    )

    quality_corr_all.to_csv(
        OUTPUT_ROOT / "landmark_quality" / "quality_prediction_correlation_all.csv",
        index=False,
    )

    save_table(
        quality_corr_all,
        "table_landmark_quality_prediction_correlation.csv",
    )


# ============================================================
# S6 — Cross-dataset generalization
# ============================================================

if RUN_S6_CROSS_DATASET:
    require_long_run("S6_CROSS_DATASET")

    s6_pairs = [
        ("I3D", "RLT"),
        ("RLT", "I3D"),
    ]

    s6_results = []

    for source_ds, target_ds in s6_pairs:
        print("\n" + "#" * 90)
        print(f"S6 Cross-Dataset: {source_ds} -> {target_ds}")
        print("#" * 90)

        print("\n" + "-" * 70)
        print(f"S6A MSTGNet source-only: {source_ds} -> {target_ds}")
        print("-" * 70)

        source_model_factory = build_mstgnet_for_dataset(
            source_ds,
            data_dict[source_ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        df_mstg_source_only = mb.run_cross_dataset_mstgnet_source_only(
            source_dataset_name=source_ds,
            target_dataset_name=target_ds,
            source_data=data_dict[source_ds],
            target_data=data_dict[target_ds],
            target_splits=splits_ablation[target_ds],
            model_factory=source_model_factory,
            device=DEVICE,
            output_dir=OUTPUT_ROOT,
            seed=SEED,
            source_val_ratio=0.2,
            seq_len=int(CONFIG["sequence_length"]),
            stride=int(CONFIG["stride"]),
            batch_size=int(CONFIG["batch_size"]),
            epochs=int(CONFIG["epochs"]),
            patience=int(CONFIG["patience"]),
            lr=float(CONFIG["lr"]),
            weight_decay=float(CONFIG["weight_decay"]),
            gradient_clip=5.0,
            num_workers=0,
            model_name="MSTGNet_SourceOnly",
            save_checkpoint=True,
        )

        s6_results.append(df_mstg_source_only)
        clean_memory()

        print("\n" + "-" * 70)
        print(f"S6B Traditional ML source-only/CORAL: {source_ds} -> {target_ds}")
        print("-" * 70)

        df_trad_cd = mb.run_cross_dataset_methods(
            source_dataset_name=source_ds,
            target_dataset_name=target_ds,
            source_data=data_dict[source_ds],
            target_data=data_dict[target_ds],
            target_splits=splits_ablation[target_ds],
            output_dir=OUTPUT_ROOT,
            seed=SEED,
            source_val_ratio=0.2,
            models=mb.default_traditional_ml_models(seed=SEED),
            run_coral=True,
            coral_mode="diagonal",
            feature_mode="temporal_stat",
        )

        s6_results.append(df_trad_cd)
        clean_memory()

    s6_all = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "*_to_*.csv",
    ])
    s6_all = drop_duplicate_fold_rows(s6_all)

    save_table(s6_all, "table_cross_dataset.csv")
    s6_all.to_csv(
        OUTPUT_ROOT / "cross_dataset" / "cross_dataset_all_fold_results.csv",
        index=False,
    )

    print(s6_all)


# ============================================================
# S7 — Multi-seed robustness
# ============================================================

if RUN_S7_MULTI_SEED:
    require_long_run("S7_MULTI_SEED")

    tr_name = transformer_model_name()
    extra_seeds = [s for s in CONFIG["multiseeds"] if int(s) != 42]

    for seed in extra_seeds:
        seed = int(seed)

        print("\n" + "#" * 90)
        print(f"S7 Multi-seed additional seed={seed}")
        print("#" * 90)

        for ds in DATASETS:
            print("\n" + "=" * 80)
            print(f"S7 — {ds} — seed={seed}")
            print("=" * 80)

            X_seq, y_seq, video_seq_ids = get_sequences(ds)

            mstg_factory = build_mstgnet_for_dataset(
                ds,
                data_dict[ds],
                use_graph=True,
                use_temporal=True,
                use_pooling=True,
                use_cross_modal=False,
                enabled_modalities=("face", "eyes", "body"),
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name="MSTGNet",
                model_factory=mstg_factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=splits_main[ds],
                seed=seed,
                save_checkpoint=True,
            )
            clean_memory()

            transformer_factory = build_transformer_for_dataset(
                ds,
                num_layers=int(CONFIG["transformer_num_layers"]),
            )

            _ = run_cv_resume_safe(
                dataset_name=ds,
                model_name=tr_name,
                model_factory=transformer_factory,
                X_seq=X_seq,
                y_seq=y_seq,
                video_seq_ids=video_seq_ids,
                splits=splits_main[ds],
                seed=seed,
                save_checkpoint=True,
            )
            clean_memory()

    multiseed_df = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "MSTGNet_I3D.csv",
        OUTPUT_ROOT / "fold_results" / "MSTGNet_RLT.csv",
        OUTPUT_ROOT / "fold_results" / f"{tr_name}_I3D.csv",
        OUTPUT_ROOT / "fold_results" / f"{tr_name}_RLT.csv",
    ])
    multiseed_df = drop_duplicate_fold_rows(multiseed_df)

    multiseed_df.to_csv(
        OUTPUT_ROOT / "stats" / "multiseed_results.csv",
        index=False,
    )

    stat_rows = []
    stat_json = {}

    for ds in DATASETS:
        wilcoxon_result = mb.wilcoxon_signed_rank_test(
            multiseed_df,
            model_a="MSTGNet",
            model_b=tr_name,
            metric="test_auc",
            dataset=ds,
        )

        ttest_result = mb.paired_ttest(
            multiseed_df,
            model_a="MSTGNet",
            model_b=tr_name,
            metric="test_auc",
            dataset=ds,
        )

        stat_json[ds] = {
            "wilcoxon_mstgnet_vs_transformer": wilcoxon_result,
            "paired_ttest_mstgnet_vs_transformer": ttest_result,
        }

        stat_rows.append(
            {
                "dataset": ds,
                "metric": "test_auc",
                "model_a": "MSTGNet",
                "model_b": tr_name,
                "wilcoxon_p_value": wilcoxon_result.get("p_value", np.nan),
                "wilcoxon_n_pairs": wilcoxon_result.get("n_pairs", np.nan),
                "paired_ttest_p_value": ttest_result.get("p_value", np.nan),
                "paired_ttest_n_pairs": ttest_result.get("n_pairs", np.nan),
                "mean_diff_mstgnet_minus_transformer": wilcoxon_result.get(
                    "mean_diff_a_minus_b",
                    np.nan,
                ),
            }
        )

    stats_df = pd.DataFrame(stat_rows)
    stats_df.to_csv(
        OUTPUT_ROOT / "stats" / "statistical_tests_summary.csv",
        index=False,
    )

    multiseed_summary = mb.summarize_cv_results(
        multiseed_df,
        metric_cols=[
            "test_auc",
            "test_accuracy",
            "test_balanced_accuracy",
            "test_mcc",
            "test_f1",
        ],
        group_cols=["dataset", "model"],
    )

    save_table(multiseed_summary, "table_multiseed_robustness.csv")

    repeat_ci_metrics = [
        "test_auc",
        "test_f1",
        "test_mcc",
        "test_balanced_accuracy",
    ]

    repeat_ci_path = mb.save_repeat_level_ci_table(
        multiseed_df,
        OUTPUT_ROOT,
        filename="repeat_level_ci_multiseed.csv",
        metrics=repeat_ci_metrics,
        group_cols=["dataset", "model"],
        ci=0.95,
    )
    print(f"Saved repeat-level CI table: {repeat_ci_path}")

    for ds in DATASETS:
        ds_df = multiseed_df[multiseed_df["dataset"].astype(str) == str(ds)].copy()

        if len(ds_df) == 0:
            print(f"Skip repeat-level CI for {ds}: no data.")
            continue

        n_repeats_available = (
            int(ds_df["repeat"].nunique())
            if "repeat" in ds_df.columns else 1
        )
        print(f"\n{ds}: n_repeats_available={n_repeats_available}")

        ds_ci_parts = []

        for metric in repeat_ci_metrics:
            ci_df = mb.compute_repeat_level_ci(
                ds_df,
                metric=metric,
                group_cols=["dataset", "model"],
                ci=0.95,
            )

            if ci_df is not None and len(ci_df) > 0:
                ci_df["n_repeats_available"] = n_repeats_available
                ds_ci_parts.append(ci_df)

        ds_ci_all = (
            pd.concat(ds_ci_parts, ignore_index=True)
            if ds_ci_parts else pd.DataFrame()
        )

        ds_ci_path = OUTPUT_ROOT / "stats" / f"repeat_level_ci_{ds}.csv"
        ds_ci_all.to_csv(ds_ci_path, index=False)
        print(f"  Saved: {ds_ci_path} shape={ds_ci_all.shape}")

        preview_cols = [
            "dataset",
            "model",
            "metric",
            "repeat_n",
            "mean",
            "ci_low",
            "ci_high",
        ]
        existing_preview_cols = [c for c in preview_cols if c in ds_ci_all.columns]

        if len(ds_ci_all) > 0 and len(existing_preview_cols) > 0:
            print(ds_ci_all[existing_preview_cols].to_string(index=False))

    repeat_ci_all_parts = []

    for ds in DATASETS:
        p = OUTPUT_ROOT / "stats" / f"repeat_level_ci_{ds}.csv"
        if p.exists():
            repeat_ci_all_parts.append(pd.read_csv(p))

    repeat_ci_all = (
        pd.concat(repeat_ci_all_parts, ignore_index=True)
        if repeat_ci_all_parts else pd.DataFrame()
    )

    repeat_ci_all.to_csv(
        OUTPUT_ROOT / "stats" / "repeat_level_ci_all_datasets.csv",
        index=False,
    )

    save_table(repeat_ci_all, "table_repeat_level_ci.csv")
    print(f"\nRepeat-level CI all datasets: {repeat_ci_all.shape}")

    all_results_for_stats = combine_fold_results(baseline_fold_result_files())
    all_results_for_stats = drop_duplicate_fold_rows(all_results_for_stats)

    if len(all_results_for_stats) > 0:
        full_comparison_df = mb.compare_models_statistically(
            all_results_for_stats,
            reference_model="MSTGNet",
            metric="test_auc",
            adjust_pvalues=True,
        )

        full_comparison_df.to_csv(
            OUTPUT_ROOT / "stats" / "statistical_comparison_all_models.csv",
            index=False,
        )

        save_table(full_comparison_df, "table_statistical_comparison.csv")

        stat_json["all_model_comparison_note"] = (
            "Full comparison computed against all available paired fold results "
            "from baseline_fold_result_files(). Pairing uses dataset/seed/repeat/fold."
        )
    else:
        full_comparison_df = pd.DataFrame()
        warnings.warn(
            "No baseline fold results available for full statistical comparison.",
            RuntimeWarning,
        )

    mb.safe_json_dump(
        stat_json,
        OUTPUT_ROOT / "stats" / "statistical_tests.json",
    )

    print(stats_df)
    print(full_comparison_df)


# ============================================================
# S8 — Computational cost
# ============================================================

if RUN_S8_COMPUTE_COST:
    cost_sources = combine_fold_results([
        OUTPUT_ROOT / "fold_results" / "*.csv",
    ])
    cost_sources = drop_duplicate_fold_rows(cost_sources)

    cost_models = [
        "MSTGNet",
        "LSTM",
        "BiLSTM",
        "GRU",
        "CNN-LSTM",
        transformer_model_name(),
        "LogReg_temporal_stat",
        "RF_temporal_stat",
        "SVM_temporal_stat",
        "GradBoost_temporal_stat",
        "MSTGNet_NoGraph",
        "MSTGNet_NoTemporal",
        "MSTGNet_NoPooling",
        "MSTGNet_CrossModalAblation",
        "MSTGNet_FaceOnly",
        "MSTGNet_EyesOnly",
        "MSTGNet_BodyOnly",
        "MSTGNet_FaceEyes",
        "MSTGNet_FaceBody",
        "MSTGNet_EyesBody",
        "MSTGNet_Window100",
    ]

    cost_models += cross_dataset_model_names()

    if "model" in cost_sources.columns:
        cost_sources = cost_sources[cost_sources["model"].isin(cost_models)].copy()

    keep_cols = [
        "dataset",
        "source_dataset",
        "target_dataset",
        "model",
        "seed",
        "repeat",
        "fold",
        "n_params",
        "n_trainable_params",
        "n_total_params",
        "train_time_sec",
        "ms_per_batch",
        "ms_per_sequence",
        "ms_per_video",
        "n_train_seq",
        "n_val_seq",
        "n_test_seq",
        "n_train_videos",
        "n_val_videos",
        "n_test_videos",
        "n_source_train_videos",
        "n_source_val_videos",
        "n_target_adapt_videos",
        "n_target_test_videos",
    ]

    if len(cost_sources) > 0:
        existing_cols = [c for c in keep_cols if c in cost_sources.columns]
        cost_fold = cost_sources[existing_cols].copy()
    else:
        cost_fold = pd.DataFrame(columns=keep_cols)

    cost_fold.to_csv(
        OUTPUT_ROOT / "compute_cost" / "cost_table.csv",
        index=False,
    )

    param_col = get_param_column(cost_fold)

    if len(cost_fold) > 0:
        agg_kwargs = {
            "n_folds": ("fold", "count"),
            "train_time_sec_mean": ("train_time_sec", "mean"),
            "train_time_sec_std": ("train_time_sec", "std"),
            "ms_per_video_mean": ("ms_per_video", "mean"),
            "ms_per_video_std": ("ms_per_video", "std"),
            "ms_per_sequence_mean": ("ms_per_sequence", "mean"),
            "ms_per_sequence_std": ("ms_per_sequence", "std"),
        }

        if param_col is not None:
            agg_kwargs["n_params_mean"] = (param_col, "mean")
            agg_kwargs["n_params_median"] = (param_col, "median")

        cost_summary = (
            cost_fold
            .groupby(["dataset", "model"], dropna=False)
            .agg(**agg_kwargs)
            .reset_index()
        )
    else:
        cost_summary = pd.DataFrame()

    save_table(cost_summary, "table_computational_cost.csv")

    capacity_rows = []

    for ds in DATASETS:
        cdf = mb.compute_model_capacity_table(capacity_factories_for_dataset(ds))
        cdf["dataset"] = ds
        capacity_rows.append(cdf)

    capacity_df = (
        pd.concat(capacity_rows, ignore_index=True)
        if capacity_rows else pd.DataFrame()
    )

    capacity_df.to_csv(
        OUTPUT_ROOT / "compute_cost" / "model_capacity_table.csv",
        index=False,
    )

    print(capacity_df)


# ============================================================
# S9 — Calibration export
# ============================================================

if RUN_S9_CALIBRATION_EXPORT:
    pred_files = sorted((OUTPUT_ROOT / "predictions").glob("*video_predictions.csv"))

    pred_dfs = []

    for p in pred_files:
        try:
            d = pd.read_csv(p)
            d["source_file"] = str(p)
            pred_dfs.append(d)
        except Exception as e:
            warnings.warn(f"Could not read {p}: {e}", RuntimeWarning)

    pred_all = pd.concat(pred_dfs, ignore_index=True) if pred_dfs else pd.DataFrame()
    pred_all = drop_duplicate_prediction_rows(pred_all)

    pred_all.to_csv(
        OUTPUT_ROOT / "figures_data" / "all_video_predictions_for_calibration.csv",
        index=False,
    )

    if len(pred_all) > 0:
        cal_summary = (
            pred_all
            .groupby(["dataset", "model", "split"], dropna=False)
            .agg(
                n=("video_id", "count"),
                mean_y_true=("y_true", "mean"),
                mean_y_prob=("y_prob", "mean"),
                threshold_mean=("threshold", "mean"),
            )
            .reset_index()
        )
    else:
        cal_summary = pd.DataFrame()

    save_table(cal_summary, "table_calibration_prediction_summary.csv")
    print(cal_summary)


# ============================================================
# S10 — Interpretability
# ============================================================

if RUN_S10_INTERPRETABILITY:
    require_long_run("S10_INTERPRETABILITY")

    for ds in DATASETS:
        print("\n" + "#" * 90)
        print(f"S10 Interpretability — {ds}")
        print("#" * 90)

        ckpt_path = find_best_checkpoint(
            ds,
            "MSTGNet",
            seed_whitelist=[43, 44, 45, 46, 47],
            repeat_whitelist=[1],
        )

        if ckpt_path is None:
            print(f"{ds}: no checkpoint with seed_whitelist=[43..47], trying repeat=1 only.")
            ckpt_path = find_best_checkpoint(
                ds,
                "MSTGNet",
                repeat_whitelist=[1],
            )

        if ckpt_path is None:
            print(f"{ds}: no checkpoint with repeat=1 filter, trying no filter.")
            ckpt_path = find_best_checkpoint(
                ds,
                "MSTGNet",
            )

        if ckpt_path is None:
            warnings.warn(f"No checkpoint found for interpretability: {ds}", RuntimeWarning)
            continue

        factory = build_mstgnet_for_dataset(
            ds,
            data_dict[ds],
            use_graph=True,
            use_temporal=True,
            use_pooling=True,
            use_cross_modal=False,
            enabled_modalities=("face", "eyes", "body"),
        )

        X_seq, y_seq, video_seq_ids = get_sequences(ds)

        ckpt = safe_torch_load_checkpoint_local(ckpt_path, map_location="cpu")
        split = ckpt.get("split", ckpt.get("source_split", {}))
        split_videos = split.get("val_videos", None)

        imp_df = mb.compute_gradient_importance_from_checkpoint(
            checkpoint_path=ckpt_path,
            model_factory=factory,
            X_seq=X_seq,
            y_seq=y_seq,
            video_seq_ids=video_seq_ids,
            device=DEVICE,
            feature_names=data_dict[ds].get("coord_cols_active", None),
            modality_slices=data_dict[ds].get("active_modality_slices", None),
            split_videos=split_videos,
            batch_size=int(CONFIG["batch_size"]),
            max_sequences=2048,
            seed=SEED,
        )

        if imp_df is None or len(imp_df) == 0:
            warnings.warn(
                f"Empty importance dataframe for {ds}: {ckpt_path}",
                RuntimeWarning,
            )
            continue

        suffix = (
            f"seed{imp_df['seed'].iloc[0]}"
            f"_rep{imp_df['repeat'].iloc[0]}"
            f"_fold{imp_df['fold'].iloc[0]}"
        )

        paths = mb.save_gradient_importance(
            imp_df,
            OUTPUT_ROOT,
            dataset_name=ds,
            model_name="MSTGNet",
            top_k=100,
            suffix=suffix,
        )

        print("Saved gradient importance:", paths)

        imp_df.to_csv(
            OUTPUT_ROOT / "interpretability" / f"{ds}_MSTGNet_gradient_importance_all.csv",
            index=False,
        )

        clean_memory()


# ============================================================
# S11 — Export paper tables
# ============================================================

if RUN_S11_EXPORT_PAPER_TABLES:
    if not (OUTPUT_ROOT / "tables" / "table_baseline_comparison.csv").exists():
        baseline_all = combine_fold_results(baseline_fold_result_files())
        baseline_all = drop_duplicate_fold_rows(baseline_all)
        summarize_results(baseline_all, output_name="table_baseline_comparison.csv")

    for table_name in [
        "table_baseline_comparison.csv",
        "table_modality_ablation.csv",
        "table_architecture_ablation.csv",
        "table_multiseed_robustness.csv",
        "table_cross_dataset.csv",
        "table_computational_cost.csv",
        "table_temporal_sensitivity.csv",
        "table_statistical_comparison.csv",
        "table_landmark_quality_prediction_correlation.csv",
        "table_repeat_level_ci.csv",
    ]:
        standardize_table_for_paper_if_exists(table_name)

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "dataset_summary.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table1_dataset_summary.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_baseline_comparison.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table2_baseline_comparison.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_modality_ablation.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table3_modality_ablation.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_architecture_ablation.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table4_architecture_ablation.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_multiseed_robustness.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table5_multiseed_robustness.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_cross_dataset.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table6_cross_dataset.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_landmark_quality.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table7_landmark_quality.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_computational_cost.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table8_computational_cost.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_temporal_sensitivity.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table9_temporal_sensitivity.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_statistical_comparison.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table10_statistical_comparison.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_landmark_quality_prediction_correlation.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table11_landmark_quality_prediction_correlation.csv",
    )

    copy_if_exists(
        OUTPUT_ROOT / "tables" / "table_repeat_level_ci.csv",
        OUTPUT_ROOT / "tables" / "PAPER_Table12_repeat_level_ci.csv",
    )

    paper_tables = sorted((OUTPUT_ROOT / "tables").glob("PAPER_Table*.csv"))

    paper_index = pd.DataFrame(
        {
            "paper_table": [p.name for p in paper_tables],
            "path": [str(p) for p in paper_tables],
            "exists": [p.exists() for p in paper_tables],
        }
    )

    paper_index.to_csv(
        OUTPUT_ROOT / "tables" / "PAPER_Table_index.csv",
        index=False,
    )

    print(paper_index)


# ============================================================
# Final checklist
# ============================================================

final_files = {
    "manifest": OUTPUT_ROOT / "config" / "experiment_manifest.json",
    "dataset_summary": OUTPUT_ROOT / "tables" / "dataset_summary.csv",
    "capacity_check_pre_S2": OUTPUT_ROOT / "compute_cost" / "capacity_check_pre_S2.csv",
    "main_I3D": OUTPUT_ROOT / "fold_results" / "main_I3D.csv",
    "main_RLT": OUTPUT_ROOT / "fold_results" / "main_RLT.csv",
    "full_ref_I3D": OUTPUT_ROOT / "fold_results" / "full_model_reference_I3D.csv",
    "full_ref_RLT": OUTPUT_ROOT / "fold_results" / "full_model_reference_RLT.csv",
    "baseline_table": OUTPUT_ROOT / "tables" / "table_baseline_comparison.csv",
    "arch_table": OUTPUT_ROOT / "tables" / "table_architecture_ablation.csv",
    "modal_table": OUTPUT_ROOT / "tables" / "table_modality_ablation.csv",
    "landmark_table": OUTPUT_ROOT / "tables" / "table_landmark_quality.csv",
    "landmark_prediction_corr": OUTPUT_ROOT / "tables" / "table_landmark_quality_prediction_correlation.csv",
    "cross_dataset_table": OUTPUT_ROOT / "tables" / "table_cross_dataset.csv",
    "compute_cost_table": OUTPUT_ROOT / "tables" / "table_computational_cost.csv",
    "temporal_sensitivity_table": OUTPUT_ROOT / "tables" / "table_temporal_sensitivity.csv",
    "multiseed_stats": OUTPUT_ROOT / "stats" / "statistical_tests.json",
    "statistical_comparison": OUTPUT_ROOT / "stats" / "statistical_comparison_all_models.csv",
    "repeat_level_ci_I3D": OUTPUT_ROOT / "stats" / "repeat_level_ci_I3D.csv",
    "repeat_level_ci_RLT": OUTPUT_ROOT / "stats" / "repeat_level_ci_RLT.csv",
    "repeat_level_ci_all": OUTPUT_ROOT / "stats" / "repeat_level_ci_all_datasets.csv",
    "repeat_level_ci_multiseed": OUTPUT_ROOT / "tables" / "repeat_level_ci_multiseed.csv",
    "repeat_level_ci_table": OUTPUT_ROOT / "tables" / "table_repeat_level_ci.csv",
    "paper_table_index": OUTPUT_ROOT / "tables" / "PAPER_Table_index.csv",
    "paper_table12_repeat_ci": OUTPUT_ROOT / "tables" / "PAPER_Table12_repeat_level_ci.csv",
    "interpretability_dir": OUTPUT_ROOT / "interpretability",
}

final_check = pd.DataFrame(
    {
        "item": list(final_files.keys()),
        "path": [str(p) for p in final_files.values()],
        "exists": [Path(p).exists() for p in final_files.values()],
    }
)

final_check.to_csv(
    OUTPUT_ROOT / "tables" / "final_file_checklist.csv",
    index=False,
)

print(final_check)
# Out:
# Using device: cuda
# OUTPUT_ROOT: outputs\revision_final_20260501
# DEVICE: cuda
# PASS: model_base API compatible with notebook
# Loading processed dataset: data\processed\mstgnet_I3D.pkl
# ✓ I3D loaded
#   Videos: 1568
#   Observed features: 1533
#   Active features:   1503
#   Active slices:     {'face': [0, 1374], 'eyes': [1374, 1404], 'body': [1404, 1503]}
# Loading processed dataset: data\processed\mstgnet_RLT.pkl
# ✓ RLT loaded
#   Videos: 121
#   Observed features: 1533
#   Active features:   1503
#   Active slices:     {'face': [0, 1374], 'eyes': [1374, 1404], 'body': [1404, 1503]}
# Saved table: outputs\revision_final_20260501\tables\dataset_summary.csv shape=(2, 9)
#   dataset  n_videos  n_class_0  n_class_1  n_observed_features  \
# 0     I3D      1568        784        784                 1533
# 1     RLT       121         60         61                 1533
#
#    n_active_features face_slice    eyes_slice    body_slice
# 0               1503  [0, 1374]  [1374, 1404]  [1404, 1503]
# 1               1503  [0, 1374]  [1374, 1404]  [1404, 1503]
# Loading existing splits: outputs\revision_final_20260501\config\splits\I3D_splits_main_seed42.json
# Loading existing splits: outputs\revision_final_20260501\config\splits\RLT_splits_main_seed42.json
# {'I3D': 5, 'RLT': 15} {'I3D': 5, 'RLT': 5}
# I3D
# status
# PASS    5
# Name: count, dtype: int64
# RLT
# status
# PASS    15
# Name: count, dtype: int64
# PASS: all main splits have no video-level overlap
#
# ##########################################################################################
# S4 Modality Ablation — I3D
# ##########################################################################################
# Prepared sequences:
#   X_seq: (23599, 50, 1503)
#   y_seq: (23599,)
#   video_seq_ids: (23599,)
#   unique videos: 1568
#   class balance seq: [13047 10552]
#
# ----------------------------------------------------------------------
# MSTGNet_FaceOnly modalities=('face',) — I3D
# ----------------------------------------------------------------------
# filter_completed_splits: total=5, done=5, remaining=0
# MSTGNet_FaceOnly | I3D: all splits already complete.
#
# ----------------------------------------------------------------------
# MSTGNet_EyesOnly modalities=('eyes',) — I3D
# ----------------------------------------------------------------------
# filter_completed_splits: total=5, done=5, remaining=0
# MSTGNet_EyesOnly | I3D: all splits already complete.
#
# ----------------------------------------------------------------------
# MSTGNet_BodyOnly modalities=('body',) — I3D
# ----------------------------------------------------------------------
# filter_completed_splits: total=5, done=1, remaining=4
#
# ======================================================================
# Running MSTGNet_BodyOnly | I3D | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_BodyOnly, repeat=1, fold=2, seed=44, n_params=178946
# Sequences: train=13663, val=5336, test=4600 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6663 | val_auc=0.5292 | best_val_auc=0.5292 | bad_epochs=0
#   epoch=002 | loss=0.5963 | val_auc=0.5406 | best_val_auc=0.5406 | bad_epochs=0
#   epoch=003 | loss=0.5133 | val_auc=0.5816 | best_val_auc=0.5816 | bad_epochs=0
#   epoch=004 | loss=0.4377 | val_auc=0.6070 | best_val_auc=0.6070 | bad_epochs=0
#   epoch=005 | loss=0.3873 | val_auc=0.6523 | best_val_auc=0.6523 | bad_epochs=0
#   epoch=007 | loss=0.3121 | val_auc=0.6677 | best_val_auc=0.6677 | bad_epochs=0
#   epoch=009 | loss=0.2675 | val_auc=0.6921 | best_val_auc=0.6921 | bad_epochs=0
#   epoch=010 | loss=0.2496 | val_auc=0.6966 | best_val_auc=0.6966 | bad_epochs=0
#   epoch=011 | loss=0.2286 | val_auc=0.7001 | best_val_auc=0.7001 | bad_epochs=0
#   epoch=012 | loss=0.2143 | val_auc=0.7008 | best_val_auc=0.7008 | bad_epochs=0
#   epoch=014 | loss=0.1920 | val_auc=0.7129 | best_val_auc=0.7129 | bad_epochs=0
#   epoch=015 | loss=0.1825 | val_auc=0.7027 | best_val_auc=0.7129 | bad_epochs=1
#   epoch=016 | loss=0.1707 | val_auc=0.7194 | best_val_auc=0.7194 | bad_epochs=0
#   epoch=018 | loss=0.1549 | val_auc=0.7196 | best_val_auc=0.7196 | bad_epochs=0
#   epoch=020 | loss=0.1463 | val_auc=0.7109 | best_val_auc=0.7196 | bad_epochs=2
#   epoch=021 | loss=0.1407 | val_auc=0.7347 | best_val_auc=0.7347 | bad_epochs=0
#   epoch=022 | loss=0.1406 | val_auc=0.7349 | best_val_auc=0.7349 | bad_epochs=0
#   epoch=024 | loss=0.1260 | val_auc=0.7406 | best_val_auc=0.7406 | bad_epochs=0
#   epoch=025 | loss=0.1189 | val_auc=0.7099 | best_val_auc=0.7406 | bad_epochs=1
#   epoch=028 | loss=0.1118 | val_auc=0.7571 | best_val_auc=0.7571 | bad_epochs=0
#   epoch=029 | loss=0.1074 | val_auc=0.7588 | best_val_auc=0.7588 | bad_epochs=0
#   epoch=030 | loss=0.1007 | val_auc=0.7601 | best_val_auc=0.7601 | bad_epochs=0
#   epoch=031 | loss=0.1010 | val_auc=0.7795 | best_val_auc=0.7795 | bad_epochs=0
#   epoch=035 | loss=0.0910 | val_auc=0.7675 | best_val_auc=0.7795 | bad_epochs=4
#   epoch=039 | loss=0.0768 | val_auc=0.7803 | best_val_auc=0.7803 | bad_epochs=0
#   epoch=040 | loss=0.0771 | val_auc=0.7838 | best_val_auc=0.7838 | bad_epochs=0
#   epoch=043 | loss=0.0766 | val_auc=0.7948 | best_val_auc=0.7948 | bad_epochs=0
#   epoch=045 | loss=0.0762 | val_auc=0.7512 | best_val_auc=0.7948 | bad_epochs=2
#   epoch=050 | loss=0.0754 | val_auc=0.7573 | best_val_auc=0.7948 | bad_epochs=7
#   epoch=052 | loss=0.0626 | val_auc=0.7998 | best_val_auc=0.7998 | bad_epochs=0
#   epoch=055 | loss=0.0642 | val_auc=0.7731 | best_val_auc=0.7998 | bad_epochs=3
#   epoch=058 | loss=0.0550 | val_auc=0.8109 | best_val_auc=0.8109 | bad_epochs=0
#   epoch=059 | loss=0.0586 | val_auc=0.8156 | best_val_auc=0.8156 | bad_epochs=0
#   epoch=060 | loss=0.0606 | val_auc=0.7821 | best_val_auc=0.8156 | bad_epochs=1
#   epoch=065 | loss=0.0530 | val_auc=0.7996 | best_val_auc=0.8156 | bad_epochs=6
#   epoch=070 | loss=0.0512 | val_auc=0.7980 | best_val_auc=0.8156 | bad_epochs=11
#   epoch=071 | loss=0.0528 | val_auc=0.8160 | best_val_auc=0.8160 | bad_epochs=0
#   epoch=075 | loss=0.0524 | val_auc=0.7922 | best_val_auc=0.8160 | bad_epochs=4
#   epoch=080 | loss=0.0475 | val_auc=0.7932 | best_val_auc=0.8160 | bad_epochs=9
#   epoch=085 | loss=0.0404 | val_auc=0.7996 | best_val_auc=0.8160 | bad_epochs=14
#   Early stopping at epoch=86. Best epoch=71, best val AUC=0.8160
#
# ======================================================================
# Running MSTGNet_BodyOnly | I3D | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_BodyOnly, repeat=1, fold=3, seed=45, n_params=178946
# Sequences: train=13760, val=5234, test=4605 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6770 | val_auc=0.4992 | best_val_auc=0.4992 | bad_epochs=0
#   epoch=002 | loss=0.6148 | val_auc=0.5393 | best_val_auc=0.5393 | bad_epochs=0
#   epoch=003 | loss=0.5440 | val_auc=0.5876 | best_val_auc=0.5876 | bad_epochs=0
#   epoch=004 | loss=0.4729 | val_auc=0.6478 | best_val_auc=0.6478 | bad_epochs=0
#   epoch=005 | loss=0.4146 | val_auc=0.6429 | best_val_auc=0.6478 | bad_epochs=1
#   epoch=006 | loss=0.3700 | val_auc=0.6815 | best_val_auc=0.6815 | bad_epochs=0
#   epoch=007 | loss=0.3313 | val_auc=0.7102 | best_val_auc=0.7102 | bad_epochs=0
#   epoch=008 | loss=0.3058 | val_auc=0.7107 | best_val_auc=0.7107 | bad_epochs=0
#   epoch=009 | loss=0.2869 | val_auc=0.7144 | best_val_auc=0.7144 | bad_epochs=0
#   epoch=010 | loss=0.2650 | val_auc=0.7093 | best_val_auc=0.7144 | bad_epochs=1
#   epoch=011 | loss=0.2509 | val_auc=0.7251 | best_val_auc=0.7251 | bad_epochs=0
#   epoch=012 | loss=0.2252 | val_auc=0.7314 | best_val_auc=0.7314 | bad_epochs=0
#   epoch=013 | loss=0.2231 | val_auc=0.7399 | best_val_auc=0.7399 | bad_epochs=0
#   epoch=015 | loss=0.1974 | val_auc=0.7514 | best_val_auc=0.7514 | bad_epochs=0
#   epoch=016 | loss=0.1943 | val_auc=0.7565 | best_val_auc=0.7565 | bad_epochs=0
#   epoch=018 | loss=0.1815 | val_auc=0.7633 | best_val_auc=0.7633 | bad_epochs=0
#   epoch=020 | loss=0.1604 | val_auc=0.7837 | best_val_auc=0.7837 | bad_epochs=0
#   epoch=025 | loss=0.1340 | val_auc=0.7901 | best_val_auc=0.7901 | bad_epochs=0
#   epoch=028 | loss=0.1224 | val_auc=0.7920 | best_val_auc=0.7920 | bad_epochs=0
#   epoch=030 | loss=0.1138 | val_auc=0.7809 | best_val_auc=0.7920 | bad_epochs=2
#   epoch=032 | loss=0.1130 | val_auc=0.8018 | best_val_auc=0.8018 | bad_epochs=0
#   epoch=035 | loss=0.1051 | val_auc=0.7776 | best_val_auc=0.8018 | bad_epochs=3
#   epoch=040 | loss=0.0946 | val_auc=0.7907 | best_val_auc=0.8018 | bad_epochs=8
#   epoch=045 | loss=0.0846 | val_auc=0.7986 | best_val_auc=0.8018 | bad_epochs=13
#   epoch=047 | loss=0.0765 | val_auc=0.8089 | best_val_auc=0.8089 | bad_epochs=0
#   epoch=048 | loss=0.0748 | val_auc=0.8165 | best_val_auc=0.8165 | bad_epochs=0
#   epoch=050 | loss=0.0726 | val_auc=0.8133 | best_val_auc=0.8165 | bad_epochs=2
#   epoch=051 | loss=0.0696 | val_auc=0.8270 | best_val_auc=0.8270 | bad_epochs=0
#   epoch=055 | loss=0.0722 | val_auc=0.8161 | best_val_auc=0.8270 | bad_epochs=4
#   epoch=060 | loss=0.0582 | val_auc=0.8123 | best_val_auc=0.8270 | bad_epochs=9
#   epoch=063 | loss=0.0614 | val_auc=0.8361 | best_val_auc=0.8361 | bad_epochs=0
#   epoch=065 | loss=0.0591 | val_auc=0.8270 | best_val_auc=0.8361 | bad_epochs=2
#   epoch=070 | loss=0.0545 | val_auc=0.8031 | best_val_auc=0.8361 | bad_epochs=7
#   epoch=075 | loss=0.0495 | val_auc=0.8258 | best_val_auc=0.8361 | bad_epochs=12
#   Early stopping at epoch=78. Best epoch=63, best val AUC=0.8361
#
# ======================================================================
# Running MSTGNet_BodyOnly | I3D | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_BodyOnly, repeat=1, fold=4, seed=46, n_params=178946
# Sequences: train=13818, val=5141, test=4640 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6712 | val_auc=0.5236 | best_val_auc=0.5236 | bad_epochs=0
#   epoch=002 | loss=0.6004 | val_auc=0.5759 | best_val_auc=0.5759 | bad_epochs=0
#   epoch=003 | loss=0.5186 | val_auc=0.6035 | best_val_auc=0.6035 | bad_epochs=0
#   epoch=004 | loss=0.4513 | val_auc=0.6493 | best_val_auc=0.6493 | bad_epochs=0
#   epoch=005 | loss=0.4027 | val_auc=0.6752 | best_val_auc=0.6752 | bad_epochs=0
#   epoch=006 | loss=0.3694 | val_auc=0.6934 | best_val_auc=0.6934 | bad_epochs=0
#   epoch=007 | loss=0.3436 | val_auc=0.7073 | best_val_auc=0.7073 | bad_epochs=0
#   epoch=008 | loss=0.3127 | val_auc=0.7291 | best_val_auc=0.7291 | bad_epochs=0
#   epoch=009 | loss=0.2961 | val_auc=0.7409 | best_val_auc=0.7409 | bad_epochs=0
#   epoch=010 | loss=0.2739 | val_auc=0.7514 | best_val_auc=0.7514 | bad_epochs=0
#   epoch=012 | loss=0.2444 | val_auc=0.7766 | best_val_auc=0.7766 | bad_epochs=0
#   epoch=013 | loss=0.2326 | val_auc=0.7944 | best_val_auc=0.7944 | bad_epochs=0
#   epoch=015 | loss=0.2108 | val_auc=0.7809 | best_val_auc=0.7944 | bad_epochs=2
#   epoch=019 | loss=0.1785 | val_auc=0.8011 | best_val_auc=0.8011 | bad_epochs=0
#   epoch=020 | loss=0.1685 | val_auc=0.8128 | best_val_auc=0.8128 | bad_epochs=0
#   epoch=024 | loss=0.1500 | val_auc=0.8282 | best_val_auc=0.8282 | bad_epochs=0
#   epoch=025 | loss=0.1489 | val_auc=0.8249 | best_val_auc=0.8282 | bad_epochs=1
#   epoch=030 | loss=0.1246 | val_auc=0.8378 | best_val_auc=0.8378 | bad_epochs=0
#   epoch=033 | loss=0.1218 | val_auc=0.8433 | best_val_auc=0.8433 | bad_epochs=0
#   epoch=035 | loss=0.1133 | val_auc=0.8125 | best_val_auc=0.8433 | bad_epochs=2
#   epoch=036 | loss=0.1091 | val_auc=0.8439 | best_val_auc=0.8439 | bad_epochs=0
#   epoch=040 | loss=0.0997 | val_auc=0.8499 | best_val_auc=0.8499 | bad_epochs=0
#   epoch=042 | loss=0.0989 | val_auc=0.8531 | best_val_auc=0.8531 | bad_epochs=0
#   epoch=045 | loss=0.0930 | val_auc=0.8474 | best_val_auc=0.8531 | bad_epochs=3
#   epoch=046 | loss=0.0859 | val_auc=0.8550 | best_val_auc=0.8550 | bad_epochs=0
#   epoch=048 | loss=0.0918 | val_auc=0.8600 | best_val_auc=0.8600 | bad_epochs=0
#   epoch=050 | loss=0.0914 | val_auc=0.8404 | best_val_auc=0.8600 | bad_epochs=2
#   epoch=054 | loss=0.0763 | val_auc=0.8639 | best_val_auc=0.8639 | bad_epochs=0
#   epoch=055 | loss=0.0738 | val_auc=0.8485 | best_val_auc=0.8639 | bad_epochs=1
#   epoch=060 | loss=0.0685 | val_auc=0.8587 | best_val_auc=0.8639 | bad_epochs=6
#   epoch=063 | loss=0.0672 | val_auc=0.8670 | best_val_auc=0.8670 | bad_epochs=0
#   epoch=064 | loss=0.0666 | val_auc=0.8755 | best_val_auc=0.8755 | bad_epochs=0
#   epoch=065 | loss=0.0599 | val_auc=0.8607 | best_val_auc=0.8755 | bad_epochs=1
#   epoch=070 | loss=0.0615 | val_auc=0.8687 | best_val_auc=0.8755 | bad_epochs=6
#   epoch=075 | loss=0.0535 | val_auc=0.8646 | best_val_auc=0.8755 | bad_epochs=11
#   Early stopping at epoch=79. Best epoch=64, best val AUC=0.8755
#
# ======================================================================
# Running MSTGNet_BodyOnly | I3D | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_BodyOnly, repeat=1, fold=5, seed=47, n_params=178946
# Sequences: train=13595, val=5222, test=4782 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6618 | val_auc=0.4943 | best_val_auc=0.4943 | bad_epochs=0
#   epoch=002 | loss=0.5820 | val_auc=0.5383 | best_val_auc=0.5383 | bad_epochs=0
#   epoch=003 | loss=0.5092 | val_auc=0.5922 | best_val_auc=0.5922 | bad_epochs=0
#   epoch=004 | loss=0.4511 | val_auc=0.5927 | best_val_auc=0.5927 | bad_epochs=0
#   epoch=005 | loss=0.4071 | val_auc=0.6112 | best_val_auc=0.6112 | bad_epochs=0
#   epoch=006 | loss=0.3741 | val_auc=0.6348 | best_val_auc=0.6348 | bad_epochs=0
#   epoch=007 | loss=0.3428 | val_auc=0.6501 | best_val_auc=0.6501 | bad_epochs=0
#   epoch=008 | loss=0.3139 | val_auc=0.6747 | best_val_auc=0.6747 | bad_epochs=0
#   epoch=010 | loss=0.2724 | val_auc=0.6716 | best_val_auc=0.6747 | bad_epochs=2
#   epoch=011 | loss=0.2514 | val_auc=0.6811 | best_val_auc=0.6811 | bad_epochs=0
#   epoch=012 | loss=0.2426 | val_auc=0.7026 | best_val_auc=0.7026 | bad_epochs=0
#   epoch=015 | loss=0.2057 | val_auc=0.7131 | best_val_auc=0.7131 | bad_epochs=0
#   epoch=016 | loss=0.1994 | val_auc=0.7233 | best_val_auc=0.7233 | bad_epochs=0
#   epoch=018 | loss=0.1813 | val_auc=0.7292 | best_val_auc=0.7292 | bad_epochs=0
#   epoch=020 | loss=0.1659 | val_auc=0.7278 | best_val_auc=0.7292 | bad_epochs=2
#   epoch=021 | loss=0.1567 | val_auc=0.7430 | best_val_auc=0.7430 | bad_epochs=0
#   epoch=023 | loss=0.1472 | val_auc=0.7535 | best_val_auc=0.7535 | bad_epochs=0
#   epoch=025 | loss=0.1389 | val_auc=0.7351 | best_val_auc=0.7535 | bad_epochs=2
#   epoch=026 | loss=0.1384 | val_auc=0.7659 | best_val_auc=0.7659 | bad_epochs=0
#   epoch=030 | loss=0.1161 | val_auc=0.7672 | best_val_auc=0.7672 | bad_epochs=0
#   epoch=033 | loss=0.1144 | val_auc=0.7751 | best_val_auc=0.7751 | bad_epochs=0
#   epoch=035 | loss=0.1108 | val_auc=0.7723 | best_val_auc=0.7751 | bad_epochs=2
#   epoch=037 | loss=0.1058 | val_auc=0.7868 | best_val_auc=0.7868 | bad_epochs=0
#   epoch=040 | loss=0.0975 | val_auc=0.7715 | best_val_auc=0.7868 | bad_epochs=3
#   epoch=043 | loss=0.0961 | val_auc=0.7917 | best_val_auc=0.7917 | bad_epochs=0
#   epoch=045 | loss=0.0943 | val_auc=0.7909 | best_val_auc=0.7917 | bad_epochs=2
#   epoch=047 | loss=0.0840 | val_auc=0.7956 | best_val_auc=0.7956 | bad_epochs=0
#   epoch=050 | loss=0.0820 | val_auc=0.7931 | best_val_auc=0.7956 | bad_epochs=3
#   epoch=053 | loss=0.0832 | val_auc=0.8010 | best_val_auc=0.8010 | bad_epochs=0
#   epoch=055 | loss=0.0781 | val_auc=0.8060 | best_val_auc=0.8060 | bad_epochs=0
#   epoch=056 | loss=0.0834 | val_auc=0.8125 | best_val_auc=0.8125 | bad_epochs=0
#   epoch=060 | loss=0.0766 | val_auc=0.7899 | best_val_auc=0.8125 | bad_epochs=4
#   epoch=065 | loss=0.0677 | val_auc=0.8082 | best_val_auc=0.8125 | bad_epochs=9
#   epoch=067 | loss=0.0749 | val_auc=0.8162 | best_val_auc=0.8162 | bad_epochs=0
#   epoch=070 | loss=0.0627 | val_auc=0.8144 | best_val_auc=0.8162 | bad_epochs=3
#   epoch=074 | loss=0.0681 | val_auc=0.8185 | best_val_auc=0.8185 | bad_epochs=0
#   epoch=075 | loss=0.0606 | val_auc=0.8179 | best_val_auc=0.8185 | bad_epochs=1
#   epoch=080 | loss=0.0557 | val_auc=0.8194 | best_val_auc=0.8194 | bad_epochs=0
#   epoch=083 | loss=0.0532 | val_auc=0.8263 | best_val_auc=0.8263 | bad_epochs=0
#   epoch=085 | loss=0.0508 | val_auc=0.8196 | best_val_auc=0.8263 | bad_epochs=2
#   epoch=090 | loss=0.0585 | val_auc=0.8287 | best_val_auc=0.8287 | bad_epochs=0
#   epoch=095 | loss=0.0501 | val_auc=0.8228 | best_val_auc=0.8287 | bad_epochs=5
#   epoch=100 | loss=0.0442 | val_auc=0.8080 | best_val_auc=0.8287 | bad_epochs=10
#
# ----------------------------------------------------------------------
# MSTGNet_FaceEyes modalities=('face', 'eyes') — I3D
# ----------------------------------------------------------------------
#
# ======================================================================
# Running MSTGNet_FaceEyes | I3D | repeat=1 fold=1
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceEyes, repeat=1, fold=1, seed=43, n_params=503427
# Sequences: train=13465, val=5162, test=4972 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6881 | val_auc=0.4735 | best_val_auc=0.4735 | bad_epochs=0
#   epoch=003 | loss=0.6572 | val_auc=0.4962 | best_val_auc=0.4962 | bad_epochs=0
#   epoch=005 | loss=0.6248 | val_auc=0.5092 | best_val_auc=0.5092 | bad_epochs=0
#   epoch=008 | loss=0.5893 | val_auc=0.5175 | best_val_auc=0.5175 | bad_epochs=0
#   epoch=010 | loss=0.5733 | val_auc=0.5110 | best_val_auc=0.5175 | bad_epochs=2
#   epoch=011 | loss=0.5598 | val_auc=0.5189 | best_val_auc=0.5189 | bad_epochs=0
#   epoch=013 | loss=0.5482 | val_auc=0.5364 | best_val_auc=0.5364 | bad_epochs=0
#   epoch=015 | loss=0.5297 | val_auc=0.5365 | best_val_auc=0.5365 | bad_epochs=0
#   epoch=019 | loss=0.5097 | val_auc=0.5382 | best_val_auc=0.5382 | bad_epochs=0
#   epoch=020 | loss=0.5000 | val_auc=0.5518 | best_val_auc=0.5518 | bad_epochs=0
#   epoch=021 | loss=0.4960 | val_auc=0.5694 | best_val_auc=0.5694 | bad_epochs=0
#   epoch=024 | loss=0.4811 | val_auc=0.5738 | best_val_auc=0.5738 | bad_epochs=0
#   epoch=025 | loss=0.4743 | val_auc=0.5661 | best_val_auc=0.5738 | bad_epochs=1
#   epoch=027 | loss=0.4669 | val_auc=0.5776 | best_val_auc=0.5776 | bad_epochs=0
#   epoch=028 | loss=0.4610 | val_auc=0.5854 | best_val_auc=0.5854 | bad_epochs=0
#   epoch=030 | loss=0.4461 | val_auc=0.5689 | best_val_auc=0.5854 | bad_epochs=2
#   epoch=033 | loss=0.4284 | val_auc=0.5942 | best_val_auc=0.5942 | bad_epochs=0
#   epoch=034 | loss=0.4256 | val_auc=0.6045 | best_val_auc=0.6045 | bad_epochs=0
#   epoch=035 | loss=0.4148 | val_auc=0.5903 | best_val_auc=0.6045 | bad_epochs=1
#   epoch=037 | loss=0.4154 | val_auc=0.6115 | best_val_auc=0.6115 | bad_epochs=0
#   epoch=040 | loss=0.3963 | val_auc=0.5975 | best_val_auc=0.6115 | bad_epochs=3
#   epoch=041 | loss=0.3920 | val_auc=0.6243 | best_val_auc=0.6243 | bad_epochs=0
#   epoch=045 | loss=0.3722 | val_auc=0.6214 | best_val_auc=0.6243 | bad_epochs=4
#   epoch=047 | loss=0.3709 | val_auc=0.6303 | best_val_auc=0.6303 | bad_epochs=0
#   epoch=050 | loss=0.3584 | val_auc=0.6349 | best_val_auc=0.6349 | bad_epochs=0
#   epoch=055 | loss=0.3444 | val_auc=0.6060 | best_val_auc=0.6349 | bad_epochs=5
#   epoch=058 | loss=0.3378 | val_auc=0.6423 | best_val_auc=0.6423 | bad_epochs=0
#   epoch=060 | loss=0.3251 | val_auc=0.6269 | best_val_auc=0.6423 | bad_epochs=2
#   epoch=064 | loss=0.3204 | val_auc=0.6614 | best_val_auc=0.6614 | bad_epochs=0
#   epoch=065 | loss=0.3235 | val_auc=0.6332 | best_val_auc=0.6614 | bad_epochs=1
#   epoch=070 | loss=0.3052 | val_auc=0.6295 | best_val_auc=0.6614 | bad_epochs=6
#   epoch=075 | loss=0.2957 | val_auc=0.6549 | best_val_auc=0.6614 | bad_epochs=11
#   Early stopping at epoch=79. Best epoch=64, best val AUC=0.6614
#
# ======================================================================
# Running MSTGNet_FaceEyes | I3D | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceEyes, repeat=1, fold=2, seed=44, n_params=503427
# Sequences: train=13663, val=5336, test=4600 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6876 | val_auc=0.4778 | best_val_auc=0.4778 | bad_epochs=0
#   epoch=002 | loss=0.6710 | val_auc=0.4922 | best_val_auc=0.4922 | bad_epochs=0
#   epoch=004 | loss=0.6509 | val_auc=0.4929 | best_val_auc=0.4929 | bad_epochs=0
#   epoch=005 | loss=0.6363 | val_auc=0.4965 | best_val_auc=0.4965 | bad_epochs=0
#   epoch=007 | loss=0.5997 | val_auc=0.5021 | best_val_auc=0.5021 | bad_epochs=0
#   epoch=009 | loss=0.5720 | val_auc=0.5061 | best_val_auc=0.5061 | bad_epochs=0
#   epoch=010 | loss=0.5598 | val_auc=0.5077 | best_val_auc=0.5077 | bad_epochs=0
#   epoch=012 | loss=0.5443 | val_auc=0.5152 | best_val_auc=0.5152 | bad_epochs=0
#   epoch=014 | loss=0.5325 | val_auc=0.5320 | best_val_auc=0.5320 | bad_epochs=0
#   epoch=015 | loss=0.5206 | val_auc=0.5440 | best_val_auc=0.5440 | bad_epochs=0
#   epoch=020 | loss=0.4941 | val_auc=0.5402 | best_val_auc=0.5440 | bad_epochs=5
#   epoch=021 | loss=0.4824 | val_auc=0.5459 | best_val_auc=0.5459 | bad_epochs=0
#   epoch=023 | loss=0.4769 | val_auc=0.5481 | best_val_auc=0.5481 | bad_epochs=0
#   epoch=024 | loss=0.4707 | val_auc=0.5587 | best_val_auc=0.5587 | bad_epochs=0
#   epoch=025 | loss=0.4686 | val_auc=0.5486 | best_val_auc=0.5587 | bad_epochs=1
#   epoch=026 | loss=0.4602 | val_auc=0.5775 | best_val_auc=0.5775 | bad_epochs=0
#   epoch=028 | loss=0.4435 | val_auc=0.5860 | best_val_auc=0.5860 | bad_epochs=0
#   epoch=030 | loss=0.4424 | val_auc=0.5691 | best_val_auc=0.5860 | bad_epochs=2
#   epoch=031 | loss=0.4311 | val_auc=0.5863 | best_val_auc=0.5863 | bad_epochs=0
#   epoch=035 | loss=0.4181 | val_auc=0.5879 | best_val_auc=0.5879 | bad_epochs=0
#   epoch=036 | loss=0.4123 | val_auc=0.5960 | best_val_auc=0.5960 | bad_epochs=0
#   epoch=037 | loss=0.4079 | val_auc=0.6035 | best_val_auc=0.6035 | bad_epochs=0
#   epoch=039 | loss=0.4008 | val_auc=0.6062 | best_val_auc=0.6062 | bad_epochs=0
#   epoch=040 | loss=0.3984 | val_auc=0.6097 | best_val_auc=0.6097 | bad_epochs=0
#   epoch=041 | loss=0.3975 | val_auc=0.6109 | best_val_auc=0.6109 | bad_epochs=0
#   epoch=045 | loss=0.3775 | val_auc=0.5914 | best_val_auc=0.6109 | bad_epochs=4
#   epoch=047 | loss=0.3755 | val_auc=0.6132 | best_val_auc=0.6132 | bad_epochs=0
#   epoch=050 | loss=0.3699 | val_auc=0.6101 | best_val_auc=0.6132 | bad_epochs=3
#   epoch=053 | loss=0.3523 | val_auc=0.6139 | best_val_auc=0.6139 | bad_epochs=0
#   epoch=055 | loss=0.3507 | val_auc=0.6199 | best_val_auc=0.6199 | bad_epochs=0
#   epoch=056 | loss=0.3422 | val_auc=0.6313 | best_val_auc=0.6313 | bad_epochs=0
#   epoch=060 | loss=0.3370 | val_auc=0.6228 | best_val_auc=0.6313 | bad_epochs=4
#   epoch=065 | loss=0.3198 | val_auc=0.5986 | best_val_auc=0.6313 | bad_epochs=9
#   epoch=066 | loss=0.3219 | val_auc=0.6430 | best_val_auc=0.6430 | bad_epochs=0
#   epoch=070 | loss=0.3180 | val_auc=0.6227 | best_val_auc=0.6430 | bad_epochs=4
#   epoch=075 | loss=0.3048 | val_auc=0.6200 | best_val_auc=0.6430 | bad_epochs=9
#   epoch=079 | loss=0.2934 | val_auc=0.6439 | best_val_auc=0.6439 | bad_epochs=0
#   epoch=080 | loss=0.2991 | val_auc=0.6441 | best_val_auc=0.6441 | bad_epochs=0
#   epoch=084 | loss=0.2826 | val_auc=0.6451 | best_val_auc=0.6451 | bad_epochs=0
#   epoch=085 | loss=0.2879 | val_auc=0.6301 | best_val_auc=0.6451 | bad_epochs=1
#   epoch=090 | loss=0.2782 | val_auc=0.6245 | best_val_auc=0.6451 | bad_epochs=6
#   epoch=091 | loss=0.2755 | val_auc=0.6458 | best_val_auc=0.6458 | bad_epochs=0
#   epoch=093 | loss=0.2740 | val_auc=0.6532 | best_val_auc=0.6532 | bad_epochs=0
#   epoch=095 | loss=0.2729 | val_auc=0.6520 | best_val_auc=0.6532 | bad_epochs=2
#   epoch=100 | loss=0.2542 | val_auc=0.6357 | best_val_auc=0.6532 | bad_epochs=7
#
# ======================================================================
# Running MSTGNet_FaceEyes | I3D | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceEyes, repeat=1, fold=3, seed=45, n_params=503427
# Sequences: train=13760, val=5234, test=4605 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6854 | val_auc=0.4743 | best_val_auc=0.4743 | bad_epochs=0
#   epoch=004 | loss=0.6418 | val_auc=0.4870 | best_val_auc=0.4870 | bad_epochs=0
#   epoch=005 | loss=0.6249 | val_auc=0.4945 | best_val_auc=0.4945 | bad_epochs=0
#   epoch=006 | loss=0.6113 | val_auc=0.5074 | best_val_auc=0.5074 | bad_epochs=0
#   epoch=008 | loss=0.5849 | val_auc=0.5105 | best_val_auc=0.5105 | bad_epochs=0
#   epoch=009 | loss=0.5734 | val_auc=0.5258 | best_val_auc=0.5258 | bad_epochs=0
#   epoch=010 | loss=0.5602 | val_auc=0.5418 | best_val_auc=0.5418 | bad_epochs=0
#   epoch=013 | loss=0.5333 | val_auc=0.5467 | best_val_auc=0.5467 | bad_epochs=0
#   epoch=015 | loss=0.5154 | val_auc=0.5461 | best_val_auc=0.5467 | bad_epochs=2
#   epoch=018 | loss=0.4926 | val_auc=0.5478 | best_val_auc=0.5478 | bad_epochs=0
#   epoch=019 | loss=0.4831 | val_auc=0.5562 | best_val_auc=0.5562 | bad_epochs=0
#   epoch=020 | loss=0.4760 | val_auc=0.5392 | best_val_auc=0.5562 | bad_epochs=1
#   epoch=021 | loss=0.4703 | val_auc=0.5567 | best_val_auc=0.5567 | bad_epochs=0
#   epoch=023 | loss=0.4563 | val_auc=0.5633 | best_val_auc=0.5633 | bad_epochs=0
#   epoch=025 | loss=0.4470 | val_auc=0.5658 | best_val_auc=0.5658 | bad_epochs=0
#   epoch=030 | loss=0.4181 | val_auc=0.5627 | best_val_auc=0.5658 | bad_epochs=5
#   epoch=031 | loss=0.4184 | val_auc=0.5790 | best_val_auc=0.5790 | bad_epochs=0
#   epoch=035 | loss=0.3969 | val_auc=0.5645 | best_val_auc=0.5790 | bad_epochs=4
#   epoch=039 | loss=0.3776 | val_auc=0.5832 | best_val_auc=0.5832 | bad_epochs=0
#   epoch=040 | loss=0.3736 | val_auc=0.5740 | best_val_auc=0.5832 | bad_epochs=1
#   epoch=044 | loss=0.3619 | val_auc=0.5908 | best_val_auc=0.5908 | bad_epochs=0
#   epoch=045 | loss=0.3579 | val_auc=0.5827 | best_val_auc=0.5908 | bad_epochs=1
#   epoch=050 | loss=0.3410 | val_auc=0.5915 | best_val_auc=0.5915 | bad_epochs=0
#   epoch=052 | loss=0.3353 | val_auc=0.5956 | best_val_auc=0.5956 | bad_epochs=0
#   epoch=054 | loss=0.3244 | val_auc=0.5956 | best_val_auc=0.5956 | bad_epochs=0
#   epoch=055 | loss=0.3240 | val_auc=0.5909 | best_val_auc=0.5956 | bad_epochs=1
#   epoch=057 | loss=0.3270 | val_auc=0.5998 | best_val_auc=0.5998 | bad_epochs=0
#   epoch=060 | loss=0.3143 | val_auc=0.5978 | best_val_auc=0.5998 | bad_epochs=3
#   epoch=062 | loss=0.3068 | val_auc=0.6019 | best_val_auc=0.6019 | bad_epochs=0
#   epoch=063 | loss=0.3041 | val_auc=0.6088 | best_val_auc=0.6088 | bad_epochs=0
#   epoch=065 | loss=0.2939 | val_auc=0.5936 | best_val_auc=0.6088 | bad_epochs=2
#   epoch=068 | loss=0.2933 | val_auc=0.6108 | best_val_auc=0.6108 | bad_epochs=0
#   epoch=070 | loss=0.2885 | val_auc=0.6019 | best_val_auc=0.6108 | bad_epochs=2
#   epoch=074 | loss=0.2793 | val_auc=0.6217 | best_val_auc=0.6217 | bad_epochs=0
#   epoch=075 | loss=0.2777 | val_auc=0.6037 | best_val_auc=0.6217 | bad_epochs=1
#   epoch=078 | loss=0.2713 | val_auc=0.6275 | best_val_auc=0.6275 | bad_epochs=0
#   epoch=080 | loss=0.2647 | val_auc=0.6161 | best_val_auc=0.6275 | bad_epochs=2
#   epoch=085 | loss=0.2635 | val_auc=0.6061 | best_val_auc=0.6275 | bad_epochs=7
#   epoch=090 | loss=0.2469 | val_auc=0.6296 | best_val_auc=0.6296 | bad_epochs=0
#   epoch=095 | loss=0.2431 | val_auc=0.6298 | best_val_auc=0.6298 | bad_epochs=0
#   epoch=096 | loss=0.2410 | val_auc=0.6304 | best_val_auc=0.6304 | bad_epochs=0
#   epoch=100 | loss=0.2355 | val_auc=0.6160 | best_val_auc=0.6304 | bad_epochs=4
#
# ======================================================================
# Running MSTGNet_FaceEyes | I3D | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceEyes, repeat=1, fold=4, seed=46, n_params=503427
# Sequences: train=13818, val=5141, test=4640 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6908 | val_auc=0.4496 | best_val_auc=0.4496 | bad_epochs=0
#   epoch=002 | loss=0.6722 | val_auc=0.4564 | best_val_auc=0.4564 | bad_epochs=0
#   epoch=003 | loss=0.6595 | val_auc=0.5011 | best_val_auc=0.5011 | bad_epochs=0
#   epoch=005 | loss=0.6315 | val_auc=0.5057 | best_val_auc=0.5057 | bad_epochs=0
#   epoch=007 | loss=0.6060 | val_auc=0.5225 | best_val_auc=0.5225 | bad_epochs=0
#   epoch=008 | loss=0.5916 | val_auc=0.5452 | best_val_auc=0.5452 | bad_epochs=0
#   epoch=010 | loss=0.5656 | val_auc=0.5301 | best_val_auc=0.5452 | bad_epochs=2
#   epoch=013 | loss=0.5425 | val_auc=0.5468 | best_val_auc=0.5468 | bad_epochs=0
#   epoch=014 | loss=0.5345 | val_auc=0.5603 | best_val_auc=0.5603 | bad_epochs=0
#   epoch=015 | loss=0.5236 | val_auc=0.5473 | best_val_auc=0.5603 | bad_epochs=1
#   epoch=017 | loss=0.5122 | val_auc=0.5614 | best_val_auc=0.5614 | bad_epochs=0
#   epoch=020 | loss=0.4930 | val_auc=0.5730 | best_val_auc=0.5730 | bad_epochs=0
#   epoch=023 | loss=0.4741 | val_auc=0.5896 | best_val_auc=0.5896 | bad_epochs=0
#   epoch=025 | loss=0.4630 | val_auc=0.5776 | best_val_auc=0.5896 | bad_epochs=2
#   epoch=030 | loss=0.4426 | val_auc=0.5701 | best_val_auc=0.5896 | bad_epochs=7
#   epoch=033 | loss=0.4266 | val_auc=0.5929 | best_val_auc=0.5929 | bad_epochs=0
#   epoch=034 | loss=0.4232 | val_auc=0.6033 | best_val_auc=0.6033 | bad_epochs=0
#   epoch=035 | loss=0.4175 | val_auc=0.5747 | best_val_auc=0.6033 | bad_epochs=1
#   epoch=036 | loss=0.4166 | val_auc=0.6070 | best_val_auc=0.6070 | bad_epochs=0
#   epoch=039 | loss=0.4026 | val_auc=0.6105 | best_val_auc=0.6105 | bad_epochs=0
#   epoch=040 | loss=0.3928 | val_auc=0.5908 | best_val_auc=0.6105 | bad_epochs=1
#   epoch=043 | loss=0.3872 | val_auc=0.6212 | best_val_auc=0.6212 | bad_epochs=0
#   epoch=045 | loss=0.3835 | val_auc=0.6065 | best_val_auc=0.6212 | bad_epochs=2
#   epoch=047 | loss=0.3780 | val_auc=0.6340 | best_val_auc=0.6340 | bad_epochs=0
#   epoch=048 | loss=0.3690 | val_auc=0.6341 | best_val_auc=0.6341 | bad_epochs=0
#   epoch=050 | loss=0.3668 | val_auc=0.6170 | best_val_auc=0.6341 | bad_epochs=2
#   epoch=054 | loss=0.3539 | val_auc=0.6386 | best_val_auc=0.6386 | bad_epochs=0
#   epoch=055 | loss=0.3512 | val_auc=0.6415 | best_val_auc=0.6415 | bad_epochs=0
#   epoch=056 | loss=0.3531 | val_auc=0.6471 | best_val_auc=0.6471 | bad_epochs=0
#   epoch=059 | loss=0.3399 | val_auc=0.6527 | best_val_auc=0.6527 | bad_epochs=0
#   epoch=060 | loss=0.3379 | val_auc=0.6489 | best_val_auc=0.6527 | bad_epochs=1
#   epoch=065 | loss=0.3232 | val_auc=0.6416 | best_val_auc=0.6527 | bad_epochs=6
#   epoch=068 | loss=0.3178 | val_auc=0.6651 | best_val_auc=0.6651 | bad_epochs=0
#   epoch=070 | loss=0.3148 | val_auc=0.6615 | best_val_auc=0.6651 | bad_epochs=2
#   epoch=072 | loss=0.3136 | val_auc=0.6808 | best_val_auc=0.6808 | bad_epochs=0
#   epoch=075 | loss=0.3023 | val_auc=0.6460 | best_val_auc=0.6808 | bad_epochs=3
#   epoch=080 | loss=0.2867 | val_auc=0.6676 | best_val_auc=0.6808 | bad_epochs=8
#   epoch=085 | loss=0.2826 | val_auc=0.6831 | best_val_auc=0.6831 | bad_epochs=0
#   epoch=089 | loss=0.2772 | val_auc=0.6982 | best_val_auc=0.6982 | bad_epochs=0
#   epoch=090 | loss=0.2679 | val_auc=0.6840 | best_val_auc=0.6982 | bad_epochs=1
#   epoch=092 | loss=0.2669 | val_auc=0.7033 | best_val_auc=0.7033 | bad_epochs=0
#   epoch=095 | loss=0.2628 | val_auc=0.6846 | best_val_auc=0.7033 | bad_epochs=3
#   epoch=100 | loss=0.2536 | val_auc=0.6820 | best_val_auc=0.7033 | bad_epochs=8
#
# ======================================================================
# Running MSTGNet_FaceEyes | I3D | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceEyes, repeat=1, fold=5, seed=47, n_params=503427
# Sequences: train=13595, val=5222, test=4782 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6924 | val_auc=0.5008 | best_val_auc=0.5008 | bad_epochs=0
#   epoch=002 | loss=0.6776 | val_auc=0.5241 | best_val_auc=0.5241 | bad_epochs=0
#   epoch=003 | loss=0.6686 | val_auc=0.5551 | best_val_auc=0.5551 | bad_epochs=0
#   epoch=005 | loss=0.6438 | val_auc=0.5519 | best_val_auc=0.5551 | bad_epochs=2
#   epoch=010 | loss=0.5739 | val_auc=0.5500 | best_val_auc=0.5551 | bad_epochs=7
#   epoch=012 | loss=0.5540 | val_auc=0.5636 | best_val_auc=0.5636 | bad_epochs=0
#   epoch=013 | loss=0.5426 | val_auc=0.5675 | best_val_auc=0.5675 | bad_epochs=0
#   epoch=015 | loss=0.5255 | val_auc=0.5590 | best_val_auc=0.5675 | bad_epochs=2
#   epoch=016 | loss=0.5197 | val_auc=0.5817 | best_val_auc=0.5817 | bad_epochs=0
#   epoch=020 | loss=0.4911 | val_auc=0.5676 | best_val_auc=0.5817 | bad_epochs=4
#   epoch=025 | loss=0.4664 | val_auc=0.5897 | best_val_auc=0.5897 | bad_epochs=0
#   epoch=030 | loss=0.4364 | val_auc=0.5759 | best_val_auc=0.5897 | bad_epochs=5
#   epoch=035 | loss=0.4209 | val_auc=0.5768 | best_val_auc=0.5897 | bad_epochs=10
#   epoch=036 | loss=0.4177 | val_auc=0.5920 | best_val_auc=0.5920 | bad_epochs=0
#   epoch=037 | loss=0.4077 | val_auc=0.6016 | best_val_auc=0.6016 | bad_epochs=0
#   epoch=040 | loss=0.3984 | val_auc=0.6010 | best_val_auc=0.6016 | bad_epochs=3
#   epoch=045 | loss=0.3830 | val_auc=0.5942 | best_val_auc=0.6016 | bad_epochs=8
#   epoch=046 | loss=0.3779 | val_auc=0.6042 | best_val_auc=0.6042 | bad_epochs=0
#   epoch=048 | loss=0.3704 | val_auc=0.6139 | best_val_auc=0.6139 | bad_epochs=0
#   epoch=049 | loss=0.3665 | val_auc=0.6169 | best_val_auc=0.6169 | bad_epochs=0
#   epoch=050 | loss=0.3669 | val_auc=0.6008 | best_val_auc=0.6169 | bad_epochs=1
#   epoch=055 | loss=0.3481 | val_auc=0.6047 | best_val_auc=0.6169 | bad_epochs=6
#   epoch=057 | loss=0.3454 | val_auc=0.6208 | best_val_auc=0.6208 | bad_epochs=0
#   epoch=060 | loss=0.3320 | val_auc=0.6328 | best_val_auc=0.6328 | bad_epochs=0
#   epoch=065 | loss=0.3188 | val_auc=0.6104 | best_val_auc=0.6328 | bad_epochs=5
#   epoch=070 | loss=0.3066 | val_auc=0.6133 | best_val_auc=0.6328 | bad_epochs=10
#   epoch=073 | loss=0.3048 | val_auc=0.6358 | best_val_auc=0.6358 | bad_epochs=0
#   epoch=075 | loss=0.2981 | val_auc=0.6394 | best_val_auc=0.6394 | bad_epochs=0
#   epoch=080 | loss=0.2870 | val_auc=0.6407 | best_val_auc=0.6407 | bad_epochs=0
#   epoch=085 | loss=0.2807 | val_auc=0.6431 | best_val_auc=0.6431 | bad_epochs=0
#   epoch=089 | loss=0.2712 | val_auc=0.6515 | best_val_auc=0.6515 | bad_epochs=0
#   epoch=090 | loss=0.2673 | val_auc=0.6513 | best_val_auc=0.6515 | bad_epochs=1
#   epoch=091 | loss=0.2672 | val_auc=0.6548 | best_val_auc=0.6548 | bad_epochs=0
#   epoch=095 | loss=0.2599 | val_auc=0.6268 | best_val_auc=0.6548 | bad_epochs=4
#   epoch=100 | loss=0.2502 | val_auc=0.6598 | best_val_auc=0.6598 | bad_epochs=0
#
# ----------------------------------------------------------------------
# MSTGNet_FaceBody modalities=('face', 'body') — I3D
# ----------------------------------------------------------------------
#
# ======================================================================
# Running MSTGNet_FaceBody | I3D | repeat=1 fold=1
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceBody, repeat=1, fold=1, seed=43, n_params=512259
# Sequences: train=13465, val=5162, test=4972 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6717 | val_auc=0.4868 | best_val_auc=0.4868 | bad_epochs=0
#   epoch=002 | loss=0.6022 | val_auc=0.5856 | best_val_auc=0.5856 | bad_epochs=0
#   epoch=003 | loss=0.5120 | val_auc=0.6199 | best_val_auc=0.6199 | bad_epochs=0
#   epoch=004 | loss=0.4320 | val_auc=0.6763 | best_val_auc=0.6763 | bad_epochs=0
#   epoch=005 | loss=0.3794 | val_auc=0.7011 | best_val_auc=0.7011 | bad_epochs=0
#   epoch=006 | loss=0.3381 | val_auc=0.7042 | best_val_auc=0.7042 | bad_epochs=0
#   epoch=007 | loss=0.3080 | val_auc=0.7323 | best_val_auc=0.7323 | bad_epochs=0
#   epoch=008 | loss=0.2770 | val_auc=0.7604 | best_val_auc=0.7604 | bad_epochs=0
#   epoch=009 | loss=0.2564 | val_auc=0.7702 | best_val_auc=0.7702 | bad_epochs=0
#   epoch=010 | loss=0.2383 | val_auc=0.7653 | best_val_auc=0.7702 | bad_epochs=1
#   epoch=011 | loss=0.2192 | val_auc=0.7754 | best_val_auc=0.7754 | bad_epochs=0
#   epoch=012 | loss=0.2068 | val_auc=0.7789 | best_val_auc=0.7789 | bad_epochs=0
#   epoch=013 | loss=0.1957 | val_auc=0.7812 | best_val_auc=0.7812 | bad_epochs=0
#   epoch=014 | loss=0.1897 | val_auc=0.7950 | best_val_auc=0.7950 | bad_epochs=0
#   epoch=015 | loss=0.1822 | val_auc=0.7936 | best_val_auc=0.7950 | bad_epochs=1
#   epoch=016 | loss=0.1673 | val_auc=0.8069 | best_val_auc=0.8069 | bad_epochs=0
#   epoch=020 | loss=0.1401 | val_auc=0.7903 | best_val_auc=0.8069 | bad_epochs=4
#   epoch=021 | loss=0.1328 | val_auc=0.8117 | best_val_auc=0.8117 | bad_epochs=0
#   epoch=022 | loss=0.1320 | val_auc=0.8155 | best_val_auc=0.8155 | bad_epochs=0
#   epoch=023 | loss=0.1228 | val_auc=0.8212 | best_val_auc=0.8212 | bad_epochs=0
#   epoch=024 | loss=0.1241 | val_auc=0.8246 | best_val_auc=0.8246 | bad_epochs=0
#   epoch=025 | loss=0.1177 | val_auc=0.8122 | best_val_auc=0.8246 | bad_epochs=1
#   epoch=030 | loss=0.0958 | val_auc=0.8011 | best_val_auc=0.8246 | bad_epochs=6
#   epoch=033 | loss=0.1023 | val_auc=0.8288 | best_val_auc=0.8288 | bad_epochs=0
#   epoch=035 | loss=0.0880 | val_auc=0.8210 | best_val_auc=0.8288 | bad_epochs=2
#   epoch=036 | loss=0.0887 | val_auc=0.8332 | best_val_auc=0.8332 | bad_epochs=0
#   epoch=040 | loss=0.0835 | val_auc=0.8350 | best_val_auc=0.8350 | bad_epochs=0
#   epoch=045 | loss=0.0745 | val_auc=0.8179 | best_val_auc=0.8350 | bad_epochs=5
#   epoch=047 | loss=0.0690 | val_auc=0.8359 | best_val_auc=0.8359 | bad_epochs=0
#   epoch=050 | loss=0.0652 | val_auc=0.8450 | best_val_auc=0.8450 | bad_epochs=0
#   epoch=055 | loss=0.0577 | val_auc=0.8361 | best_val_auc=0.8450 | bad_epochs=5
#   epoch=060 | loss=0.0546 | val_auc=0.8349 | best_val_auc=0.8450 | bad_epochs=10
#   epoch=061 | loss=0.0537 | val_auc=0.8491 | best_val_auc=0.8491 | bad_epochs=0
#   epoch=065 | loss=0.0474 | val_auc=0.8382 | best_val_auc=0.8491 | bad_epochs=4
#   epoch=070 | loss=0.0477 | val_auc=0.8356 | best_val_auc=0.8491 | bad_epochs=9
#   epoch=075 | loss=0.0463 | val_auc=0.8222 | best_val_auc=0.8491 | bad_epochs=14
#   Early stopping at epoch=76. Best epoch=61, best val AUC=0.8491
#
# ======================================================================
# Running MSTGNet_FaceBody | I3D | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceBody, repeat=1, fold=2, seed=44, n_params=512259
# Sequences: train=13663, val=5336, test=4600 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6640 | val_auc=0.5550 | best_val_auc=0.5550 | bad_epochs=0
#   epoch=003 | loss=0.4847 | val_auc=0.5946 | best_val_auc=0.5946 | bad_epochs=0
#   epoch=004 | loss=0.4103 | val_auc=0.6498 | best_val_auc=0.6498 | bad_epochs=0
#   epoch=005 | loss=0.3602 | val_auc=0.6878 | best_val_auc=0.6878 | bad_epochs=0
#   epoch=007 | loss=0.2907 | val_auc=0.6880 | best_val_auc=0.6880 | bad_epochs=0
#   epoch=008 | loss=0.2673 | val_auc=0.7111 | best_val_auc=0.7111 | bad_epochs=0
#   epoch=009 | loss=0.2532 | val_auc=0.7243 | best_val_auc=0.7243 | bad_epochs=0
#   epoch=010 | loss=0.2272 | val_auc=0.7482 | best_val_auc=0.7482 | bad_epochs=0
#   epoch=013 | loss=0.1846 | val_auc=0.7591 | best_val_auc=0.7591 | bad_epochs=0
#   epoch=015 | loss=0.1647 | val_auc=0.7744 | best_val_auc=0.7744 | bad_epochs=0
#   epoch=018 | loss=0.1431 | val_auc=0.7752 | best_val_auc=0.7752 | bad_epochs=0
#   epoch=020 | loss=0.1305 | val_auc=0.7685 | best_val_auc=0.7752 | bad_epochs=2
#   epoch=021 | loss=0.1298 | val_auc=0.7764 | best_val_auc=0.7764 | bad_epochs=0
#   epoch=022 | loss=0.1156 | val_auc=0.7894 | best_val_auc=0.7894 | bad_epochs=0
#   epoch=025 | loss=0.1085 | val_auc=0.7777 | best_val_auc=0.7894 | bad_epochs=3
#   epoch=027 | loss=0.0973 | val_auc=0.7967 | best_val_auc=0.7967 | bad_epochs=0
#   epoch=029 | loss=0.0943 | val_auc=0.7998 | best_val_auc=0.7998 | bad_epochs=0
#   epoch=030 | loss=0.0909 | val_auc=0.7910 | best_val_auc=0.7998 | bad_epochs=1
#   epoch=031 | loss=0.0843 | val_auc=0.8068 | best_val_auc=0.8068 | bad_epochs=0
#   epoch=035 | loss=0.0772 | val_auc=0.7935 | best_val_auc=0.8068 | bad_epochs=4
#   epoch=039 | loss=0.0752 | val_auc=0.8068 | best_val_auc=0.8068 | bad_epochs=0
#   epoch=040 | loss=0.0714 | val_auc=0.8079 | best_val_auc=0.8079 | bad_epochs=0
#   epoch=041 | loss=0.0694 | val_auc=0.8084 | best_val_auc=0.8084 | bad_epochs=0
#   epoch=043 | loss=0.0691 | val_auc=0.8112 | best_val_auc=0.8112 | bad_epochs=0
#   epoch=044 | loss=0.0642 | val_auc=0.8234 | best_val_auc=0.8234 | bad_epochs=0
#   epoch=045 | loss=0.0618 | val_auc=0.8031 | best_val_auc=0.8234 | bad_epochs=1
#   epoch=050 | loss=0.0578 | val_auc=0.7971 | best_val_auc=0.8234 | bad_epochs=6
#   epoch=055 | loss=0.0515 | val_auc=0.8120 | best_val_auc=0.8234 | bad_epochs=11
#   Early stopping at epoch=59. Best epoch=44, best val AUC=0.8234
#
# ======================================================================
# Running MSTGNet_FaceBody | I3D | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceBody, repeat=1, fold=3, seed=45, n_params=512259
# Sequences: train=13760, val=5234, test=4605 | Videos: train=902, val=352, test=314
#   epoch=001 | loss=0.6651 | val_auc=0.5097 | best_val_auc=0.5097 | bad_epochs=0
#   epoch=002 | loss=0.5818 | val_auc=0.5765 | best_val_auc=0.5765 | bad_epochs=0
#   epoch=003 | loss=0.4949 | val_auc=0.5998 | best_val_auc=0.5998 | bad_epochs=0
#   epoch=004 | loss=0.4123 | val_auc=0.6445 | best_val_auc=0.6445 | bad_epochs=0
#   epoch=005 | loss=0.3558 | val_auc=0.6900 | best_val_auc=0.6900 | bad_epochs=0
#   epoch=006 | loss=0.3094 | val_auc=0.7022 | best_val_auc=0.7022 | bad_epochs=0
#   epoch=007 | loss=0.2789 | val_auc=0.7258 | best_val_auc=0.7258 | bad_epochs=0
#   epoch=008 | loss=0.2526 | val_auc=0.7362 | best_val_auc=0.7362 | bad_epochs=0
#   epoch=009 | loss=0.2332 | val_auc=0.7517 | best_val_auc=0.7517 | bad_epochs=0
#   epoch=010 | loss=0.2172 | val_auc=0.7407 | best_val_auc=0.7517 | bad_epochs=1
#   epoch=011 | loss=0.2077 | val_auc=0.7544 | best_val_auc=0.7544 | bad_epochs=0
#   epoch=014 | loss=0.1806 | val_auc=0.7702 | best_val_auc=0.7702 | bad_epochs=0
#   epoch=015 | loss=0.1716 | val_auc=0.7712 | best_val_auc=0.7712 | bad_epochs=0
#   epoch=018 | loss=0.1504 | val_auc=0.7991 | best_val_auc=0.7991 | bad_epochs=0
#   epoch=020 | loss=0.1374 | val_auc=0.7975 | best_val_auc=0.7991 | bad_epochs=2
#   epoch=022 | loss=0.1270 | val_auc=0.8113 | best_val_auc=0.8113 | bad_epochs=0
#   epoch=025 | loss=0.1146 | val_auc=0.8103 | best_val_auc=0.8113 | bad_epochs=3
#   epoch=028 | loss=0.1043 | val_auc=0.8198 | best_val_auc=0.8198 | bad_epochs=0
#   epoch=030 | loss=0.0965 | val_auc=0.8107 | best_val_auc=0.8198 | bad_epochs=2
#   epoch=032 | loss=0.0947 | val_auc=0.8206 | best_val_auc=0.8206 | bad_epochs=0
#   epoch=033 | loss=0.0880 | val_auc=0.8242 | best_val_auc=0.8242 | bad_epochs=0
#   epoch=035 | loss=0.0859 | val_auc=0.8150 | best_val_auc=0.8242 | bad_epochs=2
#   epoch=036 | loss=0.0823 | val_auc=0.8329 | best_val_auc=0.8329 | bad_epochs=0
#   epoch=039 | loss=0.0789 | val_auc=0.8363 | best_val_auc=0.8363 | bad_epochs=0
#   epoch=040 | loss=0.0765 | val_auc=0.8256 | best_val_auc=0.8363 | bad_epochs=1
#   epoch=045 | loss=0.0697 | val_auc=0.8157 | best_val_auc=0.8363 | bad_epochs=6
#   epoch=050 | loss=0.0643 | val_auc=0.8234 | best_val_auc=0.8363 | bad_epochs=11
#   Early stopping at epoch=54. Best epoch=39, best val AUC=0.8363
#
# ======================================================================
# Running MSTGNet_FaceBody | I3D | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceBody, repeat=1, fold=4, seed=46, n_params=512259
# Sequences: train=13818, val=5141, test=4640 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6654 | val_auc=0.4706 | best_val_auc=0.4706 | bad_epochs=0
#   epoch=002 | loss=0.5826 | val_auc=0.5942 | best_val_auc=0.5942 | bad_epochs=0
#   epoch=003 | loss=0.4895 | val_auc=0.6392 | best_val_auc=0.6392 | bad_epochs=0
#   epoch=004 | loss=0.4168 | val_auc=0.6814 | best_val_auc=0.6814 | bad_epochs=0
#   epoch=005 | loss=0.3555 | val_auc=0.7101 | best_val_auc=0.7101 | bad_epochs=0
#   epoch=006 | loss=0.3260 | val_auc=0.7132 | best_val_auc=0.7132 | bad_epochs=0
#   epoch=007 | loss=0.2911 | val_auc=0.7173 | best_val_auc=0.7173 | bad_epochs=0
#   epoch=008 | loss=0.2711 | val_auc=0.7509 | best_val_auc=0.7509 | bad_epochs=0
#   epoch=010 | loss=0.2413 | val_auc=0.7632 | best_val_auc=0.7632 | bad_epochs=0
#   epoch=011 | loss=0.2236 | val_auc=0.7671 | best_val_auc=0.7671 | bad_epochs=0
#   epoch=012 | loss=0.2138 | val_auc=0.7910 | best_val_auc=0.7910 | bad_epochs=0
#   epoch=014 | loss=0.1826 | val_auc=0.8034 | best_val_auc=0.8034 | bad_epochs=0
#   epoch=015 | loss=0.1795 | val_auc=0.7893 | best_val_auc=0.8034 | bad_epochs=1
#   epoch=017 | loss=0.1605 | val_auc=0.8080 | best_val_auc=0.8080 | bad_epochs=0
#   epoch=020 | loss=0.1469 | val_auc=0.8149 | best_val_auc=0.8149 | bad_epochs=0
#   epoch=024 | loss=0.1302 | val_auc=0.8175 | best_val_auc=0.8175 | bad_epochs=0
#   epoch=025 | loss=0.1162 | val_auc=0.8161 | best_val_auc=0.8175 | bad_epochs=1
#   epoch=026 | loss=0.1154 | val_auc=0.8311 | best_val_auc=0.8311 | bad_epochs=0
#   epoch=030 | loss=0.1018 | val_auc=0.8234 | best_val_auc=0.8311 | bad_epochs=4
#   epoch=032 | loss=0.0943 | val_auc=0.8328 | best_val_auc=0.8328 | bad_epochs=0
#   epoch=035 | loss=0.0867 | val_auc=0.8380 | best_val_auc=0.8380 | bad_epochs=0
#   epoch=036 | loss=0.0863 | val_auc=0.8387 | best_val_auc=0.8387 | bad_epochs=0
#   epoch=040 | loss=0.0733 | val_auc=0.8555 | best_val_auc=0.8555 | bad_epochs=0
#   epoch=045 | loss=0.0747 | val_auc=0.8442 | best_val_auc=0.8555 | bad_epochs=5
#   epoch=049 | loss=0.0653 | val_auc=0.8556 | best_val_auc=0.8556 | bad_epochs=0
#   epoch=050 | loss=0.0651 | val_auc=0.8543 | best_val_auc=0.8556 | bad_epochs=1
#   epoch=054 | loss=0.0588 | val_auc=0.8611 | best_val_auc=0.8611 | bad_epochs=0
#   epoch=055 | loss=0.0646 | val_auc=0.8499 | best_val_auc=0.8611 | bad_epochs=1
#   epoch=059 | loss=0.0546 | val_auc=0.8630 | best_val_auc=0.8630 | bad_epochs=0
#   epoch=060 | loss=0.0520 | val_auc=0.8546 | best_val_auc=0.8630 | bad_epochs=1
#   epoch=062 | loss=0.0507 | val_auc=0.8666 | best_val_auc=0.8666 | bad_epochs=0
#   epoch=065 | loss=0.0459 | val_auc=0.8641 | best_val_auc=0.8666 | bad_epochs=3
#   epoch=068 | loss=0.0446 | val_auc=0.8678 | best_val_auc=0.8678 | bad_epochs=0
#   epoch=069 | loss=0.0451 | val_auc=0.8692 | best_val_auc=0.8692 | bad_epochs=0
#   epoch=070 | loss=0.0435 | val_auc=0.8705 | best_val_auc=0.8705 | bad_epochs=0
#   epoch=072 | loss=0.0445 | val_auc=0.8743 | best_val_auc=0.8743 | bad_epochs=0
#   epoch=075 | loss=0.0462 | val_auc=0.8616 | best_val_auc=0.8743 | bad_epochs=3
#   epoch=080 | loss=0.0415 | val_auc=0.8653 | best_val_auc=0.8743 | bad_epochs=8
#   epoch=081 | loss=0.0428 | val_auc=0.8851 | best_val_auc=0.8851 | bad_epochs=0
#   epoch=085 | loss=0.0359 | val_auc=0.8768 | best_val_auc=0.8851 | bad_epochs=4
#   epoch=090 | loss=0.0344 | val_auc=0.8628 | best_val_auc=0.8851 | bad_epochs=9
#   epoch=095 | loss=0.0315 | val_auc=0.8651 | best_val_auc=0.8851 | bad_epochs=14
#   Early stopping at epoch=96. Best epoch=81, best val AUC=0.8851
#
# ======================================================================
# Running MSTGNet_FaceBody | I3D | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=I3D, model=MSTGNet_FaceBody, repeat=1, fold=5, seed=47, n_params=512259
# Sequences: train=13595, val=5222, test=4782 | Videos: train=903, val=352, test=313
#   epoch=001 | loss=0.6661 | val_auc=0.5390 | best_val_auc=0.5390 | bad_epochs=0
#   epoch=002 | loss=0.5726 | val_auc=0.5724 | best_val_auc=0.5724 | bad_epochs=0
#   epoch=003 | loss=0.4894 | val_auc=0.6242 | best_val_auc=0.6242 | bad_epochs=0
#   epoch=004 | loss=0.4124 | val_auc=0.6534 | best_val_auc=0.6534 | bad_epochs=0
#   epoch=005 | loss=0.3589 | val_auc=0.6763 | best_val_auc=0.6763 | bad_epochs=0
#   epoch=006 | loss=0.3187 | val_auc=0.7000 | best_val_auc=0.7000 | bad_epochs=0
#   epoch=007 | loss=0.2889 | val_auc=0.7154 | best_val_auc=0.7154 | bad_epochs=0
#   epoch=008 | loss=0.2632 | val_auc=0.7229 | best_val_auc=0.7229 | bad_epochs=0
#   epoch=010 | loss=0.2262 | val_auc=0.7191 | best_val_auc=0.7229 | bad_epochs=2
# ...
#   epoch=015 | loss=0.0685 | val_auc=0.7041 | best_val_auc=0.7755 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.7755
#
# ======================================================================
# Running MSTGNet_FaceEyes | RLT | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_FaceEyes, repeat=1, fold=5, seed=47, n_params=503427
# Sequences: train=1921, val=752, test=753 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.5073 | val_auc=0.8520 | best_val_auc=0.8520 | bad_epochs=0
#   epoch=005 | loss=0.2739 | val_auc=0.8163 | best_val_auc=0.8520 | bad_epochs=4
#   epoch=010 | loss=0.1727 | val_auc=0.7908 | best_val_auc=0.8520 | bad_epochs=9
#   epoch=015 | loss=0.1183 | val_auc=0.8316 | best_val_auc=0.8520 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.8520
#
# ----------------------------------------------------------------------
# MSTGNet_FaceBody modalities=('face', 'body') — RLT
# ----------------------------------------------------------------------
#
# ======================================================================
# Running MSTGNet_FaceBody | RLT | repeat=1 fold=1
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_FaceBody, repeat=1, fold=1, seed=43, n_params=512259
# Sequences: train=2103, val=700, test=623 | Videos: train=69, val=27, test=25
#   epoch=001 | loss=0.4678 | val_auc=0.7747 | best_val_auc=0.7747 | bad_epochs=0
#   epoch=005 | loss=0.1396 | val_auc=0.6209 | best_val_auc=0.7747 | bad_epochs=4
#   epoch=010 | loss=0.0631 | val_auc=0.6484 | best_val_auc=0.7747 | bad_epochs=9
#   epoch=015 | loss=0.0369 | val_auc=0.6319 | best_val_auc=0.7747 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.7747
#
# ======================================================================
# Running MSTGNet_FaceBody | RLT | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_FaceBody, repeat=1, fold=2, seed=44, n_params=512259
# Sequences: train=2034, val=759, test=633 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4452 | val_auc=0.6633 | best_val_auc=0.6633 | bad_epochs=0
#   epoch=005 | loss=0.1038 | val_auc=0.6684 | best_val_auc=0.6684 | bad_epochs=0
#   epoch=010 | loss=0.0468 | val_auc=0.6327 | best_val_auc=0.6684 | bad_epochs=5
#   epoch=013 | loss=0.0331 | val_auc=0.6735 | best_val_auc=0.6735 | bad_epochs=0
#   epoch=015 | loss=0.0310 | val_auc=0.6480 | best_val_auc=0.6735 | bad_epochs=2
#   epoch=016 | loss=0.0316 | val_auc=0.6786 | best_val_auc=0.6786 | bad_epochs=0
#   epoch=020 | loss=0.0208 | val_auc=0.6684 | best_val_auc=0.6786 | bad_epochs=4
#   epoch=025 | loss=0.0107 | val_auc=0.6888 | best_val_auc=0.6888 | bad_epochs=0
#   epoch=030 | loss=0.0078 | val_auc=0.6327 | best_val_auc=0.6888 | bad_epochs=5
#   epoch=035 | loss=0.0072 | val_auc=0.6071 | best_val_auc=0.6888 | bad_epochs=10
#   epoch=040 | loss=0.0019 | val_auc=0.6224 | best_val_auc=0.6888 | bad_epochs=15
#   Early stopping at epoch=40. Best epoch=25, best val AUC=0.6888
#
# ======================================================================
# Running MSTGNet_FaceBody | RLT | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_FaceBody, repeat=1, fold=3, seed=45, n_params=512259
# Sequences: train=1930, val=741, test=755 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4114 | val_auc=0.6327 | best_val_auc=0.6327 | bad_epochs=0
#   epoch=002 | loss=0.2522 | val_auc=0.6480 | best_val_auc=0.6480 | bad_epochs=0
#   epoch=005 | loss=0.0906 | val_auc=0.6684 | best_val_auc=0.6684 | bad_epochs=0
#   epoch=010 | loss=0.0315 | val_auc=0.6786 | best_val_auc=0.6786 | bad_epochs=0
#   epoch=012 | loss=0.0259 | val_auc=0.6939 | best_val_auc=0.6939 | bad_epochs=0
#   epoch=015 | loss=0.0197 | val_auc=0.6939 | best_val_auc=0.6939 | bad_epochs=0
#   epoch=018 | loss=0.0140 | val_auc=0.7347 | best_val_auc=0.7347 | bad_epochs=0
#   epoch=020 | loss=0.0205 | val_auc=0.6735 | best_val_auc=0.7347 | bad_epochs=2
#   epoch=025 | loss=0.0045 | val_auc=0.6633 | best_val_auc=0.7347 | bad_epochs=7
#   epoch=030 | loss=0.0277 | val_auc=0.6939 | best_val_auc=0.7347 | bad_epochs=12
#   Early stopping at epoch=33. Best epoch=18, best val AUC=0.7347
#
# ======================================================================
# Running MSTGNet_FaceBody | RLT | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_FaceBody, repeat=1, fold=4, seed=46, n_params=512259
# Sequences: train=2012, val=752, test=662 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4329 | val_auc=0.7908 | best_val_auc=0.7908 | bad_epochs=0
#   epoch=005 | loss=0.1223 | val_auc=0.7296 | best_val_auc=0.7908 | bad_epochs=4
#   epoch=010 | loss=0.0459 | val_auc=0.7449 | best_val_auc=0.7908 | bad_epochs=9
#   epoch=015 | loss=0.0201 | val_auc=0.7194 | best_val_auc=0.7908 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.7908
#
# ======================================================================
# Running MSTGNet_FaceBody | RLT | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_FaceBody, repeat=1, fold=5, seed=47, n_params=512259
# Sequences: train=1921, val=752, test=753 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4473 | val_auc=0.8929 | best_val_auc=0.8929 | bad_epochs=0
#   epoch=005 | loss=0.1263 | val_auc=0.8367 | best_val_auc=0.8929 | bad_epochs=4
#   epoch=010 | loss=0.0362 | val_auc=0.8214 | best_val_auc=0.8929 | bad_epochs=9
#   epoch=015 | loss=0.0215 | val_auc=0.7704 | best_val_auc=0.8929 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.8929
#
# ----------------------------------------------------------------------
# MSTGNet_EyesBody modalities=('eyes', 'body') — RLT
# ----------------------------------------------------------------------
#
# ======================================================================
# Running MSTGNet_EyesBody | RLT | repeat=1 fold=1
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_EyesBody, repeat=1, fold=1, seed=43, n_params=340227
# Sequences: train=2103, val=700, test=623 | Videos: train=69, val=27, test=25
#   epoch=001 | loss=0.5066 | val_auc=0.7253 | best_val_auc=0.7253 | bad_epochs=0
#   epoch=002 | loss=0.3465 | val_auc=0.7473 | best_val_auc=0.7473 | bad_epochs=0
#   epoch=003 | loss=0.2567 | val_auc=0.7527 | best_val_auc=0.7527 | bad_epochs=0
#   epoch=005 | loss=0.1570 | val_auc=0.7033 | best_val_auc=0.7527 | bad_epochs=2
#   epoch=010 | loss=0.0555 | val_auc=0.5549 | best_val_auc=0.7527 | bad_epochs=7
#   epoch=015 | loss=0.0309 | val_auc=0.5659 | best_val_auc=0.7527 | bad_epochs=12
#   Early stopping at epoch=18. Best epoch=3, best val AUC=0.7527
#
# ======================================================================
# Running MSTGNet_EyesBody | RLT | repeat=1 fold=2
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_EyesBody, repeat=1, fold=2, seed=44, n_params=340227
# Sequences: train=2034, val=759, test=633 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4428 | val_auc=0.6327 | best_val_auc=0.6327 | bad_epochs=0
#   epoch=002 | loss=0.2613 | val_auc=0.6582 | best_val_auc=0.6582 | bad_epochs=0
#   epoch=005 | loss=0.1015 | val_auc=0.6276 | best_val_auc=0.6582 | bad_epochs=3
#   epoch=010 | loss=0.0519 | val_auc=0.6071 | best_val_auc=0.6582 | bad_epochs=8
#   epoch=015 | loss=0.0191 | val_auc=0.6480 | best_val_auc=0.6582 | bad_epochs=13
#   Early stopping at epoch=17. Best epoch=2, best val AUC=0.6582
#
# ======================================================================
# Running MSTGNet_EyesBody | RLT | repeat=1 fold=3
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_EyesBody, repeat=1, fold=3, seed=45, n_params=340227
# Sequences: train=1930, val=741, test=755 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4165 | val_auc=0.6837 | best_val_auc=0.6837 | bad_epochs=0
#   epoch=005 | loss=0.1032 | val_auc=0.6378 | best_val_auc=0.6837 | bad_epochs=4
#   epoch=010 | loss=0.0334 | val_auc=0.5918 | best_val_auc=0.6837 | bad_epochs=9
#   epoch=015 | loss=0.0149 | val_auc=0.5612 | best_val_auc=0.6837 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.6837
#
# ======================================================================
# Running MSTGNet_EyesBody | RLT | repeat=1 fold=4
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_EyesBody, repeat=1, fold=4, seed=46, n_params=340227
# Sequences: train=2012, val=752, test=662 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.4933 | val_auc=0.8061 | best_val_auc=0.8061 | bad_epochs=0
#   epoch=002 | loss=0.3249 | val_auc=0.8112 | best_val_auc=0.8112 | bad_epochs=0
#   epoch=005 | loss=0.1380 | val_auc=0.7194 | best_val_auc=0.8112 | bad_epochs=3
#   epoch=010 | loss=0.0434 | val_auc=0.7449 | best_val_auc=0.8112 | bad_epochs=8
#   epoch=015 | loss=0.0209 | val_auc=0.7704 | best_val_auc=0.8112 | bad_epochs=13
#   Early stopping at epoch=17. Best epoch=2, best val AUC=0.8112
#
# ======================================================================
# Running MSTGNet_EyesBody | RLT | repeat=1 fold=5
# ======================================================================
# Fold setup: dataset=RLT, model=MSTGNet_EyesBody, repeat=1, fold=5, seed=47, n_params=340227
# Sequences: train=1921, val=752, test=753 | Videos: train=69, val=28, test=24
#   epoch=001 | loss=0.5199 | val_auc=0.9031 | best_val_auc=0.9031 | bad_epochs=0
#   epoch=005 | loss=0.1433 | val_auc=0.7500 | best_val_auc=0.9031 | bad_epochs=4
#   epoch=010 | loss=0.0473 | val_auc=0.7449 | best_val_auc=0.9031 | bad_epochs=9
#   epoch=015 | loss=0.0297 | val_auc=0.7653 | best_val_auc=0.9031 | bad_epochs=14
#   Early stopping at epoch=16. Best epoch=1, best val AUC=0.9031
# Saved table: outputs\revision_final_20260501\tables\table_modality_ablation.csv shape=(14, 47)
#    dataset             model  seed  repeat  fold  best_epoch  best_val_auc  \
# 0      I3D           MSTGNet    43       1     1          60      0.860634
# 1      I3D           MSTGNet    44       1     2          61      0.807432
# 2      I3D           MSTGNet    45       1     3          38      0.841329
# 3      I3D           MSTGNet    46       1     4          72      0.865283
# 4      I3D           MSTGNet    47       1     5          52      0.850659
# ..     ...               ...   ...     ...   ...         ...           ...
# 65     RLT  MSTGNet_EyesBody    43       1     1           3      0.752747
# 66     RLT  MSTGNet_EyesBody    44       1     2           2      0.658163
# 67     RLT  MSTGNet_EyesBody    45       1     3           1      0.683673
# 68     RLT  MSTGNet_EyesBody    46       1     4           2      0.811224
# 69     RLT  MSTGNet_EyesBody    47       1     5           1      0.903061
#
#     last_train_loss  threshold   threshold_source  ...  test_recall   test_f1  \
# 0          0.045745   0.264879  validation_youden  ...     0.847134  0.782353
# 1          0.037703   0.451381  validation_youden  ...     0.796178  0.798722
# 2          0.061221   0.555223  validation_youden  ...     0.770701  0.753894
# 3          0.035453   0.444590  validation_youden  ...     0.853503  0.822086
# 4          0.045366   0.334289  validation_youden  ...     0.756410  0.776316
# ..              ...        ...                ...  ...          ...       ...
# 65         0.026289   0.915671  validation_youden  ...     0.384615  0.555556
# 66         0.024488   0.758563  validation_youden  ...     0.500000  0.571429
# 67         0.018242   0.596909  validation_youden  ...     0.666667  0.727273
# 68         0.019518   0.511430  validation_youden  ...     0.583333  0.666667
# 69         0.022129   0.810953  validation_youden  ...     0.416667  0.555556
#
#     test_mcc  test_sensitivity  test_specificity  test_brier  test_tn  \
# 0   0.536064          0.847134          0.681529    0.180390      107
# 1   0.598738          0.796178          0.802548    0.168834      126
# 2   0.497310          0.770701          0.726115    0.209193      114
# 3   0.631157          0.853503          0.775641    0.153733      121
# 4   0.566160          0.756410          0.808917    0.187003      127
# ..       ...               ...               ...         ...      ...
# 65  0.480384          0.384615          1.000000    0.180737       12
# 66  0.258199          0.500000          0.750000    0.184928        9
# 67  0.507093          0.666667          0.833333    0.157138       10
# 68  0.430331          0.583333          0.833333    0.226472       10
# 69  0.384900          0.416667          0.916667    0.214904       11
#
#     test_fp  test_fn  test_tp
# 0        50       24      133
# 1        31       32      125
# 2        43       36      121
# 3        35       23      134
# 4        30       38      118
# ..      ...      ...      ...
# 65        0        8        5
# 66        3        6        6
# 67        2        4        8
# 68        2        5        7
# 69        1        7        5
#
# [70 rows x 52 columns]
#                           item  \
# 0                     manifest
# 1              dataset_summary
# 2        capacity_check_pre_S2
# 3                     main_I3D
# 4                     main_RLT
# 5                 full_ref_I3D
# 6                 full_ref_RLT
# 7               baseline_table
# 8                   arch_table
# 9                  modal_table
# 10              landmark_table
# 11    landmark_prediction_corr
# 12         cross_dataset_table
# 13          compute_cost_table
# 14  temporal_sensitivity_table
# 15             multiseed_stats
# 16      statistical_comparison
# 17         repeat_level_ci_I3D
# 18         repeat_level_ci_RLT
# 19         repeat_level_ci_all
# 20   repeat_level_ci_multiseed
# 21       repeat_level_ci_table
# 22           paper_table_index
# 23     paper_table12_repeat_ci
# 24        interpretability_dir
#
#                                                  path  exists
# 0   outputs\revision_final_20260501\config\experim...    True
# 1   outputs\revision_final_20260501\tables\dataset...    True
# 2   outputs\revision_final_20260501\compute_cost\c...   False
# 3   outputs\revision_final_20260501\fold_results\m...    True
# 4   outputs\revision_final_20260501\fold_results\m...    True
# 5   outputs\revision_final_20260501\fold_results\f...    True
# 6   outputs\revision_final_20260501\fold_results\f...    True
# 7   outputs\revision_final_20260501\tables\table_b...    True
# 8   outputs\revision_final_20260501\tables\table_a...    True
# 9   outputs\revision_final_20260501\tables\table_m...    True
# 10  outputs\revision_final_20260501\tables\table_l...    True
# 11  outputs\revision_final_20260501\tables\table_l...    True
# 12  outputs\revision_final_20260501\tables\table_c...   False
# 13  outputs\revision_final_20260501\tables\table_c...   False
# 14  outputs\revision_final_20260501\tables\table_t...   False
# 15  outputs\revision_final_20260501\stats\statisti...   False
# 16  outputs\revision_final_20260501\stats\statisti...   False
# 17  outputs\revision_final_20260501\stats\repeat_l...   False
# 18  outputs\revision_final_20260501\stats\repeat_l...   False
# 19  outputs\revision_final_20260501\stats\repeat_l...   False
# 20  outputs\revision_final_20260501\tables\repeat_...   False
# 21  outputs\revision_final_20260501\tables\table_r...   False
# 22  outputs\revision_final_20260501\tables\PAPER_T...   False
# 23  outputs\revision_final_20260501\tables\PAPER_T...   False
# 24   outputs\revision_final_20260501\interpretability    True
